# %%
#%% library import
import numpy as np
import pandas as pd
import torch as tc
import torch
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from sklearn.preprocessing import Normalizer
from matplotlib import pyplot as plt
from matplotlib import image as img
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial

# %%
#%% mini_dataset loading
with open("datasets/KIBA/trainset_cnn+desc.txt", "rb") as fp:
    trainset = pickle.load(fp)

with open("datasets/KIBA/validset_cnn+desc.txt", "rb") as fp:
    validset = pickle.load(fp)

# %%
#%% Make collate func.
def collate(samples):
    # The input `samples` is a list of pairs [(graph, label),(graph, label)].
    descs, images, labels = map(list, zip(*samples))
    return tc.tensor(descs, dtype=tc.float).cuda(), tc.tensor(images, dtype=tc.float).cuda(), tc.tensor(labels).cuda()

# %%
#%% network module 선언
class BasicConv2d(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride, padding=0):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_planes, out_planes,
                              kernel_size=kernel_size, stride=stride,
                              padding=padding, bias=False) # verify bias false
        self.bn = nn.BatchNorm2d(out_planes,
                                 eps=0.001, # value found in tensorflow
                                 momentum=0.1, # default pytorch value
                                 affine=True)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        out = self.relu(x)
        return out
    

class InceptionResnet_Ablock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Ablock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(4, 4, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 6, kernel_size=3, stride=1, padding=1),
            BasicConv2d(6, 8, kernel_size=3, stride=1, padding=1)
        )

        self.conv2d = nn.Conv2d(16, 4, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Ablock(nn.Module):
    def __init__(self):
        super(Reduction_Ablock, self).__init__()

        self.branch0 = BasicConv2d(4, 6, kernel_size=3, stride=2)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1),
            BasicConv2d(4, 6, kernel_size=3, stride=2)
        )

        self.branch2 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        return out


class InceptionResnet_Bblock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Bblock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(16, 16, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=(1,7), stride=1, padding=(0,3)),
            BasicConv2d(20, 24, kernel_size=(7,1), stride=1, padding=(3,0))
        )

        self.conv2d = nn.Conv2d(40, 16, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Bblock(nn.Module):
    def __init__(self):
        super(Reduction_Bblock, self).__init__()

        self.branch0 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 24, kernel_size=3, stride=2)
        )

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=3, stride=2)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 18, kernel_size=(3,1), stride=1, padding=(1,0)),
            BasicConv2d(18, 20, kernel_size=3, stride=2)
        )

        self.branch3 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        x3 = self.branch3(x)
        out = torch.cat((x0, x1, x2, x3), 1)
        return out

    
class InceptionResnet_Cblock(nn.Module):
    def __init__(self, scale=1.0, noReLU=False):
        super(InceptionResnet_Cblock, self).__init__()

        self.scale = scale
        self.noReLU = noReLU

        self.branch0 = BasicConv2d(80, 80, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(80, 80, kernel_size=1, stride=1),
            BasicConv2d(80, 93, kernel_size=(1,3), stride=1, padding=(0,1)),
            BasicConv2d(93, 106, kernel_size=(3,1), stride=1, padding=(1,0))
        )

        self.conv2d = nn.Conv2d(186, 80, kernel_size=1, stride=1)
        if not self.noReLU:
            self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        return out


class SqueezeExcitation(nn.Module):
    def __init__(self, channel):
        super(SqueezeExcitation, self).__init__()
        
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channel, channel // 2),
            nn.ReLU(),
            nn.Linear(channel // 2, channel),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        out = self.squeeze(x).view(b, c)
        out = self.excitation(out).view(b, c, 1, 1)
        out = x * out.expand_as(x)
        return out

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.dslayers = nn.Sequential(     
                        nn.Linear(9577, 2048),
                        nn.BatchNorm1d(2048),
                        nn.ReLU(),
                        nn.Dropout(0.5),
                        nn.Linear(2048, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(512, 128),
                        )
    
        self.imlayers = nn.Sequential(
                        BasicConv2d(1, 4, kernel_size=4, stride=1),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        Reduction_Ablock(), 
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        Reduction_Bblock(),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80)
                        )
        
        self.avgpool = nn.AvgPool2d(68, count_include_pad=False)
        self.regress = nn.Linear(208, 1)

    def forward(self, desc, image):
        ds_h = self.dslayers(desc)
        dim = 1
        for d in ds_h.size()[1:]:
            dim = dim * d
        ds_o = ds_h.view(-1, dim)
        
        im_h = self.imlayers(image)
        im_h = self.avgpool(im_h)
        dim = 1
        for d in im_h.size()[1:]: #16, 4, 4
            dim = dim * d
        im_o = im_h.view(-1, dim)
        
        cat = tc.cat((ds_o, im_o), 1)
       
        return self.regress(cat)

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 16
hp_d['num_epochs'] = 300

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% Training
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean')
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                           #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (desc, image, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(desc, image).view(-1)
        loss = loss_func(prediction, label)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()

    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (desc, image, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(desc, image).view(-1)
        loss = loss_func(prediction, label)
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)

end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.7886389921020749
# va_var: 0.8894951422093866
# total params: 21033243
# Training epoch 0, loss 6.5317
# Validation epoch 0, loss 2.7812
# Training epoch 1, loss 1.0696
# Validation epoch 1, loss 1.1388
# Training epoch 2, loss 0.8046
# Validation epoch 2, loss 0.7970
# Training epoch 3, loss 0.6715
# Validation epoch 3, loss 0.7364
# Training epoch 4, loss 0.5803
# Validation epoch 4, loss 0.5943
# Training epoch 5, loss 0.4963
# Validation epoch 5, loss 0.7458
# Training epoch 6, loss 0.4405
# Validation epoch 6, loss 0.5791
# Training epoch 7, loss 0.4026
# Validation epoch 7, loss 27.5530
# Training epoch 8, loss 0.3766
# Validation epoch 8, loss 1.7447
# Training epoch 9, loss 0.3562
# Validation epoch 9, loss 3.6916
# Training epoch 10, loss 0.3400
# Validation epoch 10, loss 3.4466
# Training epoch 11, loss 0.3271
# Validation epoch 11, loss 9.8620
# Training epoch 12, loss 0.3167
# Validation epoch 12, loss 1.6674
# Training epoch 13, loss 0.3047
# Validation epoch 13, loss 5.1777
# Training epoch 14, loss 0.2982
# Validation epoch 14, loss 5.8562
# Training epoch 15, loss 0.2916
# Validation epoch 15, loss 10.8034
# Training epoch 16, loss 0.2850
# Validation epoch 16, loss 4.1265
# Training epoch 17, loss 0.2828
# Validation epoch 17, loss 48.8178
# Training epoch 18, loss 0.2788
# Validation epoch 18, loss 13.2074
# Training epoch 19, loss 0.2763
# Validation epoch 19, loss 0.9139
# Training epoch 20, loss 0.2696
# Validation epoch 20, loss 7.0984
# Training epoch 21, loss 0.2700
# Validation epoch 21, loss 0.6517
# Training epoch 22, loss 0.2646
# Validation epoch 22, loss 15.0605
# Training epoch 23, loss 0.2631
# Validation epoch 23, loss 18.1771
# Training epoch 24, loss 0.2607
# Validation epoch 24, loss 13.5057
# Training epoch 25, loss 0.2589
# Validation epoch 25, loss 4.1163
# Training epoch 26, loss 0.2595
# Validation epoch 26, loss 1.0829
# Training epoch 27, loss 0.2605
# Validation epoch 27, loss 40.0120
# Training epoch 28, loss 0.2573
# Validation epoch 28, loss 37.8090
# Training epoch 29, loss 0.2627
# Validation epoch 29, loss 35.4203
# Training epoch 30, loss 0.2548
# Validation epoch 30, loss 7.5138
# Training epoch 31, loss 0.2547
# Validation epoch 31, loss 1.1108
# Training epoch 32, loss 0.2585
# Validation epoch 32, loss 1.9996
# Training epoch 33, loss 0.2585
# Validation epoch 33, loss 1.1086
# Training epoch 34, loss 0.2560
# Validation epoch 34, loss 0.7505
# Training epoch 35, loss 0.2650
# Validation epoch 35, loss 0.6716
# Training epoch 36, loss 0.2648
# Validation epoch 36, loss 0.5195
# Training epoch 37, loss 0.2624
# Validation epoch 37, loss 0.5773
# Training epoch 38, loss 0.2566
# Validation epoch 38, loss 1.2428
# Training epoch 39, loss 0.2515
# Validation epoch 39, loss 1.3601
# Training epoch 40, loss 0.2522
# Validation epoch 40, loss 1.1729
# Training epoch 41, loss 0.2520
# Validation epoch 41, loss 1.0643
# Training epoch 42, loss 0.2540
# Validation epoch 42, loss 0.9938
# Training epoch 43, loss 0.2522
# Validation epoch 43, loss 1.1301
# Training epoch 44, loss 0.2494
# Validation epoch 44, loss 0.7046
# Training epoch 45, loss 0.2476
# Validation epoch 45, loss 1.3374
# Training epoch 46, loss 0.2479
# Validation epoch 46, loss 1.5266
# Training epoch 47, loss 0.2458
# Validation epoch 47, loss 0.7618
# Training epoch 48, loss 0.2424
# Validation epoch 48, loss 1.5956
# Training epoch 49, loss 0.2363
# Validation epoch 49, loss 10.9894
# Training epoch 50, loss 0.2300
# Validation epoch 50, loss 10.0900
# Training epoch 51, loss 0.2305
# Validation epoch 51, loss 1.4566
# Training epoch 52, loss 0.2277
# Validation epoch 52, loss 0.8514
# Training epoch 53, loss 0.2279
# Validation epoch 53, loss 1.0835
# Training epoch 54, loss 0.2283
# Validation epoch 54, loss 1.4236
# Training epoch 55, loss 0.2326
# Validation epoch 55, loss 0.8381
# Training epoch 56, loss 0.2310
# Validation epoch 56, loss 0.8502
# Training epoch 57, loss 0.2377
# Validation epoch 57, loss 0.8932
# Training epoch 58, loss 0.2403
# Validation epoch 58, loss 0.7329
# Training epoch 59, loss 0.2312
# Validation epoch 59, loss 0.7428
# Training epoch 60, loss 0.2328
# Validation epoch 60, loss 1.1054
# Training epoch 61, loss 0.2356
# Validation epoch 61, loss 1.0699
# Training epoch 62, loss 0.2291
# Validation epoch 62, loss 2.6874
# Training epoch 63, loss 0.2325
# Validation epoch 63, loss 4.0608
# Training epoch 64, loss 0.2342
# Validation epoch 64, loss 11.1523
# Training epoch 65, loss 0.2267
# Validation epoch 65, loss 59.1002
# Training epoch 66, loss 0.2238
# Validation epoch 66, loss 67.1159
# Training epoch 67, loss 0.2330
# Validation epoch 67, loss 55.0894
# Training epoch 68, loss 0.2313
# Validation epoch 68, loss 0.8296
# Training epoch 69, loss 0.2301
# Validation epoch 69, loss 0.7391
# Training epoch 70, loss 0.2203
# Validation epoch 70, loss 0.5343
# Training epoch 71, loss 0.2228
# Validation epoch 71, loss 0.7558
# Training epoch 72, loss 0.2194
# Validation epoch 72, loss 2.5948
# Training epoch 73, loss 0.2153
# Validation epoch 73, loss 0.8591
# Training epoch 74, loss 0.2134
# Validation epoch 74, loss 0.7538
# Training epoch 75, loss 0.2190
# Validation epoch 75, loss 1.6766
# Training epoch 76, loss 0.2191
# Validation epoch 76, loss 4.7176
# Training epoch 77, loss 0.2307
# Validation epoch 77, loss 1.6578
# Training epoch 78, loss 0.2542
# Validation epoch 78, loss 0.7594
# Training epoch 79, loss 0.2446
# Validation epoch 79, loss 25.6385
# Training epoch 80, loss 0.2336
# Validation epoch 80, loss 7.3917
# Training epoch 81, loss 0.2341
# Validation epoch 81, loss 1.2364
# Training epoch 82, loss 0.2404
# Validation epoch 82, loss 1.2534
# Training epoch 83, loss 0.2557
# Validation epoch 83, loss 12.0522
# Training epoch 84, loss 0.2464
# Validation epoch 84, loss 3.3697
# Training epoch 85, loss 0.2469
# Validation epoch 85, loss 0.8332
# Training epoch 86, loss 0.2396
# Validation epoch 86, loss 1.1383
# Training epoch 87, loss 0.2505
# Validation epoch 87, loss 0.5983
# Training epoch 88, loss 0.2495
# Validation epoch 88, loss 7.3916
# Training epoch 89, loss 0.2435
# Validation epoch 89, loss 5.2285
# Training epoch 90, loss 0.2230
# Validation epoch 90, loss 11.6194
# Training epoch 91, loss 0.2153
# Validation epoch 91, loss 6.4410
# Training epoch 92, loss 0.2129
# Validation epoch 92, loss 6.2664
# Training epoch 93, loss 0.2093
# Validation epoch 93, loss 16.0078
# Training epoch 94, loss 0.2169
# Validation epoch 94, loss 6.8038
# Training epoch 95, loss 0.2301
# Validation epoch 95, loss 11.1915
# Training epoch 96, loss 0.2387
# Validation epoch 96, loss 1.3734
# Training epoch 97, loss 0.2356
# Validation epoch 97, loss 2.5008
# Training epoch 98, loss 0.2229
# Validation epoch 98, loss 0.9102
# Training epoch 99, loss 0.2150
# Validation epoch 99, loss 1.5538
# Training epoch 100, loss 0.2165
# Validation epoch 100, loss 0.7195
# Training epoch 101, loss 0.2335
# Validation epoch 101, loss 11.2901
# Training epoch 102, loss 0.2429
# Validation epoch 102, loss 4.2658
# Training epoch 103, loss 0.2349
# Validation epoch 103, loss 1.9948
# Training epoch 104, loss 0.2381
# Validation epoch 104, loss 3.5816
# Training epoch 105, loss 0.2302
# Validation epoch 105, loss 3.7578
# Training epoch 106, loss 0.2279
# Validation epoch 106, loss 23.9585
# Training epoch 107, loss 0.2351
# Validation epoch 107, loss 44.6535
# Training epoch 108, loss 0.2428
# Validation epoch 108, loss 2.7663
# Training epoch 109, loss 0.2503
# Validation epoch 109, loss 32.0389
# Training epoch 110, loss 0.2684
# Validation epoch 110, loss 0.4703
# Training epoch 111, loss 0.2605
# Validation epoch 111, loss 0.8102
# Training epoch 112, loss 0.2451
# Validation epoch 112, loss 0.5529
# Training epoch 113, loss 0.2332
# Validation epoch 113, loss 7.9892
# Training epoch 114, loss 0.2181
# Validation epoch 114, loss 3.5762
# Training epoch 115, loss 0.2149
# Validation epoch 115, loss 12.4114
# Training epoch 116, loss 0.2325
# Validation epoch 116, loss 20.8136
# Training epoch 117, loss 0.2246
# Validation epoch 117, loss 36.9885
# Training epoch 118, loss 0.2188
# Validation epoch 118, loss 34.2645
# Training epoch 119, loss 0.2352
# Validation epoch 119, loss 17.3156
# Training epoch 120, loss 0.2288
# Validation epoch 120, loss 2.7638
# Training epoch 121, loss 0.2218
# Validation epoch 121, loss 5.9105
# Training epoch 122, loss 0.2132
# Validation epoch 122, loss 1.1539
# Training epoch 123, loss 0.2155
# Validation epoch 123, loss 0.7773
# Training epoch 124, loss 0.2477
# Validation epoch 124, loss 2.7515
# Training epoch 125, loss 0.2316
# Validation epoch 125, loss 23.4562
# Training epoch 126, loss 0.2509
# Validation epoch 126, loss 31.0789
# Training epoch 127, loss 0.2566
# Validation epoch 127, loss 21.1762
# Training epoch 128, loss 0.2316
# Validation epoch 128, loss 39.9247
# Training epoch 129, loss 0.2118
# Validation epoch 129, loss 11.6401
# Training epoch 130, loss 0.1962
# Validation epoch 130, loss 9.3477
# Training epoch 131, loss 0.1968
# Validation epoch 131, loss 30.7963
# Training epoch 132, loss 0.2054
# Validation epoch 132, loss 42.5591
# Training epoch 133, loss 0.2231
# Validation epoch 133, loss 7.6438
# Training epoch 134, loss 0.2100
# Validation epoch 134, loss 1.4783
# Training epoch 135, loss 0.2021
# Validation epoch 135, loss 12.0240
# Training epoch 136, loss 0.2100
# Validation epoch 136, loss 3.7556
# Training epoch 137, loss 0.2249
# Validation epoch 137, loss 15.0902
# Training epoch 138, loss 0.2184
# Validation epoch 138, loss 41.0195
# Training epoch 139, loss 0.2268
# Validation epoch 139, loss 26.5460
# Training epoch 140, loss 0.2357
# Validation epoch 140, loss 3.7499
# Training epoch 141, loss 0.2552
# Validation epoch 141, loss 0.7568
# Training epoch 142, loss 0.2468
# Validation epoch 142, loss 0.9261
# Training epoch 143, loss 0.2438
# Validation epoch 143, loss 1.0750
# Training epoch 144, loss 0.2249
# Validation epoch 144, loss 3.9713
# Training epoch 145, loss 0.2137
# Validation epoch 145, loss 2.3485
# Training epoch 146, loss 0.2085
# Validation epoch 146, loss 2.5219
# Training epoch 147, loss 0.2174
# Validation epoch 147, loss 1.4560
# Training epoch 148, loss 0.2226
# Validation epoch 148, loss 1.0133
# Training epoch 149, loss 0.2196
# Validation epoch 149, loss 2.1276
# Training epoch 150, loss 0.2130
# Validation epoch 150, loss 3.7194
# Training epoch 151, loss 0.2064
# Validation epoch 151, loss 11.4032
# Training epoch 152, loss 0.2070
# Validation epoch 152, loss 2.4314
# Training epoch 153, loss 0.2191
# Validation epoch 153, loss 0.5787
# Training epoch 154, loss 0.2190
# Validation epoch 154, loss 2.1223
# Training epoch 155, loss 0.2094
# Validation epoch 155, loss 0.8146
# Training epoch 156, loss 0.2169
# Validation epoch 156, loss 2.0524
# Training epoch 157, loss 0.2321
# Validation epoch 157, loss 1.7148
# Training epoch 158, loss 0.2276
# Validation epoch 158, loss 0.6716
# Training epoch 159, loss 0.2099
# Validation epoch 159, loss 0.5223
# Training epoch 160, loss 0.2073
# Validation epoch 160, loss 0.7059
# Training epoch 161, loss 0.2219
# Validation epoch 161, loss 4.5186
# Training epoch 162, loss 0.2138
# Validation epoch 162, loss 15.4645
# Training epoch 163, loss 0.2191
# Validation epoch 163, loss 16.0748
# Training epoch 164, loss 0.2172
# Validation epoch 164, loss 34.3260
# Training epoch 165, loss 0.2149
# Validation epoch 165, loss 13.2989
# Training epoch 166, loss 0.2112
# Validation epoch 166, loss 40.3722
# Training epoch 167, loss 0.2136
# Validation epoch 167, loss 0.9844
# Training epoch 168, loss 0.2085
# Validation epoch 168, loss 0.6953
# Training epoch 169, loss 0.2044
# Validation epoch 169, loss 3.0779
# Training epoch 170, loss 0.2047
# Validation epoch 170, loss 0.8285
# Training epoch 171, loss 0.2154
# Validation epoch 171, loss 2.2831
# Training epoch 172, loss 0.2171
# Validation epoch 172, loss 3.8905
# Training epoch 173, loss 0.1979
# Validation epoch 173, loss 0.7549
# Training epoch 174, loss 0.1926
# Validation epoch 174, loss 13.0507
# Training epoch 175, loss 0.1861
# Validation epoch 175, loss 5.2231
# Training epoch 176, loss 0.1990
# Validation epoch 176, loss 6.0887
# Training epoch 177, loss 0.1932
# Validation epoch 177, loss 4.2043
# Training epoch 178, loss 0.2032
# Validation epoch 178, loss 1.3803
# Training epoch 179, loss 0.2107
# Validation epoch 179, loss 0.6046
# Training epoch 180, loss 0.2071
# Validation epoch 180, loss 6.5723
# Training epoch 181, loss 0.2297
# Validation epoch 181, loss 7.9884
# Training epoch 182, loss 0.2096
# Validation epoch 182, loss 5.1905
# Training epoch 183, loss 0.1992
# Validation epoch 183, loss 10.6483
# Training epoch 184, loss 0.1945
# Validation epoch 184, loss 11.6165
# Training epoch 185, loss 0.2213
# Validation epoch 185, loss 1.1692
# Training epoch 186, loss 0.2047
# Validation epoch 186, loss 4.8762
# Training epoch 187, loss 0.2000
# Validation epoch 187, loss 1.5985
# Training epoch 188, loss 0.2059
# Validation epoch 188, loss 2.8156
# Training epoch 189, loss 0.2091
# Validation epoch 189, loss 1.4446
# Training epoch 190, loss 0.2186
# Validation epoch 190, loss 5.0065
# Training epoch 191, loss 0.2190
# Validation epoch 191, loss 4.4845
# Training epoch 192, loss 0.2133
# Validation epoch 192, loss 0.5692
# Training epoch 193, loss 0.2112
# Validation epoch 193, loss 0.5576
# Training epoch 194, loss 0.2151
# Validation epoch 194, loss 0.6070
# Training epoch 195, loss 0.2192
# Validation epoch 195, loss 0.6095
# Training epoch 196, loss 0.2221
# Validation epoch 196, loss 0.5598
# Training epoch 197, loss 0.2190
# Validation epoch 197, loss 1.5078
# Training epoch 198, loss 0.2084
# Validation epoch 198, loss 0.8778
# Training epoch 199, loss 0.2120
# Validation epoch 199, loss 4.8798
# Training epoch 200, loss 0.2044
# Validation epoch 200, loss 0.4686
# Training epoch 201, loss 0.2073
# Validation epoch 201, loss 0.5762
# Training epoch 202, loss 0.1931
# Validation epoch 202, loss 0.5822
# Training epoch 203, loss 0.2015
# Validation epoch 203, loss 1.6930
# Training epoch 204, loss 0.1891
# Validation epoch 204, loss 2.7298
# Training epoch 205, loss 0.1882
# Validation epoch 205, loss 1.4040
# Training epoch 206, loss 0.1971
# Validation epoch 206, loss 6.5653
# Training epoch 207, loss 0.1946
# Validation epoch 207, loss 9.9535
# Training epoch 208, loss 0.1948
# Validation epoch 208, loss 5.6512
# Training epoch 209, loss 0.1931
# Validation epoch 209, loss 6.9983
# Training epoch 210, loss 0.1933
# Validation epoch 210, loss 1.9438
# Training epoch 211, loss 0.1950
# Validation epoch 211, loss 10.7122
# Training epoch 212, loss 0.1925
# Validation epoch 212, loss 3.5026
# Training epoch 213, loss 0.1943
# Validation epoch 213, loss 2.3479
# Training epoch 214, loss 0.1854
# Validation epoch 214, loss 4.5864
# Training epoch 215, loss 0.1845
# Validation epoch 215, loss 10.5735
# Training epoch 216, loss 0.1837
# Validation epoch 216, loss 8.2891
# Training epoch 217, loss 0.1919
# Validation epoch 217, loss 15.2472
# Training epoch 218, loss 0.1898
# Validation epoch 218, loss 2.1665
# Training epoch 219, loss 0.1971
# Validation epoch 219, loss 6.5272
# Training epoch 220, loss 0.1978
# Validation epoch 220, loss 2.2395
# Training epoch 221, loss 0.1963
# Validation epoch 221, loss 0.6108
# Training epoch 222, loss 0.1862
# Validation epoch 222, loss 5.2620
# Training epoch 223, loss 0.1860
# Validation epoch 223, loss 2.5574
# Training epoch 224, loss 0.1830
# Validation epoch 224, loss 3.6199
# Training epoch 225, loss 0.1814
# Validation epoch 225, loss 3.3190
# Training epoch 226, loss 0.1786
# Validation epoch 226, loss 0.8070
# Training epoch 227, loss 0.1755
# Validation epoch 227, loss 6.6902
# Training epoch 228, loss 0.1720
# Validation epoch 228, loss 2.3411
# Training epoch 229, loss 0.1835
# Validation epoch 229, loss 7.1092
# Training epoch 230, loss 0.1883
# Validation epoch 230, loss 6.1563
# Training epoch 231, loss 0.1942
# Validation epoch 231, loss 0.5330
# Training epoch 232, loss 0.1941
# Validation epoch 232, loss 0.6875
# Training epoch 233, loss 0.1845
# Validation epoch 233, loss 0.6290
# Training epoch 234, loss 0.1801
# Validation epoch 234, loss 0.5487
# Training epoch 235, loss 0.1771
# Validation epoch 235, loss 0.7153
# Training epoch 236, loss 0.1750
# Validation epoch 236, loss 32.6482
# Training epoch 237, loss 0.1771
# Validation epoch 237, loss 8.5583
# Training epoch 238, loss 0.1930
# Validation epoch 238, loss 5.0472
# Training epoch 239, loss 0.1952
# Validation epoch 239, loss 2.5965
# Training epoch 240, loss 0.1974
# Validation epoch 240, loss 1.6614
# Training epoch 241, loss 0.1930
# Validation epoch 241, loss 3.0245
# Training epoch 242, loss 0.1915
# Validation epoch 242, loss 1.2056
# Training epoch 243, loss 0.1820
# Validation epoch 243, loss 0.9780
# Training epoch 244, loss 0.1895
# Validation epoch 244, loss 1.0531
# Training epoch 245, loss 0.1930
# Validation epoch 245, loss 0.8699
# Training epoch 246, loss 0.1896
# Validation epoch 246, loss 2.0384
# Training epoch 247, loss 0.1832
# Validation epoch 247, loss 2.2956
# Training epoch 248, loss 0.1888
# Validation epoch 248, loss 22.6355
# Training epoch 249, loss 0.2034
# Validation epoch 249, loss 2.4793
# Training epoch 250, loss 0.2280
# Validation epoch 250, loss 0.5989
# Training epoch 251, loss 0.2110
# Validation epoch 251, loss 0.5897
# Training epoch 252, loss 0.2096
# Validation epoch 252, loss 0.8627
# Training epoch 253, loss 0.2168
# Validation epoch 253, loss 2.3959
# Training epoch 254, loss 0.2028
# Validation epoch 254, loss 2.3468
# Training epoch 255, loss 0.1928
# Validation epoch 255, loss 3.5504
# Training epoch 256, loss 0.1954
# Validation epoch 256, loss 0.8497
# Training epoch 257, loss 0.2056
# Validation epoch 257, loss 1.0775
# Training epoch 258, loss 0.1972
# Validation epoch 258, loss 1.9752
# Training epoch 259, loss 0.1893
# Validation epoch 259, loss 1.2060
# Training epoch 260, loss 0.1873
# Validation epoch 260, loss 1.5843
# Training epoch 261, loss 0.1951
# Validation epoch 261, loss 0.9660
# Training epoch 262, loss 0.1831
# Validation epoch 262, loss 0.7345
# Training epoch 263, loss 0.1822
# Validation epoch 263, loss 4.0403
# Training epoch 264, loss 0.1823
# Validation epoch 264, loss 5.7347
# Training epoch 265, loss 0.1771
# Validation epoch 265, loss 2.7961
# Training epoch 266, loss 0.1812
# Validation epoch 266, loss 2.9714
# Training epoch 267, loss 0.1892
# Validation epoch 267, loss 3.8391
# Training epoch 268, loss 0.1899
# Validation epoch 268, loss 2.6109
# Training epoch 269, loss 0.1862
# Validation epoch 269, loss 1.3762
# Training epoch 270, loss 0.1842
# Validation epoch 270, loss 0.7312
# Training epoch 271, loss 0.1976
# Validation epoch 271, loss 1.8726
# Training epoch 272, loss 0.1941
# Validation epoch 272, loss 3.0284
# Training epoch 273, loss 0.1958
# Validation epoch 273, loss 3.3581
# Training epoch 274, loss 0.1849
# Validation epoch 274, loss 1.3013
# Training epoch 275, loss 0.1710
# Validation epoch 275, loss 0.7825
# Training epoch 276, loss 0.1773
# Validation epoch 276, loss 0.6741
# Training epoch 277, loss 0.1831
# Validation epoch 277, loss 1.8757
# Training epoch 278, loss 0.1916
# Validation epoch 278, loss 3.8276
# Training epoch 279, loss 0.1868
# Validation epoch 279, loss 0.8637
# Training epoch 280, loss 0.1910
# Validation epoch 280, loss 5.5827
# Training epoch 281, loss 0.1951
# Validation epoch 281, loss 1.1028
# Training epoch 282, loss 0.1876
# Validation epoch 282, loss 4.7075
# Training epoch 283, loss 0.1864
# Validation epoch 283, loss 4.1595
# Training epoch 284, loss 0.1938
# Validation epoch 284, loss 45.4807
# Training epoch 285, loss 0.1870
# Validation epoch 285, loss 56.7439
# Training epoch 286, loss 0.1842
# Validation epoch 286, loss 73.5495
# Training epoch 287, loss 0.1703
# Validation epoch 287, loss 9.9315
# Training epoch 288, loss 0.1693
# Validation epoch 288, loss 297.4261
# Training epoch 289, loss 0.1705
# Validation epoch 289, loss 5.6665
# Training epoch 290, loss 0.1688
# Validation epoch 290, loss 800.8171
# Training epoch 291, loss 0.1584
# Validation epoch 291, loss 91.6431
# Training epoch 292, loss 0.1564
# Validation epoch 292, loss 2.2318
# Training epoch 293, loss 0.1566
# Validation epoch 293, loss 3.6810
# Training epoch 294, loss 0.1769
# Validation epoch 294, loss 1.2186
# Training epoch 295, loss 0.1858
# Validation epoch 295, loss 11.7754
# Training epoch 296, loss 0.1820
# Validation epoch 296, loss 15.7839
# Training epoch 297, loss 0.1737
# Validation epoch 297, loss 7.3387
# Training epoch 298, loss 0.1665
# Validation epoch 298, loss 5.0059
# Training epoch 299, loss 0.1662
# Validation epoch 299, loss 5.5359
# time elapsed: 44238.66894555092

# %%
np.save('chemception_tr_losses', tr_epoch_losses)
np.save('chemception_va_losses', va_epoch_losses)
