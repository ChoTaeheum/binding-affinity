# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import dgl
import pickle
import time

from rdkit.Chem import AllChem as chem
from rdkit.Chem import Descriptors as descriptor
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from dgl import DGLGraph
from dgl import function as fn
from dgl.data.chem import utils
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from functools import partial

# %%
#%% Load dataset and check cuda
dataset = pd.read_csv("datasets/mini-dataset.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = np.array(dataset['SMILES'], dtype=np.str)
kiba = list(dataset['KIBA'])
# del dataset

# %%
#%% protein
f = open('datasets/dictionary/seq_codeinfo.txt', 'rb')
seq_intcode, seq_codelen = pickle.load(f)    # dictionary

seq = []
for i in range(datalen):
    seq.append(seq_intcode[protein[i]])
# del protein

seq_len = []
for i in range(datalen):
    seq_len.append(seq_codelen[protein[i]])

# %%
#%% making ligand graphs and mol_descriptors
graph = []
for s in ligand:
    graph.append(utils.smiles_to_bigraph(s).to(torch.device('cuda:0')))

# %%
#%% dataset zip
revised_dataset = list(zip(seq, seq_len, graph, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**13]
validset = shuffled_dataset[2**13:(2**13) + (2**8)]

# %%
#%% mini_dataset loading
with open("datasets/KIBA/trainset_gcn+lstm.txt", "rb") as fp:
    trainset = pickle.load(fp)

with open("datasets/KIBA/validset_gcn+lstm.txt", "rb") as fp:
    validset = pickle.load(fp)

# %%
#%% Make collate func.
def collate(samples):
    # The input `samples` is a list of pairs [(graph, label),(graph, label)].
    seqs, seq_lens, graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs).to(torch.device('cuda:0'))
    return tc.LongTensor(seqs).cuda(), tc.LongTensor(seq_lens), batched_graph, tc.tensor(labels).cuda()

# %%
#%% GCN module 
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = tc.mean(nodes.mailbox['m'], 1).cuda()
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature.cuda()
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h').cuda()

# %%
#%% learning module
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.emlayer = nn.Embedding(21, 10)
        self.lslayer = nn.LSTM(10, 64, num_layers=1, bidirectional=True, batch_first=True)
        
        self.gclayers = nn.ModuleList([
                        GCN(1, 128, F.relu),
                        GCN(128, 256, F.relu),
                        GCN(256, 128, F.relu)]
                        )
               
        self.regress = nn.Linear(256, 1)    # regression

    def forward(self, seq, seq_len, graph):    # mini-batch, 순서 정확하게 맞음
        sorted_seq_len, sorted_idx = seq_len.sort(0, descending=True)
        seq = seq[sorted_idx]
        
        ls_i = self.emlayer(seq)
        ls_i = pack_padded_sequence(ls_i, sorted_seq_len.tolist(), batch_first=True)
        ls_h = torch.zeros(2, 16, 64).cuda()     # (num_layers * num_directions, batch, hidden_size)
        ls_c = torch.zeros(2, 16, 64).cuda()
        
        ls_o, (ls_h, ls_c) = self.lslayer(ls_i, (ls_h, ls_c))
        ls_o, _ = pad_packed_sequence(ls_o, batch_first=True)

        # 순서 다시 바로잡아주기        
        _, sortedback_idx = sorted_idx.sort(0)
        ls_o = ls_o[sortedback_idx]
        
        # 각 sample의 last output vector 추출
        for_o = []
        for idx, o in enumerate(ls_o):
            for_o.append(o[seq_len[idx]-1, :64].view(1, 64))
        for_o = torch.cat(for_o, 0)
        back_o = ls_o[:, 0, 64:]
        concat_o = tc.cat((for_o, back_o), axis=1)   # batch, hidden*2
 
        gc_h = graph.in_degrees().view(-1, 1).float().cuda()     # 노드의 개수를 feature vector로 사용, ex> torch.Size([7016, 1])
        for conv in self.gclayers:
            gc_h = conv(graph, gc_h).cuda()
        graph.ndata['h'] = gc_h
        gc_h = dgl.mean_nodes(graph, 'h')
        
        cat = tc.cat((concat_o, gc_h),axis=1)
        
        return self.regress(cat)

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 128
hp_d['num_epochs'] = 300

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% learning and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[3] for s in trainset])))
print('va_var:', np.var(np.array([s[3] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                      # epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, seq_len, graph, label) in enumerate(tr_data_loader):  # batch-loop
        prediction = model(seq, seq_len, graph).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, seq_len, graph, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, seq_len, graph).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
    
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.7878362683449712
# va_var: 0.9149456086799042
# total params: 105555
# Training epoch 0, loss 93.5982
# Validation epoch 0, loss 30.2152
# Training epoch 1, loss 4.5296
# Validation epoch 1, loss 1.0934
# Training epoch 2, loss 0.8642
# Validation epoch 2, loss 1.0318
# Training epoch 3, loss 0.8594
# Validation epoch 3, loss 1.0316
# Training epoch 4, loss 0.8579
# Validation epoch 4, loss 1.0311
# Training epoch 5, loss 0.8564
# Validation epoch 5, loss 1.0298
# Training epoch 6, loss 0.8548
# Validation epoch 6, loss 1.0290
# Training epoch 7, loss 0.8531
# Validation epoch 7, loss 1.0291
# Training epoch 8, loss 0.8513
# Validation epoch 8, loss 1.0285
# Training epoch 9, loss 0.8491
# Validation epoch 9, loss 1.0258
# Training epoch 10, loss 0.8462
# Validation epoch 10, loss 1.0228
# Training epoch 11, loss 0.8435
# Validation epoch 11, loss 1.0201
# Training epoch 12, loss 0.8408
# Validation epoch 12, loss 1.0168
# Training epoch 13, loss 0.8383
# Validation epoch 13, loss 1.0138
# Training epoch 14, loss 0.8356
# Validation epoch 14, loss 1.0101
# Training epoch 15, loss 0.8325
# Validation epoch 15, loss 1.0056
# Training epoch 16, loss 0.8290
# Validation epoch 16, loss 0.9982
# Training epoch 17, loss 0.8258
# Validation epoch 17, loss 0.9944
# Training epoch 18, loss 0.8228
# Validation epoch 18, loss 0.9903
# Training epoch 19, loss 0.8202
# Validation epoch 19, loss 0.9864
# Training epoch 20, loss 0.8177
# Validation epoch 20, loss 0.9824
# Training epoch 21, loss 0.8154
# Validation epoch 21, loss 0.9793
# Training epoch 22, loss 0.8133
# Validation epoch 22, loss 0.9761
# Training epoch 23, loss 0.8111
# Validation epoch 23, loss 0.9729
# Training epoch 24, loss 0.8090
# Validation epoch 24, loss 0.9699
# Training epoch 25, loss 0.8072
# Validation epoch 25, loss 0.9672
# Training epoch 26, loss 0.8055
# Validation epoch 26, loss 0.9646
# Training epoch 27, loss 0.8040
# Validation epoch 27, loss 0.9621
# Training epoch 28, loss 0.8028
# Validation epoch 28, loss 0.9601
# Training epoch 29, loss 0.8016
# Validation epoch 29, loss 0.9579
# Training epoch 30, loss 0.8002
# Validation epoch 30, loss 0.9562
# Training epoch 31, loss 0.7990
# Validation epoch 31, loss 0.9545
# Training epoch 32, loss 0.7980
# Validation epoch 32, loss 0.9530
# Training epoch 33, loss 0.7971
# Validation epoch 33, loss 0.9517
# Training epoch 34, loss 0.7962
# Validation epoch 34, loss 0.9504
# Training epoch 35, loss 0.7954
# Validation epoch 35, loss 0.9492
# Training epoch 36, loss 0.7946
# Validation epoch 36, loss 0.9481
# Training epoch 37, loss 0.7939
# Validation epoch 37, loss 0.9471
# Training epoch 38, loss 0.7933
# Validation epoch 38, loss 0.9462
# Training epoch 39, loss 0.7927
# Validation epoch 39, loss 0.9453
# Training epoch 40, loss 0.7922
# Validation epoch 40, loss 0.9444
# Training epoch 41, loss 0.7917
# Validation epoch 41, loss 0.9435
# Training epoch 42, loss 0.7911
# Validation epoch 42, loss 0.9428
# Training epoch 43, loss 0.7908
# Validation epoch 43, loss 0.9421
# Training epoch 44, loss 0.7904
# Validation epoch 44, loss 0.9414
# Training epoch 45, loss 0.7901
# Validation epoch 45, loss 0.9408
# Training epoch 46, loss 0.7898
# Validation epoch 46, loss 0.9402
# Training epoch 47, loss 0.7895
# Validation epoch 47, loss 0.9396
# Training epoch 48, loss 0.7892
# Validation epoch 48, loss 0.9391
# Training epoch 49, loss 0.7890
# Validation epoch 49, loss 0.9386
# Training epoch 50, loss 0.7888
# Validation epoch 50, loss 0.9381
# Training epoch 51, loss 0.7887
# Validation epoch 51, loss 0.9377
# Training epoch 52, loss 0.7885
# Validation epoch 52, loss 0.9373
# Training epoch 53, loss 0.7884
# Validation epoch 53, loss 0.9369
# Training epoch 54, loss 0.7882
# Validation epoch 54, loss 0.9366
# Training epoch 55, loss 0.7881
# Validation epoch 55, loss 0.9364
# Training epoch 56, loss 0.7881
# Validation epoch 56, loss 0.9361
# Training epoch 57, loss 0.7881
# Validation epoch 57, loss 0.9360
# Training epoch 58, loss 0.7881
# Validation epoch 58, loss 0.9358
# Training epoch 59, loss 0.7881
# Validation epoch 59, loss 0.9358
# Training epoch 60, loss 0.7880
# Validation epoch 60, loss 0.9357
# Training epoch 61, loss 0.7881
# Validation epoch 61, loss 0.9356
# Training epoch 62, loss 0.7880
# Validation epoch 62, loss 0.9356
# Training epoch 63, loss 0.7880
# Validation epoch 63, loss 0.9356
# Training epoch 64, loss 0.7881
# Validation epoch 64, loss 0.9354
# Training epoch 65, loss 0.7880
# Validation epoch 65, loss 0.9354
# Training epoch 66, loss 0.7880
# Validation epoch 66, loss 0.9355
# Training epoch 67, loss 0.7881
# Validation epoch 67, loss 0.9354
# Training epoch 68, loss 0.7880
# Validation epoch 68, loss 0.9355
# Training epoch 69, loss 0.7881
# Validation epoch 69, loss 0.9355
# Training epoch 70, loss 0.7880
# Validation epoch 70, loss 0.9355
# Training epoch 71, loss 0.7880
# Validation epoch 71, loss 0.9355
# Training epoch 72, loss 0.7880
# Validation epoch 72, loss 0.9355
# Training epoch 73, loss 0.7880
# Validation epoch 73, loss 0.9355
# Training epoch 74, loss 0.7880
# Validation epoch 74, loss 0.9354
# Training epoch 75, loss 0.7879
# Validation epoch 75, loss 0.9354
# Training epoch 76, loss 0.7879
# Validation epoch 76, loss 0.9354
# Training epoch 77, loss 0.7879
# Validation epoch 77, loss 0.9354
# Training epoch 78, loss 0.7879
# Validation epoch 78, loss 0.9353
# Training epoch 79, loss 0.7878
# Validation epoch 79, loss 0.9353
# Training epoch 80, loss 0.7877
# Validation epoch 80, loss 0.9351
# Training epoch 81, loss 0.7877
# Validation epoch 81, loss 0.9352
# Training epoch 82, loss 0.7877
# Validation epoch 82, loss 0.9351
# Training epoch 83, loss 0.7877
# Validation epoch 83, loss 0.9350
# Training epoch 84, loss 0.7876
# Validation epoch 84, loss 0.9349
# Training epoch 85, loss 0.7876
# Validation epoch 85, loss 0.9349
# Training epoch 86, loss 0.7876
# Validation epoch 86, loss 0.9348
# Training epoch 87, loss 0.7875
# Validation epoch 87, loss 0.9346
# Training epoch 88, loss 0.7875
# Validation epoch 88, loss 0.9346
# Training epoch 89, loss 0.7875
# Validation epoch 89, loss 0.9345
# Training epoch 90, loss 0.7874
# Validation epoch 90, loss 0.9344
# Training epoch 91, loss 0.7874
# Validation epoch 91, loss 0.9343
# Training epoch 92, loss 0.7874
# Validation epoch 92, loss 0.9342
# Training epoch 93, loss 0.7873
# Validation epoch 93, loss 0.9341
# Training epoch 94, loss 0.7873
# Validation epoch 94, loss 0.9340
# Training epoch 95, loss 0.7873
# Validation epoch 95, loss 0.9339
# Training epoch 96, loss 0.7872
# Validation epoch 96, loss 0.9337
# Training epoch 97, loss 0.7872
# Validation epoch 97, loss 0.9337
# Training epoch 98, loss 0.7872
# Validation epoch 98, loss 0.9337
# Training epoch 99, loss 0.7872
# Validation epoch 99, loss 0.9336
# Training epoch 100, loss 0.7872
# Validation epoch 100, loss 0.9335
# Training epoch 101, loss 0.7871
# Validation epoch 101, loss 0.9334
# Training epoch 102, loss 0.7871
# Validation epoch 102, loss 0.9333
# Training epoch 103, loss 0.7871
# Validation epoch 103, loss 0.9333
# Training epoch 104, loss 0.7871
# Validation epoch 104, loss 0.9332
# Training epoch 105, loss 0.7870
# Validation epoch 105, loss 0.9331
# Training epoch 106, loss 0.7870
# Validation epoch 106, loss 0.9330
# Training epoch 107, loss 0.7870
# Validation epoch 107, loss 0.9330
# Training epoch 108, loss 0.7870
# Validation epoch 108, loss 0.9330
# Training epoch 109, loss 0.7870
# Validation epoch 109, loss 0.9329
# Training epoch 110, loss 0.7869
# Validation epoch 110, loss 0.9328
# Training epoch 111, loss 0.7869
# Validation epoch 111, loss 0.9328
# Training epoch 112, loss 0.7869
# Validation epoch 112, loss 0.9327
# Training epoch 113, loss 0.7869
# Validation epoch 113, loss 0.9327
# Training epoch 114, loss 0.7869
# Validation epoch 114, loss 0.9326
# Training epoch 115, loss 0.7869
# Validation epoch 115, loss 0.9326
# Training epoch 116, loss 0.7869
# Validation epoch 116, loss 0.9325
# Training epoch 117, loss 0.7869
# Validation epoch 117, loss 0.9325
# Training epoch 118, loss 0.7869
# Validation epoch 118, loss 0.9325
# Training epoch 119, loss 0.7869
# Validation epoch 119, loss 0.9324
# Training epoch 120, loss 0.7869
# Validation epoch 120, loss 0.9324
# Training epoch 121, loss 0.7869
# Validation epoch 121, loss 0.9324
# Training epoch 122, loss 0.7868
# Validation epoch 122, loss 0.9323
# Training epoch 123, loss 0.7868
# Validation epoch 123, loss 0.9323
# Training epoch 124, loss 0.7868
# Validation epoch 124, loss 0.9321
# Training epoch 125, loss 0.7868
# Validation epoch 125, loss 0.9322
# Training epoch 126, loss 0.7868
# Validation epoch 126, loss 0.9322
# Training epoch 127, loss 0.7868
# Validation epoch 127, loss 0.9322
# Training epoch 128, loss 0.7868
# Validation epoch 128, loss 0.9322
# Training epoch 129, loss 0.7868
# Validation epoch 129, loss 0.9318
# Training epoch 130, loss 0.7867
# Validation epoch 130, loss 0.9321
# Training epoch 131, loss 0.7868
# Validation epoch 131, loss 0.9321
# Training epoch 132, loss 0.7867
# Validation epoch 132, loss 0.9321
# Training epoch 133, loss 0.7868
# Validation epoch 133, loss 0.9321
# Training epoch 134, loss 0.7868
# Validation epoch 134, loss 0.9319
# Training epoch 135, loss 0.7867
# Validation epoch 135, loss 0.9320
# Training epoch 136, loss 0.7868
# Validation epoch 136, loss 0.9320
# Training epoch 137, loss 0.7868
# Validation epoch 137, loss 0.9320
# Training epoch 138, loss 0.7868
# Validation epoch 138, loss 0.9320
# Training epoch 139, loss 0.7868
# Validation epoch 139, loss 0.9320
# Training epoch 140, loss 0.7868
# Validation epoch 140, loss 0.9320
# Training epoch 141, loss 0.7868
# Validation epoch 141, loss 0.9320
# Training epoch 142, loss 0.7868
# Validation epoch 142, loss 0.9320
# Training epoch 143, loss 0.7868
# Validation epoch 143, loss 0.9318
# Training epoch 144, loss 0.7867
# Validation epoch 144, loss 0.9320
# Training epoch 145, loss 0.7868
# Validation epoch 145, loss 0.9320
# Training epoch 146, loss 0.7868
# Validation epoch 146, loss 0.9319
# Training epoch 147, loss 0.7868
# Validation epoch 147, loss 0.9320
# Training epoch 148, loss 0.7868
# Validation epoch 148, loss 0.9320
# Training epoch 149, loss 0.7868
# Validation epoch 149, loss 0.9320
# Training epoch 150, loss 0.7868
# Validation epoch 150, loss 0.9319
# Training epoch 151, loss 0.7868
# Validation epoch 151, loss 0.9320
# Training epoch 152, loss 0.7868
# Validation epoch 152, loss 0.9320
# Training epoch 153, loss 0.7868
# Validation epoch 153, loss 0.9320
# Training epoch 154, loss 0.7868
# Validation epoch 154, loss 0.9316
# Training epoch 155, loss 0.7867
# Validation epoch 155, loss 0.9319
# Training epoch 156, loss 0.7868
# Validation epoch 156, loss 0.9320
# Training epoch 157, loss 0.7868
# Validation epoch 157, loss 0.9320
# Training epoch 158, loss 0.7868
# Validation epoch 158, loss 0.9320
# Training epoch 159, loss 0.7868
# Validation epoch 159, loss 0.9320
# Training epoch 160, loss 0.7868
# Validation epoch 160, loss 0.9320
# Training epoch 161, loss 0.7868
# Validation epoch 161, loss 0.9320
# Training epoch 162, loss 0.7867
# Validation epoch 162, loss 0.9318
# Training epoch 163, loss 0.7868
# Validation epoch 163, loss 0.9320
# Training epoch 164, loss 0.7868
# Validation epoch 164, loss 0.9320
# Training epoch 165, loss 0.7868
# Validation epoch 165, loss 0.9320
# Training epoch 166, loss 0.7868
# Validation epoch 166, loss 0.9319
# Training epoch 167, loss 0.7868
# Validation epoch 167, loss 0.9320
# Training epoch 168, loss 0.7868
# Validation epoch 168, loss 0.9320
# Training epoch 169, loss 0.7865
# Validation epoch 169, loss 0.9308
# Training epoch 170, loss 0.7866
# Validation epoch 170, loss 0.9314
# Training epoch 171, loss 0.7867
# Validation epoch 171, loss 0.9315
# Training epoch 172, loss 0.7867
# Validation epoch 172, loss 0.9316
# Training epoch 173, loss 0.7867
# Validation epoch 173, loss 0.9316
# Training epoch 174, loss 0.7867
# Validation epoch 174, loss 0.9317
# Training epoch 175, loss 0.7867
# Validation epoch 175, loss 0.9318
# Training epoch 176, loss 0.7867
# Validation epoch 176, loss 0.9318
# Training epoch 177, loss 0.7868
# Validation epoch 177, loss 0.9317
# Training epoch 178, loss 0.7866
# Validation epoch 178, loss 0.9309
# Training epoch 179, loss 0.7866
# Validation epoch 179, loss 0.9314
# Training epoch 180, loss 0.7867
# Validation epoch 180, loss 0.9315
# Training epoch 181, loss 0.7867
# Validation epoch 181, loss 0.9316
# Training epoch 182, loss 0.7867
# Validation epoch 182, loss 0.9316
# Training epoch 183, loss 0.7867
# Validation epoch 183, loss 0.9317
# Training epoch 184, loss 0.7867
# Validation epoch 184, loss 0.9317
# Training epoch 185, loss 0.7867
# Validation epoch 185, loss 0.9317
# Training epoch 186, loss 0.7867
# Validation epoch 186, loss 0.9317
# Training epoch 187, loss 0.7867
# Validation epoch 187, loss 0.9317
# Training epoch 188, loss 0.7867
# Validation epoch 188, loss 0.9318
# Training epoch 189, loss 0.7868
# Validation epoch 189, loss 0.9318
# Training epoch 190, loss 0.7868
# Validation epoch 190, loss 0.9318
# Training epoch 191, loss 0.7868
# Validation epoch 191, loss 0.9319
# Training epoch 192, loss 0.7868
# Validation epoch 192, loss 0.9319
# Training epoch 193, loss 0.7868
# Validation epoch 193, loss 0.9311
# Training epoch 194, loss 0.7866
# Validation epoch 194, loss 0.9316
# Training epoch 195, loss 0.7867
# Validation epoch 195, loss 0.9317
# Training epoch 196, loss 0.7868
# Validation epoch 196, loss 0.9316
# Training epoch 197, loss 0.7867
# Validation epoch 197, loss 0.9318
# Training epoch 198, loss 0.7868
# Validation epoch 198, loss 0.9319
# Training epoch 199, loss 0.7868
# Validation epoch 199, loss 0.9319
# Training epoch 200, loss 0.7868
# Validation epoch 200, loss 0.9320
# Training epoch 201, loss 0.7868
# Validation epoch 201, loss 0.9319
# Training epoch 202, loss 0.7868
# Validation epoch 202, loss 0.9320
# Training epoch 203, loss 0.7868
# Validation epoch 203, loss 0.9320
# Training epoch 204, loss 0.7868
# Validation epoch 204, loss 0.9320
# Training epoch 205, loss 0.7869
# Validation epoch 205, loss 0.9319
# Training epoch 206, loss 0.7868
# Validation epoch 206, loss 0.9320
# Training epoch 207, loss 0.7868
# Validation epoch 207, loss 0.9321
# Training epoch 208, loss 0.7868
# Validation epoch 208, loss 0.9319
# Training epoch 209, loss 0.7868
# Validation epoch 209, loss 0.9321
# Training epoch 210, loss 0.7869
# Validation epoch 210, loss 0.9321
# Training epoch 211, loss 0.7869
# Validation epoch 211, loss 0.9322
# Training epoch 212, loss 0.7869
# Validation epoch 212, loss 0.9322
# Training epoch 213, loss 0.7869
# Validation epoch 213, loss 0.9322
# Training epoch 214, loss 0.7869
# Validation epoch 214, loss 0.9322
# Training epoch 215, loss 0.7869
# Validation epoch 215, loss 0.9323
# Training epoch 216, loss 0.7869
# Validation epoch 216, loss 0.9323
# Training epoch 217, loss 0.7869
# Validation epoch 217, loss 0.9323
# Training epoch 218, loss 0.7869
# Validation epoch 218, loss 0.9323
# Training epoch 219, loss 0.7870
# Validation epoch 219, loss 0.9323
# Training epoch 220, loss 0.7870
# Validation epoch 220, loss 0.9322
# Training epoch 221, loss 0.7868
# Validation epoch 221, loss 0.9322
# Training epoch 222, loss 0.7869
# Validation epoch 222, loss 0.9323
# Training epoch 223, loss 0.7870
# Validation epoch 223, loss 0.9322
# Training epoch 224, loss 0.7869
# Validation epoch 224, loss 0.9322
# Training epoch 225, loss 0.7869
# Validation epoch 225, loss 0.9324
# Training epoch 226, loss 0.7869
# Validation epoch 226, loss 0.9322
# Training epoch 227, loss 0.7869
# Validation epoch 227, loss 0.9324
# Training epoch 228, loss 0.7870
# Validation epoch 228, loss 0.9323
# Training epoch 229, loss 0.7870
# Validation epoch 229, loss 0.9324
# Training epoch 230, loss 0.7870
# Validation epoch 230, loss 0.9324
# Training epoch 231, loss 0.7870
# Validation epoch 231, loss 0.9325
# Training epoch 232, loss 0.7870
# Validation epoch 232, loss 0.9325
# Training epoch 233, loss 0.7870
# Validation epoch 233, loss 0.9325
# Training epoch 234, loss 0.7871
# Validation epoch 234, loss 0.9325
# Training epoch 235, loss 0.7870
# Validation epoch 235, loss 0.9325
# Training epoch 236, loss 0.7871
# Validation epoch 236, loss 0.9325
# Training epoch 237, loss 0.7871
# Validation epoch 237, loss 0.9323
# Training epoch 238, loss 0.7871
# Validation epoch 238, loss 0.9325
# Training epoch 239, loss 0.7871
# Validation epoch 239, loss 0.9325
# Training epoch 240, loss 0.7871
# Validation epoch 240, loss 0.9324
# Training epoch 241, loss 0.7871
# Validation epoch 241, loss 0.9325
# Training epoch 242, loss 0.7871
# Validation epoch 242, loss 0.9325
# Training epoch 243, loss 0.7871
# Validation epoch 243, loss 0.9325
# Training epoch 244, loss 0.7871
# Validation epoch 244, loss 0.9325
# Training epoch 245, loss 0.7871
# Validation epoch 245, loss 0.9325
# Training epoch 246, loss 0.7871
# Validation epoch 246, loss 0.9324
# Training epoch 247, loss 0.7871
# Validation epoch 247, loss 0.9325
# Training epoch 248, loss 0.7871
# Validation epoch 248, loss 0.9325
# Training epoch 249, loss 0.7872
# Validation epoch 249, loss 0.9324
# Training epoch 250, loss 0.7871
# Validation epoch 250, loss 0.9325
# Training epoch 251, loss 0.7871
# Validation epoch 251, loss 0.9325
# Training epoch 252, loss 0.7871
# Validation epoch 252, loss 0.9325
# Training epoch 253, loss 0.7872
# Validation epoch 253, loss 0.9325
# Training epoch 254, loss 0.7872
# Validation epoch 254, loss 0.9325
# Training epoch 255, loss 0.7871
# Validation epoch 255, loss 0.9325
# Training epoch 256, loss 0.7872
# Validation epoch 256, loss 0.9325
# Training epoch 257, loss 0.7871
# Validation epoch 257, loss 0.9323
# Training epoch 258, loss 0.7871
# Validation epoch 258, loss 0.9325
# Training epoch 259, loss 0.7872
# Validation epoch 259, loss 0.9325
# Training epoch 260, loss 0.7871
# Validation epoch 260, loss 0.9324
# Training epoch 261, loss 0.7872
# Validation epoch 261, loss 0.9321
# Training epoch 262, loss 0.7871
# Validation epoch 262, loss 0.9325
# Training epoch 263, loss 0.7872
# Validation epoch 263, loss 0.9323
# Training epoch 264, loss 0.7871
# Validation epoch 264, loss 0.9325
# Training epoch 265, loss 0.7871
# Validation epoch 265, loss 0.9324
# Training epoch 266, loss 0.7872
# Validation epoch 266, loss 0.9324
# Training epoch 267, loss 0.7872
# Validation epoch 267, loss 0.9322
# Training epoch 268, loss 0.7872
# Validation epoch 268, loss 0.9324
# Training epoch 269, loss 0.7872
# Validation epoch 269, loss 0.9324
# Training epoch 270, loss 0.7872
# Validation epoch 270, loss 0.9324
# Training epoch 271, loss 0.7872
# Validation epoch 271, loss 0.9321
# Training epoch 272, loss 0.7871
# Validation epoch 272, loss 0.9323
# Training epoch 273, loss 0.7872
# Validation epoch 273, loss 0.9322
# Training epoch 274, loss 0.7871
# Validation epoch 274, loss 0.9322
# Training epoch 275, loss 0.7871
# Validation epoch 275, loss 0.9323
# Training epoch 276, loss 0.7872
# Validation epoch 276, loss 0.9322
# Training epoch 277, loss 0.7872
# Validation epoch 277, loss 0.9323
# Training epoch 278, loss 0.7872
# Validation epoch 278, loss 0.9323
# Training epoch 279, loss 0.7872
# Validation epoch 279, loss 0.9322
# Training epoch 280, loss 0.7872
# Validation epoch 280, loss 0.9322
# Training epoch 281, loss 0.7872
# Validation epoch 281, loss 0.9322
# Training epoch 282, loss 0.7872
# Validation epoch 282, loss 0.9321
# Training epoch 283, loss 0.7871
# Validation epoch 283, loss 0.9321
# Training epoch 284, loss 0.7872
# Validation epoch 284, loss 0.9321
# Training epoch 285, loss 0.7872
# Validation epoch 285, loss 0.9322
# Training epoch 286, loss 0.7872
# Validation epoch 286, loss 0.9322
# Training epoch 287, loss 0.7872
# Validation epoch 287, loss 0.9321
# Training epoch 288, loss 0.7872
# Validation epoch 288, loss 0.9321
# Training epoch 289, loss 0.7872
# Validation epoch 289, loss 0.9321
# Training epoch 290, loss 0.7872
# Validation epoch 290, loss 0.9321
# Training epoch 291, loss 0.7872
# Validation epoch 291, loss 0.9320
# Training epoch 292, loss 0.7872
# Validation epoch 292, loss 0.9320
# Training epoch 293, loss 0.7872
# Validation epoch 293, loss 0.9320
# Training epoch 294, loss 0.7872
# Validation epoch 294, loss 0.9320
# Training epoch 295, loss 0.7872
# Validation epoch 295, loss 0.9320
# Training epoch 296, loss 0.7872
# Validation epoch 296, loss 0.9320
# Training epoch 297, loss 0.7872
# Validation epoch 297, loss 0.9317
# Training epoch 298, loss 0.7871
# Validation epoch 298, loss 0.9320
# Training epoch 299, loss 0.7872
# Validation epoch 299, loss 0.9319
# time elapsed: 5487.8886868953705

# %%
np.save('lstm+gcn_tr_losses', tr_epoch_losses)
np.save('lstm+gcn_va_losses', va_epoch_losses)
