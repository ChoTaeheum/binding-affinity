# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from rdkit.Chem import AllChem as chem
from rdkit.Chem import Draw as draw
from torch.autograd import Variable
from sklearn.utils import shuffle
from sklearn.preprocessing import Normalizer
from matplotlib import pyplot as plt
from matplotlib import image as img
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from functools import partial

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/mini-dataset.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, 'uniprotID']
ligand = dataset.loc[:, 'chemblID']
kiba = list(dataset['KIBA'])
# del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/seq_codeinfo.txt', 'rb')
seq_voc, seq_len = pickle.load(f)
f.close()

sequence = np.zeros(((2**13)+(2**8), 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]
    
sequence_len = np.zeros(((2**13)+(2**8),))
for i, s in enumerate(protein):
    sequence_len[i] = seq_len[s]

# %%
#%% ligand image load
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

image = np.zeros(((2**13)+(2**8), 1, 280, 280))
for i, l in enumerate(ligand):
    im = img.imread("datasets/dictionaries/ligand_img/{}.png".format(l))
    image[i][0] = rgb2gray(im)[10:290, 10:290]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, sequence_len, image, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**13]
validset = shuffled_dataset[2**13:(2**13)+(2**8)]
del shuffled_dataset

# %%
#%% Make collate func.
def collate(samples):
    # The input `samples` is a list of pairs [(graph, label),(graph, label)].
    sequences, sequence_lens, images, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.LongTensor(sequence_lens), tc.tensor(images, dtype=tc.float).cuda(), tc.tensor(labels).cuda()

# %%
#%% network module 선언
class BasicConv2d(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride, padding=0):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_planes, out_planes,
                              kernel_size=kernel_size, stride=stride,
                              padding=padding, bias=False) # verify bias false
        self.bn = nn.BatchNorm2d(out_planes,
                                 eps=0.001, # value found in tensorflow
                                 momentum=0.1, # default pytorch value
                                 affine=True)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        out = self.relu(x)
        return out
    

class InceptionResnet_Ablock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Ablock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(4, 4, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 6, kernel_size=3, stride=1, padding=1),
            BasicConv2d(6, 8, kernel_size=3, stride=1, padding=1)
        )

        self.conv2d = nn.Conv2d(16, 4, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Ablock(nn.Module):
    def __init__(self):
        super(Reduction_Ablock, self).__init__()

        self.branch0 = BasicConv2d(4, 6, kernel_size=3, stride=2)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1),
            BasicConv2d(4, 6, kernel_size=3, stride=2)
        )

        self.branch2 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        return out


class InceptionResnet_Bblock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Bblock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(16, 16, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=(1,7), stride=1, padding=(0,3)),
            BasicConv2d(20, 24, kernel_size=(7,1), stride=1, padding=(3,0))
        )

        self.conv2d = nn.Conv2d(40, 16, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Bblock(nn.Module):
    def __init__(self):
        super(Reduction_Bblock, self).__init__()

        self.branch0 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 24, kernel_size=3, stride=2)
        )

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=3, stride=2)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 18, kernel_size=(3,1), stride=1, padding=(1,0)),
            BasicConv2d(18, 20, kernel_size=3, stride=2)
        )

        self.branch3 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        x3 = self.branch3(x)
        out = torch.cat((x0, x1, x2, x3), 1)
        return out

    
class InceptionResnet_Cblock(nn.Module):
    def __init__(self, scale=1.0, noReLU=False):
        super(InceptionResnet_Cblock, self).__init__()

        self.scale = scale
        self.noReLU = noReLU

        self.branch0 = BasicConv2d(80, 80, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(80, 80, kernel_size=1, stride=1),
            BasicConv2d(80, 93, kernel_size=(1,3), stride=1, padding=(0,1)),
            BasicConv2d(93, 106, kernel_size=(3,1), stride=1, padding=(1,0))
        )

        self.conv2d = nn.Conv2d(186, 80, kernel_size=1, stride=1)
        if not self.noReLU:
            self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        return out


class SqueezeExcitation(nn.Module):
    def __init__(self, channel):
        super(SqueezeExcitation, self).__init__()
        
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channel, channel // 2),
            nn.ReLU(),
            nn.Linear(channel // 2, channel),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        out = self.squeeze(x).view(b, c)
        out = self.excitation(out).view(b, c, 1, 1)
        out = x * out.expand_as(x)
        return out

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.emlayer = nn.Embedding(21, 10)
        self.lslayer = nn.LSTM(10, 64, num_layers=1, bidirectional=True, batch_first=True)
        
        self.imlayers = nn.Sequential(
                        BasicConv2d(1, 4, kernel_size=4, stride=1),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        Reduction_Ablock(), 
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        Reduction_Bblock(),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80)
                        )

        self.avgpool = nn.AvgPool2d(68, count_include_pad=False)
        self.regress = nn.Linear(208, 1)

    def forward(self, seq, seq_len, image):
        sorted_seq_len, sorted_idx = seq_len.sort(0, descending=True)
        seq = seq[sorted_idx]
        
        ls_i = self.emlayer(seq)
        ls_i = pack_padded_sequence(ls_i, sorted_seq_len.tolist(), batch_first=True)
        ls_h = torch.zeros(2, 16, 64).cuda()     # (num_layers * num_directions, batch, hidden_size)
        ls_c = torch.zeros(2, 16, 64).cuda()
        
        ls_o, (ls_h, ls_c) = self.lslayer(ls_i, (ls_h, ls_c))
        ls_o, _ = pad_packed_sequence(ls_o, batch_first=True)

        # 순서 다시 바로잡아주기        
        _, sortedback_idx = sorted_idx.sort(0)
        ls_o = ls_o[sortedback_idx]
        
        # 각 sample의 last output vector 추출
        for_o = []
        for idx, o in enumerate(ls_o):
            for_o.append(o[seq_len[idx]-1, :64].view(1, 64))
        for_o = torch.cat(for_o, 0)
        back_o = ls_o[:, 0, 64:]
        concat_o = tc.cat((for_o, back_o), axis=1)   # batch, hidden*2
        
        im_h = self.imlayers(image)
        im_h = self.avgpool(im_h)
        dim = 1
        for d in im_h.size()[1:]: #16, 4, 4
            dim = dim * d
        im_h = im_h.view(-1, dim)      # batch * 80
        
        cat = tc.cat((concat_o, im_h), axis=1).cuda()
       
        return self.regress(cat).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 16
hp_d['num_epochs'] = 300

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% learning and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[3] for s in trainset])))
print('va_var:', np.var(np.array([s[3] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, seq_len, image, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, seq_len, image).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, seq_len, image, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, seq_len, image).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.7881695087571461
# va_var: 0.9048297662299764
# total params: 336749
# Training epoch 0, loss 20.5127
# Validation epoch 0, loss 0.9358
# Training epoch 1, loss 0.7319
# Validation epoch 1, loss 1.1567
# Training epoch 2, loss 0.6576
# Validation epoch 2, loss 18.2908
# Training epoch 3, loss 0.6105
# Validation epoch 3, loss 2.3776
# Training epoch 4, loss 0.5535
# Validation epoch 4, loss 20.1493
# Training epoch 5, loss 0.4932
# Validation epoch 5, loss 1.6746
# Training epoch 6, loss 0.4465
# Validation epoch 6, loss 14.9868
# Training epoch 7, loss 0.4084
# Validation epoch 7, loss 15.0104
# Training epoch 8, loss 0.3808
# Validation epoch 8, loss 25.2584
# Training epoch 9, loss 0.3601
# Validation epoch 9, loss 24.9943
# Training epoch 10, loss 0.3457
# Validation epoch 10, loss 20.7846
# Training epoch 11, loss 0.3320
# Validation epoch 11, loss 10.1866
# Training epoch 12, loss 0.3206
# Validation epoch 12, loss 3073.2799
# Training epoch 13, loss 0.3128
# Validation epoch 13, loss 15.0069
# Training epoch 14, loss 0.3049
# Validation epoch 14, loss 14.1469
# Training epoch 15, loss 0.2955
# Validation epoch 15, loss 10.6746
# Training epoch 16, loss 0.2933
# Validation epoch 16, loss 2.9563
# Training epoch 17, loss 0.2940
# Validation epoch 17, loss 2.6537
# Training epoch 18, loss 0.2832
# Validation epoch 18, loss 23.3224
# Training epoch 19, loss 0.2764
# Validation epoch 19, loss 21.8553
# Training epoch 20, loss 0.2720
# Validation epoch 20, loss 22.2315
# Training epoch 21, loss 0.2712
# Validation epoch 21, loss 17.9709
# Training epoch 22, loss 0.2698
# Validation epoch 22, loss 10.7933
# Training epoch 23, loss 0.2656
# Validation epoch 23, loss 20.9637
# Training epoch 24, loss 0.2627
# Validation epoch 24, loss 18.7304
# Training epoch 25, loss 0.2625
# Validation epoch 25, loss 2.8722
# Training epoch 26, loss 0.2612
# Validation epoch 26, loss 2.7012
# Training epoch 27, loss 0.2559
# Validation epoch 27, loss 51.1988
# Training epoch 28, loss 0.2567
# Validation epoch 28, loss 1182.2311
# Training epoch 29, loss 0.2600
# Validation epoch 29, loss 61.8664
# Training epoch 30, loss 0.2623
# Validation epoch 30, loss 3945.9950
# Training epoch 31, loss 0.2592
# Validation epoch 31, loss 313.3699
# Training epoch 32, loss 0.2516
# Validation epoch 32, loss 238.2071
# Training epoch 33, loss 0.2481
# Validation epoch 33, loss 2.2959
# Training epoch 34, loss 0.2566
# Validation epoch 34, loss 4.1209
# Training epoch 35, loss 0.2514
# Validation epoch 35, loss 1647.7852
# Training epoch 36, loss 0.2475
# Validation epoch 36, loss 5.0023
# Training epoch 37, loss 0.2427
# Validation epoch 37, loss 0.8237
# Training epoch 38, loss 0.2461
# Validation epoch 38, loss 21.1422
# Training epoch 39, loss 0.2497
# Validation epoch 39, loss 9.5219
# Training epoch 40, loss 0.2460
# Validation epoch 40, loss 11.1957
# Training epoch 41, loss 0.2565
# Validation epoch 41, loss 12.3440
# Training epoch 42, loss 0.2407
# Validation epoch 42, loss 18.7091
# Training epoch 43, loss 0.2392
# Validation epoch 43, loss 19.0960
# Training epoch 44, loss 0.2461
# Validation epoch 44, loss 19.6981
# Training epoch 45, loss 0.2498
# Validation epoch 45, loss 9.2694
# Training epoch 46, loss 0.2462
# Validation epoch 46, loss 18.4547
# Training epoch 47, loss 0.2435
# Validation epoch 47, loss 1.7858
# Training epoch 48, loss 0.2514
# Validation epoch 48, loss 8.0911
# Training epoch 49, loss 0.2483
# Validation epoch 49, loss 9.0479
# Training epoch 50, loss 0.2494
# Validation epoch 50, loss 11.4957
# Training epoch 51, loss 0.2521
# Validation epoch 51, loss 70.7330
# Training epoch 52, loss 0.2415
# Validation epoch 52, loss 16.5040
# Training epoch 53, loss 0.2405
# Validation epoch 53, loss 14.0869
# Training epoch 54, loss 0.2316
# Validation epoch 54, loss 7.4331
# Training epoch 55, loss 0.2397
# Validation epoch 55, loss 14.7949
# Training epoch 56, loss 0.2356
# Validation epoch 56, loss 118.2682
# Training epoch 57, loss 0.2304
# Validation epoch 57, loss 59.6616
# Training epoch 58, loss 0.2261
# Validation epoch 58, loss 11.9796
# Training epoch 59, loss 0.2257
# Validation epoch 59, loss 12.0683
# Training epoch 60, loss 0.2212
# Validation epoch 60, loss 13.3190
# Training epoch 61, loss 0.2251
# Validation epoch 61, loss 5.5033
# Training epoch 62, loss 0.2389
# Validation epoch 62, loss 12.1844
# Training epoch 63, loss 0.2395
# Validation epoch 63, loss 4.7531
# Training epoch 64, loss 0.2383
# Validation epoch 64, loss 9.9461
# Training epoch 65, loss 0.2377
# Validation epoch 65, loss 12.6765
# Training epoch 66, loss 0.2302
# Validation epoch 66, loss 11.3314
# Training epoch 67, loss 0.2248
# Validation epoch 67, loss 10.4599
# Training epoch 68, loss 0.2290
# Validation epoch 68, loss 10.8112
# Training epoch 69, loss 0.2247
# Validation epoch 69, loss 9.5039
# Training epoch 70, loss 0.2211
# Validation epoch 70, loss 5.8745
# Training epoch 71, loss 0.2185
# Validation epoch 71, loss 2.6398
# Training epoch 72, loss 0.2190
# Validation epoch 72, loss 7.0688
# Training epoch 73, loss 0.2285
# Validation epoch 73, loss 2.1947
# Training epoch 74, loss 0.2303
# Validation epoch 74, loss 9.1212
# Training epoch 75, loss 0.2383
# Validation epoch 75, loss 14183.5806
# Training epoch 76, loss 0.2437
# Validation epoch 76, loss 3.3544
# Training epoch 77, loss 0.2425
# Validation epoch 77, loss 21041.0664
# Training epoch 78, loss 0.2393
# Validation epoch 78, loss 342.9960
# Training epoch 79, loss 0.2379
# Validation epoch 79, loss 5190.1141
# Training epoch 80, loss 0.2389
# Validation epoch 80, loss 8.6361
# Training epoch 81, loss 0.2384
# Validation epoch 81, loss 10.5324
# Training epoch 82, loss 0.2455
# Validation epoch 82, loss 10.3458
# Training epoch 83, loss 0.2431
# Validation epoch 83, loss 9.5227
# Training epoch 84, loss 0.2471
# Validation epoch 84, loss 9.7658
# Training epoch 85, loss 0.2462
# Validation epoch 85, loss 9.6732
# Training epoch 86, loss 0.2502
# Validation epoch 86, loss 7.1017
# Training epoch 87, loss 0.2417
# Validation epoch 87, loss 8.0950
# Training epoch 88, loss 0.2296
# Validation epoch 88, loss 6.8920
# Training epoch 89, loss 0.2287
# Validation epoch 89, loss 4.3451
# Training epoch 90, loss 0.2221
# Validation epoch 90, loss 0.8424
# Training epoch 91, loss 0.2207
# Validation epoch 91, loss 2.8643
# Training epoch 92, loss 0.2260
# Validation epoch 92, loss 8.3423
# Training epoch 93, loss 0.2337
# Validation epoch 93, loss 4.8544
# Training epoch 94, loss 0.2394
# Validation epoch 94, loss 5.8235
# Training epoch 95, loss 0.2346
# Validation epoch 95, loss 6.5190
# Training epoch 96, loss 0.2294
# Validation epoch 96, loss 7.2536
# Training epoch 97, loss 0.2287
# Validation epoch 97, loss 6.2322
# Training epoch 98, loss 0.2304
# Validation epoch 98, loss 7.7803
# Training epoch 99, loss 0.2253
# Validation epoch 99, loss 5.5714
# Training epoch 100, loss 0.2224
# Validation epoch 100, loss 5.3299
# Training epoch 101, loss 0.2250
# Validation epoch 101, loss 5.2892
# Training epoch 102, loss 0.2194
# Validation epoch 102, loss 0.6207
# Training epoch 103, loss 0.2183
# Validation epoch 103, loss 8.0562
# Training epoch 104, loss 0.2174
# Validation epoch 104, loss 6.9847
# Training epoch 105, loss 0.2150
# Validation epoch 105, loss 5.2636
# Training epoch 106, loss 0.2115
# Validation epoch 106, loss 5.2820
# Training epoch 107, loss 0.2096
# Validation epoch 107, loss 3.9136
# Training epoch 108, loss 0.2060
# Validation epoch 108, loss 1.3486
# Training epoch 109, loss 0.2050
# Validation epoch 109, loss 3.5747
# Training epoch 110, loss 0.2083
# Validation epoch 110, loss 1.8913
# Training epoch 111, loss 0.2071
# Validation epoch 111, loss 5.9697
# Training epoch 112, loss 0.2015
# Validation epoch 112, loss 4.4071
# Training epoch 113, loss 0.2028
# Validation epoch 113, loss 3.8926
# Training epoch 114, loss 0.2033
# Validation epoch 114, loss 1.9749
# Training epoch 115, loss 0.2073
# Validation epoch 115, loss 2.3190
# Training epoch 116, loss 0.2276
# Validation epoch 116, loss 3.2882
# Training epoch 117, loss 0.2225
# Validation epoch 117, loss 739.2203
# Training epoch 118, loss 0.2188
# Validation epoch 118, loss 3.2347
# Training epoch 119, loss 0.2036
# Validation epoch 119, loss 29.7969
# Training epoch 120, loss 0.2000
# Validation epoch 120, loss 33.0799
# Training epoch 121, loss 0.1931
# Validation epoch 121, loss 5.9584
# Training epoch 122, loss 0.1885
# Validation epoch 122, loss 74.3440
# Training epoch 123, loss 0.1869
# Validation epoch 123, loss 12.4858
# Training epoch 124, loss 0.1871
# Validation epoch 124, loss 53.6423
# Training epoch 125, loss 0.1951
# Validation epoch 125, loss 26.2150
# Training epoch 126, loss 0.2064
# Validation epoch 126, loss 1.6775
# Training epoch 127, loss 0.1995
# Validation epoch 127, loss 1.8132
# Training epoch 128, loss 0.2084
# Validation epoch 128, loss 2.7229
# Training epoch 129, loss 0.2119
# Validation epoch 129, loss 91.6913
# Training epoch 130, loss 0.2109
# Validation epoch 130, loss 6678.9907
# Training epoch 131, loss 0.2150
# Validation epoch 131, loss 977.2655
# Training epoch 132, loss 0.2173
# Validation epoch 132, loss 63729.4697
# Training epoch 133, loss 0.2151
# Validation epoch 133, loss 2422.5505
# Training epoch 134, loss 0.2105
# Validation epoch 134, loss 3.7489
# Training epoch 135, loss 0.2053
# Validation epoch 135, loss 1.9392
# Training epoch 136, loss 0.2013
# Validation epoch 136, loss 3.8222
# Training epoch 137, loss 0.2071
# Validation epoch 137, loss 2.4300
# Training epoch 138, loss 0.2061
# Validation epoch 138, loss 3.1655
# Training epoch 139, loss 0.2062
# Validation epoch 139, loss 3.6976
# Training epoch 140, loss 0.2067
# Validation epoch 140, loss 4.3392
# Training epoch 141, loss 0.1979
# Validation epoch 141, loss 5.4626
# Training epoch 142, loss 0.1921
# Validation epoch 142, loss 4.9954
# Training epoch 143, loss 0.1886
# Validation epoch 143, loss 4.4246
# Training epoch 144, loss 0.1840
# Validation epoch 144, loss 5.0787
# Training epoch 145, loss 0.1854
# Validation epoch 145, loss 5.7922
# Training epoch 146, loss 0.1835
# Validation epoch 146, loss 5.5122
# Training epoch 147, loss 0.1835
# Validation epoch 147, loss 5.7181
# Training epoch 148, loss 0.1863
# Validation epoch 148, loss 5.2413
# Training epoch 149, loss 0.1828
# Validation epoch 149, loss 4.7573
# Training epoch 150, loss 0.1888
# Validation epoch 150, loss 4.7459
# Training epoch 151, loss 0.1946
# Validation epoch 151, loss 4.7357
# Training epoch 152, loss 0.1932
# Validation epoch 152, loss 5.0517
# Training epoch 153, loss 0.2062
# Validation epoch 153, loss 5.4757
# Training epoch 154, loss 0.2056
# Validation epoch 154, loss 3.5885
# Training epoch 155, loss 0.2015
# Validation epoch 155, loss 4.9831
# Training epoch 156, loss 0.2041
# Validation epoch 156, loss 5.3583
# Training epoch 157, loss 0.2001
# Validation epoch 157, loss 1.5446
# Training epoch 158, loss 0.1967
# Validation epoch 158, loss 2.5192
# Training epoch 159, loss 0.1990
# Validation epoch 159, loss 4.7016
# Training epoch 160, loss 0.2013
# Validation epoch 160, loss 8.1477
# Training epoch 161, loss 0.2016
# Validation epoch 161, loss 40.5450
# Training epoch 162, loss 0.2044
# Validation epoch 162, loss 4.6667
# Training epoch 163, loss 0.2072
# Validation epoch 163, loss 5.2899
# Training epoch 164, loss 0.2279
# Validation epoch 164, loss 1.2627
# Training epoch 165, loss 0.2241
# Validation epoch 165, loss 3.9524
# Training epoch 166, loss 0.2121
# Validation epoch 166, loss 3.8302
# Training epoch 167, loss 0.2069
# Validation epoch 167, loss 3.8541
# Training epoch 168, loss 0.2021
# Validation epoch 168, loss 0.7822
# Training epoch 169, loss 0.2036
# Validation epoch 169, loss 4.4612
# Training epoch 170, loss 0.1992
# Validation epoch 170, loss 4.4115
# Training epoch 171, loss 0.2011
# Validation epoch 171, loss 3.8963
# Training epoch 172, loss 0.1969
# Validation epoch 172, loss 3.9493
# Training epoch 173, loss 0.1892
# Validation epoch 173, loss 1.7532
# Training epoch 174, loss 0.1927
# Validation epoch 174, loss 3.8501
# Training epoch 175, loss 0.1902
# Validation epoch 175, loss 3.7075
# Training epoch 176, loss 0.1943
# Validation epoch 176, loss 3.7674
# Training epoch 177, loss 0.1982
# Validation epoch 177, loss 3.9339
# Training epoch 178, loss 0.2009
# Validation epoch 178, loss 3.8038
# Training epoch 179, loss 0.1970
# Validation epoch 179, loss 3.2539
# Training epoch 180, loss 0.1892
# Validation epoch 180, loss 4.4817
# Training epoch 181, loss 0.1933
# Validation epoch 181, loss 0.5832
# Training epoch 182, loss 0.1947
# Validation epoch 182, loss 0.8865
# Training epoch 183, loss 0.1875
# Validation epoch 183, loss 4.8879
# Training epoch 184, loss 0.1913
# Validation epoch 184, loss 4.8287
# Training epoch 185, loss 0.1878
# Validation epoch 185, loss 0.7777
# Training epoch 186, loss 0.1866
# Validation epoch 186, loss 4.7428
# Training epoch 187, loss 0.2012
# Validation epoch 187, loss 0.5871
# Training epoch 188, loss 0.2010
# Validation epoch 188, loss 4.0425
# Training epoch 189, loss 0.1970
# Validation epoch 189, loss 4.6067
# Training epoch 190, loss 0.1922
# Validation epoch 190, loss 0.5629
# Training epoch 191, loss 0.1906
# Validation epoch 191, loss 2.7538
# Training epoch 192, loss 0.1932
# Validation epoch 192, loss 4.8600
# Training epoch 193, loss 0.1931
# Validation epoch 193, loss 4.5458
# Training epoch 194, loss 0.1982
# Validation epoch 194, loss 3.8766
# Training epoch 195, loss 0.2008
# Validation epoch 195, loss 4.2294
# Training epoch 196, loss 0.1960
# Validation epoch 196, loss 4.0542
# Training epoch 197, loss 0.1866
# Validation epoch 197, loss 4.0237
# Training epoch 198, loss 0.1834
# Validation epoch 198, loss 4.1667
# Training epoch 199, loss 0.1914
# Validation epoch 199, loss 4.3429
# Training epoch 200, loss 0.1889
# Validation epoch 200, loss 1.9898
# Training epoch 201, loss 0.1902
# Validation epoch 201, loss 3.8916
# Training epoch 202, loss 0.1860
# Validation epoch 202, loss 0.7621
# Training epoch 203, loss 0.1879
# Validation epoch 203, loss 3.2448
# Training epoch 204, loss 0.1797
# Validation epoch 204, loss 10.6789
# Training epoch 205, loss 0.1830
# Validation epoch 205, loss 4.1449
# Training epoch 206, loss 0.1831
# Validation epoch 206, loss 1.4285
# Training epoch 207, loss 0.1838
# Validation epoch 207, loss 3.8282
# Training epoch 208, loss 0.1856
# Validation epoch 208, loss 4.1116
# Training epoch 209, loss 0.1827
# Validation epoch 209, loss 0.9087
# Training epoch 210, loss 0.1822
# Validation epoch 210, loss 3.8922
# Training epoch 211, loss 0.1866
# Validation epoch 211, loss 1.5342
# Training epoch 212, loss 0.1858
# Validation epoch 212, loss 4.4477
# Training epoch 213, loss 0.1862
# Validation epoch 213, loss 37.0282
# Training epoch 214, loss 0.1897
# Validation epoch 214, loss 2.9371
# Training epoch 215, loss 0.1870
# Validation epoch 215, loss 3.9257
# Training epoch 216, loss 0.2001
# Validation epoch 216, loss 24.3022
# Training epoch 217, loss 0.2025
# Validation epoch 217, loss 3.1235
# Training epoch 218, loss 0.1872
# Validation epoch 218, loss 4.4098
# Training epoch 219, loss 0.1914
# Validation epoch 219, loss 4.7694
# Training epoch 220, loss 0.1908
# Validation epoch 220, loss 10.9496
# Training epoch 221, loss 0.1999
# Validation epoch 221, loss 4.6422
# Training epoch 222, loss 0.2011
# Validation epoch 222, loss 3.3849
# Training epoch 223, loss 0.2059
# Validation epoch 223, loss 4.3315
# Training epoch 224, loss 0.2108
# Validation epoch 224, loss 3.7701
# Training epoch 225, loss 0.1961
# Validation epoch 225, loss 4.7130
# Training epoch 226, loss 0.1944
# Validation epoch 226, loss 3.0172
# Training epoch 227, loss 0.1897
# Validation epoch 227, loss 3.4383
# Training epoch 228, loss 0.2013
# Validation epoch 228, loss 4.8181
# Training epoch 229, loss 0.1946
# Validation epoch 229, loss 4.5656
# Training epoch 230, loss 0.1953
# Validation epoch 230, loss 4.4164
# Training epoch 231, loss 0.1956
# Validation epoch 231, loss 3.7089
# Training epoch 232, loss 0.1873
# Validation epoch 232, loss 4.1918
# Training epoch 233, loss 0.1886
# Validation epoch 233, loss 4.3570
# Training epoch 234, loss 0.1806
# Validation epoch 234, loss 4.3744
# Training epoch 235, loss 0.1777
# Validation epoch 235, loss 1.7620
# Training epoch 236, loss 0.1773
# Validation epoch 236, loss 4.2266
# Training epoch 237, loss 0.1740
# Validation epoch 237, loss 4.0374
# Training epoch 238, loss 0.1844
# Validation epoch 238, loss 3.7630
# Training epoch 239, loss 0.1833
# Validation epoch 239, loss 0.7610
# Training epoch 240, loss 0.1726
# Validation epoch 240, loss 0.8307
# Training epoch 241, loss 0.1725
# Validation epoch 241, loss 1.2695
# Training epoch 242, loss 0.1751
# Validation epoch 242, loss 0.7184
# Training epoch 243, loss 0.1750
# Validation epoch 243, loss 2.5748
# Training epoch 244, loss 0.1674
# Validation epoch 244, loss 4.3710
# Training epoch 245, loss 0.1624
# Validation epoch 245, loss 7.1667
# Training epoch 246, loss 0.1613
# Validation epoch 246, loss 2.6219
# Training epoch 247, loss 0.1582
# Validation epoch 247, loss 1.1439
# Training epoch 248, loss 0.1635
# Validation epoch 248, loss 1.5454
# Training epoch 249, loss 0.1628
# Validation epoch 249, loss 4.2385
# Training epoch 250, loss 0.1575
# Validation epoch 250, loss 1.3465
# Training epoch 251, loss 0.1647
# Validation epoch 251, loss 5.3815
# Training epoch 252, loss 0.1702
# Validation epoch 252, loss 4.5094
# Training epoch 253, loss 0.1606
# Validation epoch 253, loss 1.1437
# Training epoch 254, loss 0.1588
# Validation epoch 254, loss 2.1495
# Training epoch 255, loss 0.1602
# Validation epoch 255, loss 0.9572
# Training epoch 256, loss 0.1529
# Validation epoch 256, loss 2.1719
# Training epoch 257, loss 0.1612
# Validation epoch 257, loss 179.7643
# Training epoch 258, loss 0.1622
# Validation epoch 258, loss 209.8333
# Training epoch 259, loss 0.1624
# Validation epoch 259, loss 197.5218
# Training epoch 260, loss 0.1673
# Validation epoch 260, loss 106.1998
# Training epoch 261, loss 0.1614
# Validation epoch 261, loss 346.1191
# Training epoch 262, loss 0.1608
# Validation epoch 262, loss 37.7326
# Training epoch 263, loss 0.1535
# Validation epoch 263, loss 6.4393
# Training epoch 264, loss 0.1683
# Validation epoch 264, loss 95.4993
# Training epoch 265, loss 0.1706
# Validation epoch 265, loss 13.0358
# Training epoch 266, loss 0.1786
# Validation epoch 266, loss 84.4597
# Training epoch 267, loss 0.1799
# Validation epoch 267, loss 60.7347
# Training epoch 268, loss 0.1820
# Validation epoch 268, loss 15.5039
# Training epoch 269, loss 0.1771
# Validation epoch 269, loss 31.4053
# Training epoch 270, loss 0.1808
# Validation epoch 270, loss 93.7154
# Training epoch 271, loss 0.1775
# Validation epoch 271, loss 4.7806
# Training epoch 272, loss 0.1691
# Validation epoch 272, loss 4.1971
# Training epoch 273, loss 0.1703
# Validation epoch 273, loss 30.9047
# Training epoch 274, loss 0.1682
# Validation epoch 274, loss 4.7173
# Training epoch 275, loss 0.1676
# Validation epoch 275, loss 4.4757
# Training epoch 276, loss 0.1706
# Validation epoch 276, loss 4.6810
# Training epoch 277, loss 0.1730
# Validation epoch 277, loss 4.9536
# Training epoch 278, loss 0.1641
# Validation epoch 278, loss 4.4598
# Training epoch 279, loss 0.1713
# Validation epoch 279, loss 4.8225
# Training epoch 280, loss 0.1779
# Validation epoch 280, loss 4.8505
# Training epoch 281, loss 0.1744
# Validation epoch 281, loss 4.4055
# Training epoch 282, loss 0.1693
# Validation epoch 282, loss 3.3954
# Training epoch 283, loss 0.1662
# Validation epoch 283, loss 3.2168
# Training epoch 284, loss 0.1640
# Validation epoch 284, loss 3.6483
# Training epoch 285, loss 0.1615
# Validation epoch 285, loss 3.7898
# Training epoch 286, loss 0.1662
# Validation epoch 286, loss 4.6104
# Training epoch 287, loss 0.1726
# Validation epoch 287, loss 4.5280
# Training epoch 288, loss 0.1776
# Validation epoch 288, loss 4.0932
# Training epoch 289, loss 0.1768
# Validation epoch 289, loss 4.8528
# Training epoch 290, loss 0.1778
# Validation epoch 290, loss 4.9355
# Training epoch 291, loss 0.1796
# Validation epoch 291, loss 5.2668
# Training epoch 292, loss 0.1772
# Validation epoch 292, loss 4.8146
# Training epoch 293, loss 0.1831
# Validation epoch 293, loss 4.6273
# Training epoch 294, loss 0.1847
# Validation epoch 294, loss 4.3114
# Training epoch 295, loss 0.1827
# Validation epoch 295, loss 4.2785
# Training epoch 296, loss 0.1876
# Validation epoch 296, loss 4.1600
# Training epoch 297, loss 0.1889
# Validation epoch 297, loss 3.8298
# Training epoch 298, loss 0.1880
# Validation epoch 298, loss 3.0226
# Training epoch 299, loss 0.1808
# Validation epoch 299, loss 2.1862
# time elapsed: 55692.429340839386

# %%
np.save('lstm+chemception_tr_losses_v2', tr_epoch_losses)
np.save('lstm+chemception_va_losses_v2', va_epoch_losses)
