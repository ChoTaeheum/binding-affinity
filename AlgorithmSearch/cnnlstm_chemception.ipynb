# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from rdkit.Chem import AllChem as chem
from rdkit.Chem import Draw as draw
from torch.autograd import Variable
from sklearn.utils import shuffle
from sklearn.preprocessing import Normalizer
from matplotlib import pyplot as plt
from matplotlib import image as img
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:(2**16)+(2**13)-1, "uniprotID"]    # 5
ligand = dataset.loc[:(2**16)+(2**13)-1, "chemblID"]
kiba = list(dataset.loc[:(2**16)+(2**13)-1, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros(((2**16)+(2**13), 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :2000]

# %%
#%% ligand image load
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

image = np.zeros(((2**16)+(2**13), 1, 280, 280))
for i, l in enumerate(ligand):
    im = img.imread("datasets/dictionaries/ligand_img/{}.png".format(l))
    image[i][0] = rgb2gray(im)[10:290, 10:290]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, image, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**16]
validset = shuffled_dataset[2**16:(2**16)+(2**13)]
del shuffled_dataset

# %%
#%% Make collate func.
def collate(samples):
    sequences, images, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.tensor(images, dtype=tc.float).cuda(), tc.tensor(labels).cuda()

# %%
#%% network module 선언
class BasicConv2d(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride, padding=0):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_planes, out_planes,
                              kernel_size=kernel_size, stride=stride,
                              padding=padding, bias=False) # verify bias false
        self.bn = nn.BatchNorm2d(out_planes,
                                 eps=0.001, # value found in tensorflow
                                 momentum=0.1, # default pytorch value
                                 affine=True)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        out = self.relu(x)
        return out
    

class InceptionResnet_Ablock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Ablock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(4, 4, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 6, kernel_size=3, stride=1, padding=1),
            BasicConv2d(6, 8, kernel_size=3, stride=1, padding=1)
        )

        self.conv2d = nn.Conv2d(16, 4, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Ablock(nn.Module):
    def __init__(self):
        super(Reduction_Ablock, self).__init__()

        self.branch0 = BasicConv2d(4, 6, kernel_size=3, stride=2)

        self.branch1 = nn.Sequential(
            BasicConv2d(4, 4, kernel_size=1, stride=1),
            BasicConv2d(4, 4, kernel_size=3, stride=1, padding=1),
            BasicConv2d(4, 6, kernel_size=3, stride=2)
        )

        self.branch2 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        out = torch.cat((x0, x1, x2), 1)
        return out


class InceptionResnet_Bblock(nn.Module):
    def __init__(self, scale=1.0):
        super(InceptionResnet_Bblock, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(16, 16, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=(1,7), stride=1, padding=(0,3)),
            BasicConv2d(20, 24, kernel_size=(7,1), stride=1, padding=(3,0))
        )

        self.conv2d = nn.Conv2d(40, 16, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        out = self.relu(out)
        return out
    

class Reduction_Bblock(nn.Module):
    def __init__(self):
        super(Reduction_Bblock, self).__init__()

        self.branch0 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 24, kernel_size=3, stride=2)
        )

        self.branch1 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 20, kernel_size=3, stride=2)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(16, 16, kernel_size=1, stride=1),
            BasicConv2d(16, 18, kernel_size=(3,1), stride=1, padding=(1,0)),
            BasicConv2d(18, 20, kernel_size=3, stride=2)
        )

        self.branch3 = nn.MaxPool2d(3, stride=2)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        x3 = self.branch3(x)
        out = torch.cat((x0, x1, x2, x3), 1)
        return out

    
class InceptionResnet_Cblock(nn.Module):
    def __init__(self, scale=1.0, noReLU=False):
        super(InceptionResnet_Cblock, self).__init__()

        self.scale = scale
        self.noReLU = noReLU

        self.branch0 = BasicConv2d(80, 80, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(80, 80, kernel_size=1, stride=1),
            BasicConv2d(80, 93, kernel_size=(1,3), stride=1, padding=(0,1)),
            BasicConv2d(93, 106, kernel_size=(3,1), stride=1, padding=(1,0))
        )

        self.conv2d = nn.Conv2d(186, 80, kernel_size=1, stride=1)
        if not self.noReLU:
            self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        out = torch.cat((x0, x1), 1)
        out = self.conv2d(out)
        out = out * self.scale + x
        return out


class SqueezeExcitation(nn.Module):
    def __init__(self, channel):
        super(SqueezeExcitation, self).__init__()
        
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channel, channel // 2),
            nn.ReLU(),
            nn.Linear(channel // 2, channel),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        out = self.squeeze(x).view(b, c)
        out = self.excitation(out).view(b, c, 1, 1)
        out = x * out.expand_as(x)
        return out

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.emlayer = nn.Embedding(21, 10)
        
        self.cv2dlayer = nn.Sequential(
                        nn.Conv2d(1, 8, kernel_size = (64, 10), stride=(2, 1)),
                        nn.BatchNorm2d(num_features = 8),
                        nn.ReLU(),
                        nn.MaxPool2d(kernel_size = (2, 1))
                        )
        
        self.cv1dlayers = nn.Sequential(
                        nn.Conv1d(8, 16, kernel_size = 3),
                        nn.BatchNorm1d(num_features = 16),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 2),
                        nn.Conv1d(16, 24, kernel_size = 2),
                        nn.BatchNorm1d(num_features = 24),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 2)
                        )
        
        self.lslayer = nn.LSTM(24, 64, num_layers=1, bidirectional=True, batch_first=True)
        
        self.imlayers = nn.Sequential(
                        BasicConv2d(1, 4, kernel_size=4, stride=1),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        InceptionResnet_Ablock(scale=0.17),
                        SqueezeExcitation(channel=4),
                        Reduction_Ablock(), 
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        InceptionResnet_Bblock(scale=0.10),
                        SqueezeExcitation(channel=16),
                        Reduction_Bblock(),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80),
                        InceptionResnet_Cblock(scale=0.20),
                        SqueezeExcitation(channel=80)
                        )

        self.avgpool = nn.AvgPool2d(68, count_include_pad=False)
        self.regress = nn.Linear(208, 1)

    def forward(self, seq, image):
        cv_i = self.emlayer(seq)
        
        cv2_i = cv_i.unsqueeze(1)
        cv2_o = self.cv2dlayer(cv2_i)
        cv1_i = cv2_o.squeeze()
        cv1_o = self.cv1dlayers(cv1_i)
        
        ls_i = cv1_o.permute(0, 2, 1)
        
        ls_h = torch.zeros(2, 16, 64).cuda()     # (num_layers * num_directions, batch, hidden_size)
        ls_c = torch.zeros(2, 16, 64).cuda()
        
        ls_o, (ls_h, ls_c) = self.lslayer(ls_i, (ls_h, ls_c))

        for_o = ls_o[:, -1, :64]
        back_o = ls_o[:, 0, 64:]
        
        concat_o = tc.cat((for_o, back_o), axis=1)   # batch, hidden*2
        
        im_h = self.imlayers(image)
        im_h = self.avgpool(im_h)
        dim = 1
        for d in im_h.size()[1:]: #16, 4, 4
            dim = dim * d
        im_h = im_h.view(-1, dim)      # batch * 80
        
        cat = tc.cat((concat_o, im_h), axis=1).cuda()
       
        return self.regress(cat).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 16
hp_d['num_epochs'] = 600

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% learning and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, image, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, image).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, image, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, image).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.6633529516883323
# va_var: 0.6481306950598476
# total params: 350333
# Training epoch 0, loss 2.9705
# Validation epoch 0, loss 0.5337
# Training epoch 1, loss 0.5005
# Validation epoch 1, loss 0.5866
# Training epoch 2, loss 0.4458
# Validation epoch 2, loss 9.8246
# Training epoch 3, loss 0.4224
# Validation epoch 3, loss 12.1922
# Training epoch 4, loss 0.4097
# Validation epoch 4, loss 9.6574
# Training epoch 5, loss 0.4016
# Validation epoch 5, loss 0.5330
# Training epoch 6, loss 0.3957
# Validation epoch 6, loss 2.1923
# Training epoch 7, loss 0.3910
# Validation epoch 7, loss 0.4249
# Training epoch 8, loss 0.3873
# Validation epoch 8, loss 4.2104
# Training epoch 9, loss 0.3838
# Validation epoch 9, loss 1.1579
# Training epoch 10, loss 0.3807
# Validation epoch 10, loss 5.8524
# Training epoch 11, loss 0.3790
# Validation epoch 11, loss 0.7560
# Training epoch 12, loss 0.3757
# Validation epoch 12, loss 0.7645
# Training epoch 13, loss 0.3742
# Validation epoch 13, loss 5.6300
# Training epoch 14, loss 0.3724
# Validation epoch 14, loss 0.5171
# Training epoch 15, loss 0.3710
# Validation epoch 15, loss 4.8199
# Training epoch 16, loss 0.3703
# Validation epoch 16, loss 4.6937
# Training epoch 17, loss 0.3685
# Validation epoch 17, loss 4.1871
# Training epoch 18, loss 0.3673
# Validation epoch 18, loss 4.2693
# Training epoch 19, loss 0.3663
# Validation epoch 19, loss 4.0582
# Training epoch 20, loss 0.3661
# Validation epoch 20, loss 1.3829
# Training epoch 21, loss 0.3647
# Validation epoch 21, loss 3.9783
# Training epoch 22, loss 0.3639
# Validation epoch 22, loss 3.7734
# Training epoch 23, loss 0.3633
# Validation epoch 23, loss 3.6343
# Training epoch 24, loss 0.3617
# Validation epoch 24, loss 3.3064
# Training epoch 25, loss 0.3611
# Validation epoch 25, loss 3.3077
# Training epoch 26, loss 0.3605
# Validation epoch 26, loss 3.1929
# Training epoch 27, loss 0.3597
# Validation epoch 27, loss 3.1887
# Training epoch 28, loss 0.3584
# Validation epoch 28, loss 3.1543
# Training epoch 29, loss 0.3581
# Validation epoch 29, loss 2.9232
# Training epoch 30, loss 0.3570
# Validation epoch 30, loss 1.1907
# Training epoch 31, loss 0.3566
# Validation epoch 31, loss 2.0719
# Training epoch 32, loss 0.3556
# Validation epoch 32, loss 0.6721
# Training epoch 33, loss 0.3549
# Validation epoch 33, loss 2.2246
# Training epoch 34, loss 0.3539
# Validation epoch 34, loss 2.0123
# Training epoch 35, loss 0.3541
# Validation epoch 35, loss 2.7683
# Training epoch 36, loss 0.3526
# Validation epoch 36, loss 2.5770
# Training epoch 37, loss 0.3523
# Validation epoch 37, loss 2.0117
# Training epoch 38, loss 0.3517
# Validation epoch 38, loss 1.5950
# Training epoch 39, loss 0.3521
# Validation epoch 39, loss 0.4191
# Training epoch 40, loss 0.3506
# Validation epoch 40, loss 2.5302
# Training epoch 41, loss 0.3503
# Validation epoch 41, loss 2.2948
# Training epoch 42, loss 0.3498
# Validation epoch 42, loss 2.7006
# Training epoch 43, loss 0.3504
# Validation epoch 43, loss 2.4168
# Training epoch 44, loss 0.3505
# Validation epoch 44, loss 2.3495
# Training epoch 45, loss 0.3492
# Validation epoch 45, loss 2.2617
# Training epoch 46, loss 0.3489
# Validation epoch 46, loss 2.3078
# Training epoch 47, loss 0.3476
# Validation epoch 47, loss 2.6214
# Training epoch 48, loss 0.3474
# Validation epoch 48, loss 2.5259
# Training epoch 49, loss 0.3478
# Validation epoch 49, loss 2.3735
# Training epoch 50, loss 0.3481
# Validation epoch 50, loss 2.1886
# Training epoch 51, loss 0.3475
# Validation epoch 51, loss 2.3103
# Training epoch 52, loss 0.3474
# Validation epoch 52, loss 2.2053
# Training epoch 53, loss 0.3460
# Validation epoch 53, loss 2.2752
# Training epoch 54, loss 0.3466
# Validation epoch 54, loss 2.4200
# Training epoch 55, loss 0.3463
# Validation epoch 55, loss 2.4031
# Training epoch 56, loss 0.3463
# Validation epoch 56, loss 2.1089
# Training epoch 57, loss 0.3456
# Validation epoch 57, loss 2.5317
# Training epoch 58, loss 0.3455
# Validation epoch 58, loss 2.1865
# Training epoch 59, loss 0.3442
# Validation epoch 59, loss 2.4019
# Training epoch 60, loss 0.3442
# Validation epoch 60, loss 0.4267
# Training epoch 61, loss 0.3436
# Validation epoch 61, loss 2.3434
# Training epoch 62, loss 0.3431
# Validation epoch 62, loss 0.5094
# Training epoch 63, loss 0.3435
# Validation epoch 63, loss 1.4057
# Training epoch 64, loss 0.3445
# Validation epoch 64, loss 0.4237
# Training epoch 65, loss 0.3430
# Validation epoch 65, loss 0.4012
# Training epoch 66, loss 0.3428
# Validation epoch 66, loss 1.1620
# Training epoch 67, loss 0.3417
# Validation epoch 67, loss 0.5148
# Training epoch 68, loss 0.3418
# Validation epoch 68, loss 0.5248
# Training epoch 69, loss 0.3425
# Validation epoch 69, loss 0.6309
# Training epoch 70, loss 0.3423
# Validation epoch 70, loss 1.8913
# Training epoch 71, loss 0.3405
# Validation epoch 71, loss 0.8303
# Training epoch 72, loss 0.3410
# Validation epoch 72, loss 0.4168
# Training epoch 73, loss 0.3409
# Validation epoch 73, loss 1.1676
# Training epoch 74, loss 0.3407
# Validation epoch 74, loss 0.9207
# Training epoch 75, loss 0.3411
# Validation epoch 75, loss 1.7342
# Training epoch 76, loss 0.3419
# Validation epoch 76, loss 1.6408
# Training epoch 77, loss 0.3409
# Validation epoch 77, loss 2.7237
# Training epoch 78, loss 0.3409
# Validation epoch 78, loss 2.3200
# Training epoch 79, loss 0.3402
# Validation epoch 79, loss 0.4807
# Training epoch 80, loss 0.3391
# Validation epoch 80, loss 1.4541
# Training epoch 81, loss 0.3389
# Validation epoch 81, loss 1.9363
# Training epoch 82, loss 0.3396
# Validation epoch 82, loss 1.7933
# Training epoch 83, loss 0.3396
# Validation epoch 83, loss 2.3477
# Training epoch 84, loss 0.3404
# Validation epoch 84, loss 2.3426
# Training epoch 85, loss 0.3395
# Validation epoch 85, loss 2.3126
# Training epoch 86, loss 0.3387
# Validation epoch 86, loss 2.2520
# Training epoch 87, loss 0.3382
# Validation epoch 87, loss 2.3486
# Training epoch 88, loss 0.3375
# Validation epoch 88, loss 2.2868
# Training epoch 89, loss 0.3406
# Validation epoch 89, loss 2.2463
# Training epoch 90, loss 0.3382
# Validation epoch 90, loss 2.2883
# Training epoch 91, loss 0.3386
# Validation epoch 91, loss 2.0454
# Training epoch 92, loss 0.3388
# Validation epoch 92, loss 2.5184
# Training epoch 93, loss 0.3394
# Validation epoch 93, loss 1.3131
# Training epoch 94, loss 0.3387
# Validation epoch 94, loss 1.3092
# Training epoch 95, loss 0.3395
# Validation epoch 95, loss 1.9983
# Training epoch 96, loss 0.3377
# Validation epoch 96, loss 1.4049
# Training epoch 97, loss 0.3381
# Validation epoch 97, loss 1.3251
# Training epoch 98, loss 0.3379
# Validation epoch 98, loss 1.7617
# Training epoch 99, loss 0.3385
# Validation epoch 99, loss 0.4002
# Training epoch 100, loss 0.3377
# Validation epoch 100, loss 2.0161
# Training epoch 101, loss 0.3373
# Validation epoch 101, loss 0.4319
# Training epoch 102, loss 0.3370
# Validation epoch 102, loss 0.8148
# Training epoch 103, loss 0.3371
# Validation epoch 103, loss 0.3936
# Training epoch 104, loss 0.3368
# Validation epoch 104, loss 1.0737
# Training epoch 105, loss 0.3377
# Validation epoch 105, loss 0.5084
# Training epoch 106, loss 0.3375
# Validation epoch 106, loss 1.7079
# Training epoch 107, loss 0.3371
# Validation epoch 107, loss 0.9819
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f3f93f947d93> in <module>
#      23     tr_epoch_loss = 0
#      24
# ---> 25     for iter, (seq, image, label) in enumerate(tr_data_loader):  #!! batch-loop
#      26         prediction = model(seq, image).view(-1).cuda()
#      27         loss = loss_func(prediction, label).cuda()
#
# ~/anaconda3/envs/prtlgn_kiba/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/prtlgn_kiba/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/prtlgn_kiba/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# <ipython-input-7-a405f8aef6c2> in collate(samples)
#       2 def collate(samples):
#       3     sequences, images, labels = map(list, zip(*samples))
# ----> 4     return tc.LongTensor(sequences).cuda(), tc.tensor(images, dtype=tc.float).cuda(), tc.tensor(labels).cuda()
#
# KeyboardInterrupt:

# %%
np.save('cnnlstm+chemception_tr_losses', tr_epoch_losses)
np.save('cnnlstm+chemception_va_losses', va_epoch_losses)

# %%
min(va_epoch_losses)
# Out:
# 0.3935684562457027
