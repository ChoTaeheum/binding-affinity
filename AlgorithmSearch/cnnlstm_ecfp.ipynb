# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:(2**16)+(2**13)-1, "uniprotID"]    # 5
ligand = dataset.loc[:(2**16)+(2**13)-1, "chemblID"]
kiba = list(dataset.loc[:(2**16)+(2**13)-1, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros(((2**16)+(2**13), 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :2000]

# %%
#%% ligand ecfp load
f = open('datasets/dictionaries/lgn_ecfp.txt', 'rb')
ecfp = pickle.load(f)
f.close()

ecfprint = np.zeros(((2**16)+(2**13), 2048))
for i, e in enumerate(ligand):
    ecfprint[i] = ecfp[e]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, ecfprint, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**16]
validset = shuffled_dataset[2**16:(2**16) + (2**13)]

del shuffled_dataset

# %%
#%% Make collate func.
def collate(samples):
    sequences, ecfprints, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.tensor(ecfprints, dtype=tc.float).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.emlayer = nn.Embedding(21, 10)
        
        self.cv2dlayer = nn.Sequential(
                        nn.Conv2d(1, 8, kernel_size = (64, 10), stride=(2, 1)),
                        nn.BatchNorm2d(num_features = 8),
                        nn.ReLU(),
                        nn.MaxPool2d(kernel_size = (2, 1))
                        )
        
        self.cv1dlayers = nn.Sequential(
                        nn.Conv1d(8, 16, kernel_size = 3),
                        nn.BatchNorm1d(num_features = 16),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 2),
                        nn.Conv1d(16, 24, kernel_size = 2),
                        nn.BatchNorm1d(num_features = 24),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 2)
                        )
            
        self.lslayer = nn.LSTM(24, 64, num_layers=1, bidirectional=True, batch_first=True)
        
        self.eclayers = nn.Sequential(
                        nn.Linear(2048, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(512, 256),
                        nn.BatchNorm1d(256),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(256, 128),
                        )

        self.regress = nn.Linear(256, 1, F.elu)    # regression

    def forward(self, seq, ecfp):        
        cv_i = self.emlayer(seq)
        
        cv2_i = cv_i.unsqueeze(1)
        cv2_o = self.cv2dlayer(cv2_i)
        cv1_i = cv2_o.squeeze()
        cv1_o = self.cv1dlayers(cv1_i)
        
        ls_i = cv1_o.permute(0, 2, 1)
        
        ls_h = torch.zeros(2, 64, 64).cuda()     # (num_layers * num_directions, batch, hidden_size)
        ls_c = torch.zeros(2, 64, 64).cuda()
        
        ls_o, (ls_h, ls_c) = self.lslayer(ls_i, (ls_h, ls_c))

        for_o = ls_o[:, -1, :64]
        back_o = ls_o[:, 0, 64:]
        
        concat_o = tc.cat((for_o, back_o), axis=1)   # batch, hidden*2
        
        ec_h = self.eclayers(ecfp)
        dim = 1
        for e in ec_h.size()[1:]:
            dim = dim * e
        ec_h = ec_h.view(-1, dim)
        
        cat = tc.cat((concat_o, ec_h), axis=1).cuda()
       
        return self.regress(cat).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 64
hp_d['num_epochs'] = 600

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
# %% training and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, ecfp, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, ecfp).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, ecfp, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, ecfp).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.6614577136168377
# va_var: 0.6632628674412697
# total params: 2843747
# Training epoch 0, loss 5.3342
# Validation epoch 0, loss 0.8357
# Training epoch 1, loss 0.5250
# Validation epoch 1, loss 0.5266
# Training epoch 2, loss 0.4200
# Validation epoch 2, loss 0.4563
# Training epoch 3, loss 0.3798
# Validation epoch 3, loss 0.4099
# Training epoch 4, loss 0.3657
# Validation epoch 4, loss 0.3986
# Training epoch 5, loss 0.3620
# Validation epoch 5, loss 0.3996
# Training epoch 6, loss 0.3585
# Validation epoch 6, loss 0.3956
# Training epoch 7, loss 0.3559
# Validation epoch 7, loss 0.3936
# Training epoch 8, loss 0.3521
# Validation epoch 8, loss 0.3880
# Training epoch 9, loss 0.3504
# Validation epoch 9, loss 0.3916
# Training epoch 10, loss 0.3481
# Validation epoch 10, loss 0.3914
# Training epoch 11, loss 0.3445
# Validation epoch 11, loss 0.3943
# Training epoch 12, loss 0.3448
# Validation epoch 12, loss 0.3911
# Training epoch 13, loss 0.3407
# Validation epoch 13, loss 0.4028
# Training epoch 14, loss 0.3388
# Validation epoch 14, loss 0.3931
# Training epoch 15, loss 0.3364
# Validation epoch 15, loss 0.3967
# Training epoch 16, loss 0.3342
# Validation epoch 16, loss 0.4014
# Training epoch 17, loss 0.3316
# Validation epoch 17, loss 0.3990
# Training epoch 18, loss 0.3314
# Validation epoch 18, loss 0.3960
# Training epoch 19, loss 0.3280
# Validation epoch 19, loss 0.3976
# Training epoch 20, loss 0.3264
# Validation epoch 20, loss 0.4005
# Training epoch 21, loss 0.3243
# Validation epoch 21, loss 0.3968
# Training epoch 22, loss 0.3243
# Validation epoch 22, loss 0.3978
# Training epoch 23, loss 0.3205
# Validation epoch 23, loss 0.4028
# Training epoch 24, loss 0.3201
# Validation epoch 24, loss 0.3955
# Training epoch 25, loss 0.3176
# Validation epoch 25, loss 0.3948
# Training epoch 26, loss 0.3158
# Validation epoch 26, loss 0.3969
# Training epoch 27, loss 0.3141
# Validation epoch 27, loss 0.3928
# Training epoch 28, loss 0.3122
# Validation epoch 28, loss 0.3962
# Training epoch 29, loss 0.3092
# Validation epoch 29, loss 0.3966
# Training epoch 30, loss 0.3086
# Validation epoch 30, loss 0.3928
# Training epoch 31, loss 0.3063
# Validation epoch 31, loss 0.3970
# Training epoch 32, loss 0.3042
# Validation epoch 32, loss 0.3943
# Training epoch 33, loss 0.3018
# Validation epoch 33, loss 0.3918
# Training epoch 34, loss 0.3002
# Validation epoch 34, loss 0.3878
# Training epoch 35, loss 0.2968
# Validation epoch 35, loss 0.3859
# Training epoch 36, loss 0.2939
# Validation epoch 36, loss 0.3905
# Training epoch 37, loss 0.2922
# Validation epoch 37, loss 0.3974
# Training epoch 38, loss 0.2902
# Validation epoch 38, loss 0.3877
# Training epoch 39, loss 0.2873
# Validation epoch 39, loss 0.3973
# Training epoch 40, loss 0.2838
# Validation epoch 40, loss 0.3982
# Training epoch 41, loss 0.2819
# Validation epoch 41, loss 0.3880
# Training epoch 42, loss 0.2769
# Validation epoch 42, loss 0.3968
# Training epoch 43, loss 0.2745
# Validation epoch 43, loss 0.3913
# Training epoch 44, loss 0.2714
# Validation epoch 44, loss 0.3913
# Training epoch 45, loss 0.2684
# Validation epoch 45, loss 0.4005
# Training epoch 46, loss 0.2670
# Validation epoch 46, loss 0.3913
# Training epoch 47, loss 0.2644
# Validation epoch 47, loss 0.4008
# Training epoch 48, loss 0.2613
# Validation epoch 48, loss 0.3848
# Training epoch 49, loss 0.2574
# Validation epoch 49, loss 0.4028
# Training epoch 50, loss 0.2554
# Validation epoch 50, loss 0.3942
# Training epoch 51, loss 0.2538
# Validation epoch 51, loss 0.3988
# Training epoch 52, loss 0.2496
# Validation epoch 52, loss 0.4067
# Training epoch 53, loss 0.2464
# Validation epoch 53, loss 0.4060
# Training epoch 54, loss 0.2441
# Validation epoch 54, loss 0.4028
# Training epoch 55, loss 0.2430
# Validation epoch 55, loss 0.3945
# Training epoch 56, loss 0.2385
# Validation epoch 56, loss 0.4150
# Training epoch 57, loss 0.2355
# Validation epoch 57, loss 0.3937
# Training epoch 58, loss 0.2349
# Validation epoch 58, loss 0.4019
# Training epoch 59, loss 0.2311
# Validation epoch 59, loss 0.4175
# Training epoch 60, loss 0.2292
# Validation epoch 60, loss 0.4119
# Training epoch 61, loss 0.2266
# Validation epoch 61, loss 0.3960
# Training epoch 62, loss 0.2252
# Validation epoch 62, loss 0.4114
# Training epoch 63, loss 0.2223
# Validation epoch 63, loss 0.4095
# Training epoch 64, loss 0.2179
# Validation epoch 64, loss 0.4019
# Training epoch 65, loss 0.2185
# Validation epoch 65, loss 0.4158
# Training epoch 66, loss 0.2171
# Validation epoch 66, loss 0.4122
# Training epoch 67, loss 0.2136
# Validation epoch 67, loss 0.3960
# Training epoch 68, loss 0.2117
# Validation epoch 68, loss 0.4135
# Training epoch 69, loss 0.2123
# Validation epoch 69, loss 0.3976
# Training epoch 70, loss 0.2084
# Validation epoch 70, loss 0.4043
# Training epoch 71, loss 0.2072
# Validation epoch 71, loss 0.4006
# Training epoch 72, loss 0.2036
# Validation epoch 72, loss 0.4034
# Training epoch 73, loss 0.2051
# Validation epoch 73, loss 0.4004
# Training epoch 74, loss 0.2011
# Validation epoch 74, loss 0.4028
# Training epoch 75, loss 0.1998
# Validation epoch 75, loss 0.4198
# Training epoch 76, loss 0.1973
# Validation epoch 76, loss 0.4117
# Training epoch 77, loss 0.1956
# Validation epoch 77, loss 0.4091
# Training epoch 78, loss 0.1930
# Validation epoch 78, loss 0.4017
# Training epoch 79, loss 0.1934
# Validation epoch 79, loss 0.4143
# Training epoch 80, loss 0.1930
# Validation epoch 80, loss 0.4124
# Training epoch 81, loss 0.1899
# Validation epoch 81, loss 0.4184
# Training epoch 82, loss 0.1900
# Validation epoch 82, loss 0.4018
# Training epoch 83, loss 0.1877
# Validation epoch 83, loss 0.4170
# Training epoch 84, loss 0.1867
# Validation epoch 84, loss 0.4092
# Training epoch 85, loss 0.1847
# Validation epoch 85, loss 0.4140
# Training epoch 86, loss 0.1857
# Validation epoch 86, loss 0.4068
# Training epoch 87, loss 0.1821
# Validation epoch 87, loss 0.4062
# Training epoch 88, loss 0.1813
# Validation epoch 88, loss 0.4122
# Training epoch 89, loss 0.1780
# Validation epoch 89, loss 0.4094
# Training epoch 90, loss 0.1791
# Validation epoch 90, loss 0.3937
# Training epoch 91, loss 0.1783
# Validation epoch 91, loss 0.4128
# Training epoch 92, loss 0.1750
# Validation epoch 92, loss 0.4076
# Training epoch 93, loss 0.1728
# Validation epoch 93, loss 0.4082
# Training epoch 94, loss 0.1717
# Validation epoch 94, loss 0.4093
# Training epoch 95, loss 0.1738
# Validation epoch 95, loss 0.4121
# Training epoch 96, loss 0.1727
# Validation epoch 96, loss 0.4157
# Training epoch 97, loss 0.1694
# Validation epoch 97, loss 0.4001
# Training epoch 98, loss 0.1704
# Validation epoch 98, loss 0.4017
# Training epoch 99, loss 0.1682
# Validation epoch 99, loss 0.4127
# Training epoch 100, loss 0.1686
# Validation epoch 100, loss 0.4088
# Training epoch 101, loss 0.1688
# Validation epoch 101, loss 0.4080
# Training epoch 102, loss 0.1660
# Validation epoch 102, loss 0.4168
# Training epoch 103, loss 0.1659
# Validation epoch 103, loss 0.4003
# Training epoch 104, loss 0.1640
# Validation epoch 104, loss 0.4077
# Training epoch 105, loss 0.1643
# Validation epoch 105, loss 0.4322
# Training epoch 106, loss 0.1616
# Validation epoch 106, loss 0.4155
# Training epoch 107, loss 0.1631
# Validation epoch 107, loss 0.4213
# Training epoch 108, loss 0.1613
# Validation epoch 108, loss 0.4133
# Training epoch 109, loss 0.1597
# Validation epoch 109, loss 0.4057
# Training epoch 110, loss 0.1593
# Validation epoch 110, loss 0.4095
# Training epoch 111, loss 0.1600
# Validation epoch 111, loss 0.4276
# Training epoch 112, loss 0.1593
# Validation epoch 112, loss 0.4024
# Training epoch 113, loss 0.1586
# Validation epoch 113, loss 0.4169
# Training epoch 114, loss 0.1567
# Validation epoch 114, loss 0.4117
# Training epoch 115, loss 0.1564
# Validation epoch 115, loss 0.4049

# %%
#%% 저장
np.save('cnnlstm+ecfp_tr_losses', tr_epoch_losses)
np.save('cnnlstm+ecfp_va_losses', va_epoch_losses)
