# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial
# from bayes_opt import BayesianOptimization

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = dataset.loc[:, "chemblID"]
kiba = list(dataset.loc[:, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_tfidf.txt', 'rb')
tfidf_dic = pickle.load(f)
f.close()

tfidf = np.zeros((datalen, 400))
for i, s in enumerate(protein):
    tfidf[i] = tfidf_dic[s]

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros((datalen, 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :1400]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros((datalen, 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(tfidf, sequence, smileseq, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:int((9/10)*datalen)]
validset = shuffled_dataset[int((9/10)*datalen):]

# %%
#%% Make collate func.
def collate(samples):
    tfidf, sequence, smileseq, labels = map(list, zip(*samples))
    return tc.tensor(tfidf, dtype=tc.float).cuda(), tc.LongTensor(sequence).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_cv1dlayers0 = nn.Sequential(
                        nn.Conv1d(1, 1, kernel_size = 32),
                        nn.BatchNorm1d(num_features = 1),
                        nn.ReLU()
                        )
        
        self.fc = nn.Linear(369, 256, F.relu)
        
        self.prt_emlayer = nn.Embedding(21, 10)
        
        self.prt_cv1dlayers1 = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 12),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size=1379)
                        )
        
        ######################################################################
        ######################################################################
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
        
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(448, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, tfidf, prt_seq, lgn_seq):
        p0 = tfidf.unsqueeze(1)
        p0 = self.prt_cv1dlayers0(p0)
        p0 = p0.squeeze()
        p0 = self.fc(p0)
        
        p1 = self.prt_emlayer(prt_seq)
        p1 = p1.permute(0, 2, 1)
        p1 = self.prt_cv1dlayers1(p1)
        p1 = p1.squeeze()
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p0, p1, l), axis=1).cuda()
        out = self.mlplayers(cat)
        out = out.squeeze()
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 256
hp_d['num_epochs'] = 150

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% training and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (tfidf, seq, smi, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(tfidf, seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (tfidf, seq, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(tfidf, seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 372.91571770685937
# va_var: 372.9321843858667
# total params: 3606006
# Training epoch 0, loss 29.3025
# Validation epoch 0, loss 0.8949
# Training epoch 1, loss 0.7238
# Validation epoch 1, loss 0.5001
# Training epoch 2, loss 0.4616
# Validation epoch 2, loss 0.3576
# Training epoch 3, loss 0.3777
# Validation epoch 3, loss 0.3346
# Training epoch 4, loss 0.3403
# Validation epoch 4, loss 0.3313
# Training epoch 5, loss 0.3112
# Validation epoch 5, loss 0.3159
# Training epoch 6, loss 0.2892
# Validation epoch 6, loss 0.2849
# Training epoch 7, loss 0.2687
# Validation epoch 7, loss 0.2754
# Training epoch 8, loss 0.2502
# Validation epoch 8, loss 0.2777
# Training epoch 9, loss 0.2340
# Validation epoch 9, loss 0.2618
# Training epoch 10, loss 0.2193
# Validation epoch 10, loss 0.2582
# Training epoch 11, loss 0.2068
# Validation epoch 11, loss 0.2535
# Training epoch 12, loss 0.2009
# Validation epoch 12, loss 0.2540
# Training epoch 13, loss 0.1923
# Validation epoch 13, loss 0.2668
# Training epoch 14, loss 0.1823
# Validation epoch 14, loss 0.2530
# Training epoch 15, loss 0.1733
# Validation epoch 15, loss 0.2851
# Training epoch 16, loss 0.1652
# Validation epoch 16, loss 0.2807
# Training epoch 17, loss 0.1604
# Validation epoch 17, loss 0.2559
# Training epoch 18, loss 0.1528
# Validation epoch 18, loss 0.2418
# Training epoch 19, loss 0.1547
# Validation epoch 19, loss 0.2180
# Training epoch 20, loss 0.1487
# Validation epoch 20, loss 0.2181
# Training epoch 21, loss 0.1400
# Validation epoch 21, loss 0.2284
# Training epoch 22, loss 0.1375
# Validation epoch 22, loss 0.2083
# Training epoch 23, loss 0.1344
# Validation epoch 23, loss 0.2063
# Training epoch 24, loss 0.1292
# Validation epoch 24, loss 0.2370
# Training epoch 25, loss 0.1230
# Validation epoch 25, loss 0.2097
# Training epoch 26, loss 0.1197
# Validation epoch 26, loss 0.2106
# Training epoch 27, loss 0.1191
# Validation epoch 27, loss 0.2011
# Training epoch 28, loss 0.1142
# Validation epoch 28, loss 0.1948
# Training epoch 29, loss 0.1116
# Validation epoch 29, loss 0.1963
# Training epoch 30, loss 0.1107
# Validation epoch 30, loss 0.1885
# Training epoch 31, loss 0.1085
# Validation epoch 31, loss 0.1953
# Training epoch 32, loss 0.1082
# Validation epoch 32, loss 0.1911
# Training epoch 33, loss 0.1045
# Validation epoch 33, loss 0.1898
# Training epoch 34, loss 0.1051
# Validation epoch 34, loss 0.1890
# Training epoch 35, loss 0.1028
# Validation epoch 35, loss 0.2064
# Training epoch 36, loss 0.1066
# Validation epoch 36, loss 0.1989
# Training epoch 37, loss 0.0995
# Validation epoch 37, loss 0.1839
# Training epoch 38, loss 0.0959
# Validation epoch 38, loss 0.1867
# Training epoch 39, loss 0.0938
# Validation epoch 39, loss 0.1856
# Training epoch 40, loss 0.0917
# Validation epoch 40, loss 0.1890
# Training epoch 41, loss 0.0903
# Validation epoch 41, loss 0.1925
# Training epoch 42, loss 0.0912
# Validation epoch 42, loss 0.2027
# Training epoch 43, loss 0.0871
# Validation epoch 43, loss 0.1915
# Training epoch 44, loss 0.0848
# Validation epoch 44, loss 0.1874
# Training epoch 45, loss 0.0842
# Validation epoch 45, loss 0.1887
# Training epoch 46, loss 0.0847
# Validation epoch 46, loss 0.1861
# Training epoch 47, loss 0.0831
# Validation epoch 47, loss 0.1876
# Training epoch 48, loss 0.0823
# Validation epoch 48, loss 0.2084
# Training epoch 49, loss 0.0810
# Validation epoch 49, loss 0.1783
# Training epoch 50, loss 0.0821
# Validation epoch 50, loss 0.1799
# Training epoch 51, loss 0.0805
# Validation epoch 51, loss 0.1947
# Training epoch 52, loss 0.0761
# Validation epoch 52, loss 0.1812
# Training epoch 53, loss 0.0762
# Validation epoch 53, loss 0.1792
# Training epoch 54, loss 0.0757
# Validation epoch 54, loss 0.1949
# Training epoch 55, loss 0.0786
# Validation epoch 55, loss 0.1864
# Training epoch 56, loss 0.0754
# Validation epoch 56, loss 0.1899
# Training epoch 57, loss 0.0723
# Validation epoch 57, loss 0.1791
# Training epoch 58, loss 0.0766
# Validation epoch 58, loss 0.1793
# Training epoch 59, loss 0.0742
# Validation epoch 59, loss 0.1847
# Training epoch 60, loss 0.0706
# Validation epoch 60, loss 0.1838
# Training epoch 61, loss 0.0668
# Validation epoch 61, loss 0.1928
# Training epoch 62, loss 0.0704
# Validation epoch 62, loss 0.1930
# Training epoch 63, loss 0.0702
# Validation epoch 63, loss 0.1886
# Training epoch 64, loss 0.0711
# Validation epoch 64, loss 0.1951
# Training epoch 65, loss 0.0764
# Validation epoch 65, loss 0.2192
# Training epoch 66, loss 0.0665
# Validation epoch 66, loss 0.1809
# Training epoch 67, loss 0.0674
# Validation epoch 67, loss 0.1853
# Training epoch 68, loss 0.0653
# Validation epoch 68, loss 0.1916
# Training epoch 69, loss 0.0647
# Validation epoch 69, loss 0.1932
# Training epoch 70, loss 0.0637
# Validation epoch 70, loss 0.1887
# Training epoch 71, loss 0.0628
# Validation epoch 71, loss 0.1838
# Training epoch 72, loss 0.0629
# Validation epoch 72, loss 0.1770
# Training epoch 73, loss 0.0635
# Validation epoch 73, loss 0.1755
# Training epoch 74, loss 0.0664
# Validation epoch 74, loss 0.1729
# Training epoch 75, loss 0.0607
# Validation epoch 75, loss 0.1725
# Training epoch 76, loss 0.0607
# Validation epoch 76, loss 0.1749
# Training epoch 77, loss 0.0601
# Validation epoch 77, loss 0.1821
# Training epoch 78, loss 0.0604
# Validation epoch 78, loss 0.1749
# Training epoch 79, loss 0.0619
# Validation epoch 79, loss 0.1788
# Training epoch 80, loss 0.0622
# Validation epoch 80, loss 0.1736
# Training epoch 81, loss 0.0581
# Validation epoch 81, loss 0.1742
# Training epoch 82, loss 0.0567
# Validation epoch 82, loss 0.1713
# Training epoch 83, loss 0.0739
# Validation epoch 83, loss 0.1979
# Training epoch 84, loss 0.0651
# Validation epoch 84, loss 0.1828
# Training epoch 85, loss 0.0563
# Validation epoch 85, loss 0.1854
# Training epoch 86, loss 0.0580
# Validation epoch 86, loss 0.1904
# Training epoch 87, loss 0.0556
# Validation epoch 87, loss 0.1671
# Training epoch 88, loss 0.0558
# Validation epoch 88, loss 0.1712
# Training epoch 89, loss 0.0538
# Validation epoch 89, loss 0.1723
# Training epoch 90, loss 0.0556
# Validation epoch 90, loss 0.1773
# Training epoch 91, loss 0.0565
# Validation epoch 91, loss 0.1804
# Training epoch 92, loss 0.0572
# Validation epoch 92, loss 0.1781
# Training epoch 93, loss 0.0562
# Validation epoch 93, loss 0.1778
# Training epoch 94, loss 0.0550
# Validation epoch 94, loss 0.1806
# Training epoch 95, loss 0.0589
# Validation epoch 95, loss 0.1799
# Training epoch 96, loss 0.0574
# Validation epoch 96, loss 0.1782
# Training epoch 97, loss 0.0505
# Validation epoch 97, loss 0.1781
# Training epoch 98, loss 0.0533
# Validation epoch 98, loss 0.1693
# Training epoch 99, loss 0.0535
# Validation epoch 99, loss 0.1660
# Training epoch 100, loss 0.0539
# Validation epoch 100, loss 0.1836
# Training epoch 101, loss 0.0552
# Validation epoch 101, loss 0.1708
# Training epoch 102, loss 0.0526
# Validation epoch 102, loss 0.1727
# Training epoch 103, loss 0.0510
# Validation epoch 103, loss 0.1763
# Training epoch 104, loss 0.0581
# Validation epoch 104, loss 0.1847
# Training epoch 105, loss 0.0579
# Validation epoch 105, loss 0.1763
# Training epoch 106, loss 0.0501
# Validation epoch 106, loss 0.1811
# Training epoch 107, loss 0.0495
# Validation epoch 107, loss 0.1724
# Training epoch 108, loss 0.0500
# Validation epoch 108, loss 0.1730
# Training epoch 109, loss 0.0520
# Validation epoch 109, loss 0.1693
# Training epoch 110, loss 0.0492
# Validation epoch 110, loss 0.1888
# Training epoch 111, loss 0.0525
# Validation epoch 111, loss 0.1795
# Training epoch 112, loss 0.0520
# Validation epoch 112, loss 0.1710
# Training epoch 113, loss 0.0502
# Validation epoch 113, loss 0.1796
# Training epoch 114, loss 0.0534
# Validation epoch 114, loss 0.1798
# Training epoch 115, loss 0.0521
# Validation epoch 115, loss 0.1799
# Training epoch 116, loss 0.0502
# Validation epoch 116, loss 0.1735
# Training epoch 117, loss 0.0517
# Validation epoch 117, loss 0.1768
# Training epoch 118, loss 0.0498
# Validation epoch 118, loss 0.1905
# Training epoch 119, loss 0.0467
# Validation epoch 119, loss 0.1732
# Training epoch 120, loss 0.0466
# Validation epoch 120, loss 0.1740
# Training epoch 121, loss 0.0575
# Validation epoch 121, loss 0.1807
# Training epoch 122, loss 0.0534
# Validation epoch 122, loss 0.1829
# Training epoch 123, loss 0.0510
# Validation epoch 123, loss 0.1790
# Training epoch 124, loss 0.0497
# Validation epoch 124, loss 0.1700
# Training epoch 125, loss 0.0451
# Validation epoch 125, loss 0.1740
# Training epoch 126, loss 0.0466
# Validation epoch 126, loss 0.1833
# Training epoch 127, loss 0.0537
# Validation epoch 127, loss 0.1797
# Training epoch 128, loss 0.0467
# Validation epoch 128, loss 0.1776
# Training epoch 129, loss 0.0465
# Validation epoch 129, loss 0.1828
# Training epoch 130, loss 0.0457
# Validation epoch 130, loss 0.1791
# Training epoch 131, loss 0.0527
# Validation epoch 131, loss 0.1849
# Training epoch 132, loss 0.0515
# Validation epoch 132, loss 0.1836
# Training epoch 133, loss 0.0483
# Validation epoch 133, loss 0.1738
# Training epoch 134, loss 0.0487
# Validation epoch 134, loss 0.1707
# Training epoch 135, loss 0.0472
# Validation epoch 135, loss 0.1705
# Training epoch 136, loss 0.0469
# Validation epoch 136, loss 0.1725
# Training epoch 137, loss 0.0468
# Validation epoch 137, loss 0.1755
# Training epoch 138, loss 0.0478
# Validation epoch 138, loss 0.1744
# Training epoch 139, loss 0.0454
# Validation epoch 139, loss 0.1785
# Training epoch 140, loss 0.0458
# Validation epoch 140, loss 0.1818
# Training epoch 141, loss 0.0454
# Validation epoch 141, loss 0.1912
# Training epoch 142, loss 0.0473
# Validation epoch 142, loss 0.1779
# Training epoch 143, loss 0.0502
# Validation epoch 143, loss 0.1857
# Training epoch 144, loss 0.0481
# Validation epoch 144, loss 0.1908
# Training epoch 145, loss 0.0468
# Validation epoch 145, loss 0.1879
# Training epoch 146, loss 0.0444
# Validation epoch 146, loss 0.1920
# Training epoch 147, loss 0.0498
# Validation epoch 147, loss 0.1809
# Training epoch 148, loss 0.0472
# Validation epoch 148, loss 0.1843
# Training epoch 149, loss 0.0454
# Validation epoch 149, loss 0.1827
# time elapsed: 9109.744152784348

# %%
#%%
np.save('ModifiedDeepDTA_v6_tr_losses', tr_epoch_losses)
np.save('ModifiedDeepDTA_v6_va_losses', va_epoch_losses)

# %%
min(va_epoch_losses)
# Out:
# 0.21312199137173593
