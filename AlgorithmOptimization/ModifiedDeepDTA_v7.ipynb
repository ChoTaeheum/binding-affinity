# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial
# from bayes_opt import BayesianOptimization

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = dataset.loc[:, "chemblID"]
kiba = list(dataset.loc[:, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_tfidf.txt', 'rb')
tfidf_dic = pickle.load(f)
f.close()

tfidf = np.zeros((datalen, 400))
for i, s in enumerate(protein):
    tfidf[i] = tfidf_dic[s]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros((datalen, 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(tfidf, smileseq, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:int((9/10)*datalen)]
validset = shuffled_dataset[int((9/10)*datalen):]

# %%
#%% Make collate func.
def collate(samples):
    tfidf, smileseq, labels = map(list, zip(*samples))
    return tc.tensor(tfidf, dtype=tc.float).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_cv1dlayers = nn.Sequential(
                        nn.Conv1d(1, 1, kernel_size = 32),
                        nn.BatchNorm1d(num_features = 1),
                        nn.ReLU()
                        )
        
        self.fc = nn.Linear(369, 256, F.relu)
        
        ######################################################################
        ######################################################################
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
        
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(352, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, prt_seq, lgn_seq):
        p = prt_seq.unsqueeze(1)
        p = self.prt_cv1dlayers(p)
        p = p.squeeze()
        p = self.fc(p)
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p, l), axis=1).cuda()
        out = self.mlplayers(cat)
        out = out.squeeze()
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 256
hp_d['num_epochs'] = 150

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% training and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (tfidf, smi, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (tfidf, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(tfidf, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.7006010478506419
# va_var: 0.6993066206316961
# total params: 3415524
# Training epoch 0, loss 30.4930
# Validation epoch 0, loss 0.9261
# Training epoch 1, loss 0.9884
# Validation epoch 1, loss 0.4753
# Training epoch 2, loss 0.7259
# Validation epoch 2, loss 0.3645
# Training epoch 3, loss 0.4343
# Validation epoch 3, loss 0.3350
# Training epoch 4, loss 0.3483
# Validation epoch 4, loss 0.3133
# Training epoch 5, loss 0.3157
# Validation epoch 5, loss 0.2973
# Training epoch 6, loss 0.2906
# Validation epoch 6, loss 0.2815
# Training epoch 7, loss 0.2690
# Validation epoch 7, loss 0.2769
# Training epoch 8, loss 0.2617
# Validation epoch 8, loss 0.2620
# Training epoch 9, loss 0.2420
# Validation epoch 9, loss 0.2603
# Training epoch 10, loss 0.2309
# Validation epoch 10, loss 0.2594
# Training epoch 11, loss 0.2177
# Validation epoch 11, loss 0.2572
# Training epoch 12, loss 0.2101
# Validation epoch 12, loss 0.2814
# Training epoch 13, loss 0.2044
# Validation epoch 13, loss 0.2617
# Training epoch 14, loss 0.1961
# Validation epoch 14, loss 0.2494
# Training epoch 15, loss 0.1821
# Validation epoch 15, loss 0.2349
# Training epoch 16, loss 0.1697
# Validation epoch 16, loss 0.2354
# Training epoch 17, loss 0.1648
# Validation epoch 17, loss 0.2380
# Training epoch 18, loss 0.1597
# Validation epoch 18, loss 0.2415
# Training epoch 19, loss 0.1567
# Validation epoch 19, loss 0.2327
# Training epoch 20, loss 0.1496
# Validation epoch 20, loss 0.2241
# Training epoch 21, loss 0.1468
# Validation epoch 21, loss 0.2297
# Training epoch 22, loss 0.1421
# Validation epoch 22, loss 0.2438
# Training epoch 23, loss 0.1374
# Validation epoch 23, loss 0.2186
# Training epoch 24, loss 0.1303
# Validation epoch 24, loss 0.2121
# Training epoch 25, loss 0.1278
# Validation epoch 25, loss 0.2142
# Training epoch 26, loss 0.1236
# Validation epoch 26, loss 0.2153
# Training epoch 27, loss 0.1247
# Validation epoch 27, loss 0.2188
# Training epoch 28, loss 0.1208
# Validation epoch 28, loss 0.2056
# Training epoch 29, loss 0.1181
# Validation epoch 29, loss 0.2175
# Training epoch 30, loss 0.1133
# Validation epoch 30, loss 0.2089
# Training epoch 31, loss 0.1088
# Validation epoch 31, loss 0.2080
# Training epoch 32, loss 0.1090
# Validation epoch 32, loss 0.2033
# Training epoch 33, loss 0.1042
# Validation epoch 33, loss 0.1983
# Training epoch 34, loss 0.1039
# Validation epoch 34, loss 0.2005
# Training epoch 35, loss 0.1041
# Validation epoch 35, loss 0.2070
# Training epoch 36, loss 0.0985
# Validation epoch 36, loss 0.2094
# Training epoch 37, loss 0.0949
# Validation epoch 37, loss 0.1963
# Training epoch 38, loss 0.0958
# Validation epoch 38, loss 0.2007
# Training epoch 39, loss 0.0941
# Validation epoch 39, loss 0.2088
# Training epoch 40, loss 0.0939
# Validation epoch 40, loss 0.1878
# Training epoch 41, loss 0.0897
# Validation epoch 41, loss 0.1911
# Training epoch 42, loss 0.0889
# Validation epoch 42, loss 0.1912
# Training epoch 43, loss 0.0884
# Validation epoch 43, loss 0.1970
# Training epoch 44, loss 0.0878
# Validation epoch 44, loss 0.1839
# Training epoch 45, loss 0.0855
# Validation epoch 45, loss 0.1904
# Training epoch 46, loss 0.0842
# Validation epoch 46, loss 0.1894
# Training epoch 47, loss 0.0821
# Validation epoch 47, loss 0.1847
# Training epoch 48, loss 0.0837
# Validation epoch 48, loss 0.1904
# Training epoch 49, loss 0.0811
# Validation epoch 49, loss 0.1861
# Training epoch 50, loss 0.0785
# Validation epoch 50, loss 0.1954
# Training epoch 51, loss 0.0782
# Validation epoch 51, loss 0.1901
# Training epoch 52, loss 0.0806
# Validation epoch 52, loss 0.1966
# Training epoch 53, loss 0.0767
# Validation epoch 53, loss 0.1845
# Training epoch 54, loss 0.0732
# Validation epoch 54, loss 0.1801
# Training epoch 55, loss 0.0733
# Validation epoch 55, loss 0.1867
# Training epoch 56, loss 0.0745
# Validation epoch 56, loss 0.1930
# Training epoch 57, loss 0.0736
# Validation epoch 57, loss 0.1832
# Training epoch 58, loss 0.0728
# Validation epoch 58, loss 0.2060
# Training epoch 59, loss 0.0717
# Validation epoch 59, loss 0.1844
# Training epoch 60, loss 0.0697
# Validation epoch 60, loss 0.1775
# Training epoch 61, loss 0.0712
# Validation epoch 61, loss 0.1832
# Training epoch 62, loss 0.0705
# Validation epoch 62, loss 0.1809
# Training epoch 63, loss 0.0691
# Validation epoch 63, loss 0.1931
# Training epoch 64, loss 0.0674
# Validation epoch 64, loss 0.1701
# Training epoch 65, loss 0.0668
# Validation epoch 65, loss 0.1875
# Training epoch 66, loss 0.0701
# Validation epoch 66, loss 0.1800
# Training epoch 67, loss 0.0667
# Validation epoch 67, loss 0.1862
# Training epoch 68, loss 0.0667
# Validation epoch 68, loss 0.1826
# Training epoch 69, loss 0.0653
# Validation epoch 69, loss 0.1791
# Training epoch 70, loss 0.0685
# Validation epoch 70, loss 0.1837
# Training epoch 71, loss 0.0695
# Validation epoch 71, loss 0.1747
# Training epoch 72, loss 0.0709
# Validation epoch 72, loss 0.1716
# Training epoch 73, loss 0.0662
# Validation epoch 73, loss 0.1732
# Training epoch 74, loss 0.0638
# Validation epoch 74, loss 0.1757
# Training epoch 75, loss 0.0654
# Validation epoch 75, loss 0.1802
# Training epoch 76, loss 0.0667
# Validation epoch 76, loss 0.1892
# Training epoch 77, loss 0.0680
# Validation epoch 77, loss 0.1803
# Training epoch 78, loss 0.0649
# Validation epoch 78, loss 0.1709
# Training epoch 79, loss 0.0623
# Validation epoch 79, loss 0.1772
# Training epoch 80, loss 0.0594
# Validation epoch 80, loss 0.1697
# Training epoch 81, loss 0.0619
# Validation epoch 81, loss 0.1885
# Training epoch 82, loss 0.0583
# Validation epoch 82, loss 0.1745
# Training epoch 83, loss 0.0564
# Validation epoch 83, loss 0.1751
# Training epoch 84, loss 0.0597
# Validation epoch 84, loss 0.1729
# Training epoch 85, loss 0.0605
# Validation epoch 85, loss 0.1787
# Training epoch 86, loss 0.0575
# Validation epoch 86, loss 0.1823
# Training epoch 87, loss 0.0588
# Validation epoch 87, loss 0.1658
# Training epoch 88, loss 0.0581
# Validation epoch 88, loss 0.1788
# Training epoch 89, loss 0.0567
# Validation epoch 89, loss 0.1771
# Training epoch 90, loss 0.0565
# Validation epoch 90, loss 0.1812
# Training epoch 91, loss 0.0579
# Validation epoch 91, loss 0.1762
# Training epoch 92, loss 0.0598
# Validation epoch 92, loss 0.1672
# Training epoch 93, loss 0.0570
# Validation epoch 93, loss 0.1829
# Training epoch 94, loss 0.0572
# Validation epoch 94, loss 0.1740
# Training epoch 95, loss 0.0553
# Validation epoch 95, loss 0.1696
# Training epoch 96, loss 0.0545
# Validation epoch 96, loss 0.1827
# Training epoch 97, loss 0.0558
# Validation epoch 97, loss 0.1714
# Training epoch 98, loss 0.0554
# Validation epoch 98, loss 0.1687
# Training epoch 99, loss 0.0547
# Validation epoch 99, loss 0.1729
# Training epoch 100, loss 0.0536
# Validation epoch 100, loss 0.1829
# Training epoch 101, loss 0.0533
# Validation epoch 101, loss 0.1744
# Training epoch 102, loss 0.0524
# Validation epoch 102, loss 0.1652
# Training epoch 103, loss 0.0556
# Validation epoch 103, loss 0.1722
# Training epoch 104, loss 0.0558
# Validation epoch 104, loss 0.1776
# Training epoch 105, loss 0.0537
# Validation epoch 105, loss 0.1720
# Training epoch 106, loss 0.0515
# Validation epoch 106, loss 0.1746
# Training epoch 107, loss 0.0554
# Validation epoch 107, loss 0.1864
# Training epoch 108, loss 0.0530
# Validation epoch 108, loss 0.1779
# Training epoch 109, loss 0.0496
# Validation epoch 109, loss 0.1706
# Training epoch 110, loss 0.0510
# Validation epoch 110, loss 0.1774
# Training epoch 111, loss 0.0519
# Validation epoch 111, loss 0.1653
# Training epoch 112, loss 0.0512
# Validation epoch 112, loss 0.1876
# Training epoch 113, loss 0.0526
# Validation epoch 113, loss 0.1878
# Training epoch 114, loss 0.0531
# Validation epoch 114, loss 0.1692
# Training epoch 115, loss 0.0516
# Validation epoch 115, loss 0.1738
# Training epoch 116, loss 0.0506
# Validation epoch 116, loss 0.1816
# Training epoch 117, loss 0.0501
# Validation epoch 117, loss 0.1964
# Training epoch 118, loss 0.0497
# Validation epoch 118, loss 0.1661
# Training epoch 119, loss 0.0464
# Validation epoch 119, loss 0.1677
# Training epoch 120, loss 0.0499
# Validation epoch 120, loss 0.1782
# Training epoch 121, loss 0.0559
# Validation epoch 121, loss 0.1686
# Training epoch 122, loss 0.0482
# Validation epoch 122, loss 0.1656
# Training epoch 123, loss 0.0468
# Validation epoch 123, loss 0.1802
# Training epoch 124, loss 0.0480
# Validation epoch 124, loss 0.1764
# Training epoch 125, loss 0.0461
# Validation epoch 125, loss 0.1729
# Training epoch 126, loss 0.0512
# Validation epoch 126, loss 0.1738
# Training epoch 127, loss 0.0528
# Validation epoch 127, loss 0.1632
# Training epoch 128, loss 0.0517
# Validation epoch 128, loss 0.1779
# Training epoch 129, loss 0.0508
# Validation epoch 129, loss 0.1685
# Training epoch 130, loss 0.0437
# Validation epoch 130, loss 0.1675
# Training epoch 131, loss 0.0468
# Validation epoch 131, loss 0.1673
# Training epoch 132, loss 0.0525
# Validation epoch 132, loss 0.1727
# Training epoch 133, loss 0.0481
# Validation epoch 133, loss 0.1738
# Training epoch 134, loss 0.0457
# Validation epoch 134, loss 0.1730
# Training epoch 135, loss 0.0445
# Validation epoch 135, loss 0.1718
# Training epoch 136, loss 0.0471
# Validation epoch 136, loss 0.1808
# Training epoch 137, loss 0.0564
# Validation epoch 137, loss 0.1714
# Training epoch 138, loss 0.0515
# Validation epoch 138, loss 0.1718
# Training epoch 139, loss 0.0484
# Validation epoch 139, loss 0.1655
# Training epoch 140, loss 0.0474
# Validation epoch 140, loss 0.1636
# Training epoch 141, loss 0.0442
# Validation epoch 141, loss 0.1689
# Training epoch 142, loss 0.0434
# Validation epoch 142, loss 0.1671
# Training epoch 143, loss 0.0430
# Validation epoch 143, loss 0.1715
# Training epoch 144, loss 0.0462
# Validation epoch 144, loss 0.1676
# Training epoch 145, loss 0.0468
# Validation epoch 145, loss 0.1758
# Training epoch 146, loss 0.0450
# Validation epoch 146, loss 0.1750
# Training epoch 147, loss 0.0453
# Validation epoch 147, loss 0.1661
# Training epoch 148, loss 0.0453
# Validation epoch 148, loss 0.1659
# Training epoch 149, loss 0.0520
# Validation epoch 149, loss 0.1648
# time elapsed: 1457.0227780342102

# %%
#%%
np.save('ModifiedDeepDTA_v6_tr_losses', tr_epoch_losses)
np.save('ModifiedDeepDTA_v6_va_losses', va_epoch_losses)

# %%
min(va_epoch_losses)
# Out:
# 0.21312199137173593
