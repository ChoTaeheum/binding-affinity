# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial
from sklearn.model_selection import KFold

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = dataset.loc[:, "chemblID"]
kiba = list(dataset.loc[:, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_tfidf.txt', 'rb')
tfidf_dic = pickle.load(f)
f.close()

tfidf = np.zeros((datalen, 400))
for i, s in enumerate(protein):
    tfidf[i] = tfidf_dic[s]

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros((datalen, 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :1400]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros((datalen, 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(tfidf, sequence, smileseq, kiba))
shuffled_dataset = np.array(shuffle(revised_dataset)); del revised_dataset

# %%
#%% Make collate func.
def collate(samples):
    tfidf, sequence, smileseq, labels = map(list, zip(*samples))
    return tc.tensor(tfidf, dtype=tc.float).cuda(), tc.LongTensor(sequence).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_cv1dlayers0 = nn.Sequential(
                        nn.Conv1d(1, 1, kernel_size = 32),
                        nn.BatchNorm1d(num_features = 1),
                        nn.ReLU()
                        )
        
        self.fc = nn.Linear(369, 256, F.relu)
        
        self.prt_emlayer = nn.Embedding(21, 10)
        
        self.prt_cv1dlayers1 = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 12),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size=1379)
                        )
        
        
        ######################################################################
        ######################################################################
        
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
        
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(448, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, tfidf, prt_seq, lgn_seq):   
        p0 = tfidf.unsqueeze(1)
        p0 = self.prt_cv1dlayers0(p0)
        p0 = p0.squeeze()
        p0 = self.fc(p0)
        
        p1 = self.prt_emlayer(prt_seq)
        p1 = p1.permute(0, 2, 1)
        p1 = self.prt_cv1dlayers1(p1)
        p1 = p1.squeeze()
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p0, p1, l), axis=1).cuda()
        out = self.mlplayers(cat)
        out = out.squeeze()
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 512
hp_d['num_epochs'] = 100

hp_d['init_learning_rate'] = 10 ** -3.163
hp_d['eps'] = 10 ** -7.32
hp_d['weight_decay'] = 10 ** -5.639

# %%
#%% training and validation
kf = KFold(n_splits=5); kf.get_n_splits(shuffled_dataset)
val_err = 0
for tr_idx, ts_idx in kf.split(shuffled_dataset):
    trainset, testset = shuffled_dataset[tr_idx], shuffled_dataset[ts_idx]
    trainset = tuple(trainset); testset = tuple(testset)

    tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
    va_data_loader = DataLoader(testset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

    model = Regressor().to(torch.device('cuda:0'))
    loss_func = nn.MSELoss(reduction='mean').cuda()

    optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
        weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

    tr_epoch_losses = []
    va_epoch_losses = []

    for epoch in range(hp_d['num_epochs']):                             #!! epoch-loop
        # training session
        model.train()
        tr_epoch_loss = 0

        for iter, (tfidf, seq, smi, label) in enumerate(tr_data_loader):       #!! batch-loop
            prediction = model(tfidf, seq, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tr_epoch_loss += loss.detach().item()

        tr_epoch_loss /= (iter + 1)
        print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
        tr_epoch_losses.append(tr_epoch_loss)

    # ===========================================================================
        # validation session
        model.eval()
        va_epoch_loss = 0

        for iter, (tfidf, seq, smi, label) in enumerate(va_data_loader):  # batch-loop
            prediction = model(tfidf, seq, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            va_epoch_loss += loss.detach().item()

        va_epoch_loss /= (iter + 1)
        print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
        va_epoch_losses.append(va_epoch_loss)
    val_err += min(va_epoch_losses)
print('5-fold CVMSE:', val_err/5)
# Out:
# Training epoch 0, loss 19.2520
# Validation epoch 0, loss 0.5148
# Training epoch 1, loss 0.7038
# Validation epoch 1, loss 0.3840
# Training epoch 2, loss 0.5891
# Validation epoch 2, loss 0.3635
# Training epoch 3, loss 0.4719
# Validation epoch 3, loss 0.3161
# Training epoch 4, loss 0.3692
# Validation epoch 4, loss 0.2944
# Training epoch 5, loss 0.3073
# Validation epoch 5, loss 0.2774
# Training epoch 6, loss 0.2786
# Validation epoch 6, loss 0.2743
# Training epoch 7, loss 0.2528
# Validation epoch 7, loss 0.2939
# Training epoch 8, loss 0.2411
# Validation epoch 8, loss 0.2876
# Training epoch 9, loss 0.2226
# Validation epoch 9, loss 0.2884
# Training epoch 10, loss 0.2106
# Validation epoch 10, loss 0.2855
# Training epoch 11, loss 0.2012
# Validation epoch 11, loss 0.2625
# Training epoch 12, loss 0.1900
# Validation epoch 12, loss 0.3425
# Training epoch 13, loss 0.1827
# Validation epoch 13, loss 0.3407
# Training epoch 14, loss 0.1737
# Validation epoch 14, loss 0.3351
# Training epoch 15, loss 0.1663
# Validation epoch 15, loss 0.2416
# Training epoch 16, loss 0.1577
# Validation epoch 16, loss 0.2929
# Training epoch 17, loss 0.1520
# Validation epoch 17, loss 0.2909
# Training epoch 18, loss 0.1517
# Validation epoch 18, loss 0.2221
# Training epoch 19, loss 0.1466
# Validation epoch 19, loss 0.2650
# Training epoch 20, loss 0.1367
# Validation epoch 20, loss 0.2406
# Training epoch 21, loss 0.1346
# Validation epoch 21, loss 0.2285
# Training epoch 22, loss 0.1313
# Validation epoch 22, loss 0.2377
# Training epoch 23, loss 0.1275
# Validation epoch 23, loss 0.2484
# Training epoch 24, loss 0.1267
# Validation epoch 24, loss 0.1986
# Training epoch 25, loss 0.1196
# Validation epoch 25, loss 0.2109
# Training epoch 26, loss 0.1165
# Validation epoch 26, loss 0.2350
# Training epoch 27, loss 0.1127
# Validation epoch 27, loss 0.2669
# Training epoch 28, loss 0.1132
# Validation epoch 28, loss 0.2069
# Training epoch 29, loss 0.1074
# Validation epoch 29, loss 0.2278
# Training epoch 30, loss 0.1066
# Validation epoch 30, loss 0.2072
# Training epoch 31, loss 0.1064
# Validation epoch 31, loss 0.2082
# Training epoch 32, loss 0.1035
# Validation epoch 32, loss 0.2528
# Training epoch 33, loss 0.1006
# Validation epoch 33, loss 0.2027
# Training epoch 34, loss 0.0992
# Validation epoch 34, loss 0.2233
# Training epoch 35, loss 0.0998
# Validation epoch 35, loss 0.2073
# Training epoch 36, loss 0.0970
# Validation epoch 36, loss 0.1984
# Training epoch 37, loss 0.0938
# Validation epoch 37, loss 0.1933
# Training epoch 38, loss 0.0985
# Validation epoch 38, loss 0.2068
# Training epoch 39, loss 0.0908
# Validation epoch 39, loss 0.1965
# Training epoch 40, loss 0.0873
# Validation epoch 40, loss 0.2104
# Training epoch 41, loss 0.0868
# Validation epoch 41, loss 0.2355
# Training epoch 42, loss 0.0826
# Validation epoch 42, loss 0.2006
# Training epoch 43, loss 0.0798
# Validation epoch 43, loss 0.2439
# Training epoch 44, loss 0.0769
# Validation epoch 44, loss 0.2208
# Training epoch 45, loss 0.0747
# Validation epoch 45, loss 0.2065
# Training epoch 46, loss 0.0729
# Validation epoch 46, loss 0.2605
# Training epoch 47, loss 0.0679
# Validation epoch 47, loss 0.2019
# Training epoch 48, loss 0.0661
# Validation epoch 48, loss 0.1972
# Training epoch 49, loss 0.0647
# Validation epoch 49, loss 0.2136
# Training epoch 50, loss 0.0629
# Validation epoch 50, loss 0.1958
# Training epoch 51, loss 0.0626
# Validation epoch 51, loss 0.2074
# Training epoch 52, loss 0.0628
# Validation epoch 52, loss 0.1991
# Training epoch 53, loss 0.0619
# Validation epoch 53, loss 0.1924
# Training epoch 54, loss 0.0622
# Validation epoch 54, loss 0.1956
# Training epoch 55, loss 0.0659
# Validation epoch 55, loss 0.1934
# Training epoch 56, loss 0.0680
# Validation epoch 56, loss 0.1860
# Training epoch 57, loss 0.0682
# Validation epoch 57, loss 0.1882
# Training epoch 58, loss 0.0718
# Validation epoch 58, loss 0.1856
# Training epoch 59, loss 0.0695
# Validation epoch 59, loss 0.1842
# Training epoch 60, loss 0.0633
# Validation epoch 60, loss 0.1936
# Training epoch 61, loss 0.0603
# Validation epoch 61, loss 0.1968
# Training epoch 62, loss 0.0573
# Validation epoch 62, loss 0.1849
# Training epoch 63, loss 0.0567
# Validation epoch 63, loss 0.1901
# Training epoch 64, loss 0.0555
# Validation epoch 64, loss 0.2028
# Training epoch 65, loss 0.0534
# Validation epoch 65, loss 0.1896
# Training epoch 66, loss 0.0519
# Validation epoch 66, loss 0.1887
# Training epoch 67, loss 0.0513
# Validation epoch 67, loss 0.1975
# Training epoch 68, loss 0.0516
# Validation epoch 68, loss 0.1863
# Training epoch 69, loss 0.0504
# Validation epoch 69, loss 0.1919
# Training epoch 70, loss 0.0509
# Validation epoch 70, loss 0.2064
# Training epoch 71, loss 0.0507
# Validation epoch 71, loss 0.1906
# Training epoch 72, loss 0.0507
# Validation epoch 72, loss 0.1827
# Training epoch 73, loss 0.0485
# Validation epoch 73, loss 0.1916
# Training epoch 74, loss 0.0503
# Validation epoch 74, loss 0.1929
# Training epoch 75, loss 0.0511
# Validation epoch 75, loss 0.2008
# Training epoch 76, loss 0.0585
# Validation epoch 76, loss 0.1872
# Training epoch 77, loss 0.0623
# Validation epoch 77, loss 0.1812
# Training epoch 78, loss 0.0505
# Validation epoch 78, loss 0.1800
# Training epoch 79, loss 0.0463
# Validation epoch 79, loss 0.1918
# Training epoch 80, loss 0.0454
# Validation epoch 80, loss 0.1903
# Training epoch 81, loss 0.0470
# Validation epoch 81, loss 0.1750
# Training epoch 82, loss 0.0461
# Validation epoch 82, loss 0.1777
# Training epoch 83, loss 0.0494
# Validation epoch 83, loss 0.1987
# Training epoch 84, loss 0.0462
# Validation epoch 84, loss 0.2075
# Training epoch 85, loss 0.0434
# Validation epoch 85, loss 0.2076
# Training epoch 86, loss 0.0448
# Validation epoch 86, loss 0.2029
# Training epoch 87, loss 0.0481
# Validation epoch 87, loss 0.1885
# Training epoch 88, loss 0.0547
# Validation epoch 88, loss 0.1824
# Training epoch 89, loss 0.0599
# Validation epoch 89, loss 0.1920
# Training epoch 90, loss 0.0593
# Validation epoch 90, loss 0.1806
# Training epoch 91, loss 0.0463
# Validation epoch 91, loss 0.1761
# Training epoch 92, loss 0.0395
# Validation epoch 92, loss 0.1779
# Training epoch 93, loss 0.0362
# Validation epoch 93, loss 0.1703
# Training epoch 94, loss 0.0334
# Validation epoch 94, loss 0.1715
# Training epoch 95, loss 0.0317
# Validation epoch 95, loss 0.1749
# Training epoch 96, loss 0.0324
# Validation epoch 96, loss 0.1868
# Training epoch 97, loss 0.0341
# Validation epoch 97, loss 0.1724
# Training epoch 98, loss 0.0328
# Validation epoch 98, loss 0.1650
# Training epoch 99, loss 0.0344
# Validation epoch 99, loss 0.1735
# Training epoch 0, loss 17.2873
# Validation epoch 0, loss 0.5030
# Training epoch 1, loss 0.6615
# Validation epoch 1, loss 0.4837
# Training epoch 2, loss 0.5434
# Validation epoch 2, loss 0.3702
# Training epoch 3, loss 0.4493
# Validation epoch 3, loss 0.3252
# Training epoch 4, loss 0.3614
# Validation epoch 4, loss 0.3039
# Training epoch 5, loss 0.2979
# Validation epoch 5, loss 0.2908
# Training epoch 6, loss 0.2650
# Validation epoch 6, loss 0.2792
# Training epoch 7, loss 0.2433
# Validation epoch 7, loss 0.2783
# Training epoch 8, loss 0.2264
# Validation epoch 8, loss 0.2887
# Training epoch 9, loss 0.2120
# Validation epoch 9, loss 0.2650
# Training epoch 10, loss 0.1973
# Validation epoch 10, loss 0.2706
# Training epoch 11, loss 0.1940
# Validation epoch 11, loss 0.2500
# Training epoch 12, loss 0.1844
# Validation epoch 12, loss 0.2444
# Training epoch 13, loss 0.1711
# Validation epoch 13, loss 0.3223
# Training epoch 14, loss 0.1673
# Validation epoch 14, loss 0.2539
# Training epoch 15, loss 0.1628
# Validation epoch 15, loss 0.2463
# Training epoch 16, loss 0.1547
# Validation epoch 16, loss 0.2587
# Training epoch 17, loss 0.1529
# Validation epoch 17, loss 0.2307
# Training epoch 18, loss 0.1432
# Validation epoch 18, loss 0.2298
# Training epoch 19, loss 0.1391
# Validation epoch 19, loss 0.2486
# Training epoch 20, loss 0.1335
# Validation epoch 20, loss 0.2268
# Training epoch 21, loss 0.1311
# Validation epoch 21, loss 0.2636
# Training epoch 22, loss 0.1242
# Validation epoch 22, loss 0.2509
# Training epoch 23, loss 0.1265
# Validation epoch 23, loss 0.2526
# Training epoch 24, loss 0.1193
# Validation epoch 24, loss 0.2354
# Training epoch 25, loss 0.1126
# Validation epoch 25, loss 0.2173
# Training epoch 26, loss 0.1084
# Validation epoch 26, loss 0.2754
# Training epoch 27, loss 0.1088
# Validation epoch 27, loss 0.2291
# Training epoch 28, loss 0.1063
# Validation epoch 28, loss 0.2174
# Training epoch 29, loss 0.1026
# Validation epoch 29, loss 0.2166
# Training epoch 30, loss 0.1038
# Validation epoch 30, loss 0.2255
# Training epoch 31, loss 0.1084
# Validation epoch 31, loss 0.2904
# Training epoch 32, loss 0.1064
# Validation epoch 32, loss 0.2210
# Training epoch 33, loss 0.1008
# Validation epoch 33, loss 0.2038
# Training epoch 34, loss 0.0967
# Validation epoch 34, loss 0.2152
# Training epoch 35, loss 0.0907
# Validation epoch 35, loss 0.2144
# Training epoch 36, loss 0.0896
# Validation epoch 36, loss 0.2004
# Training epoch 37, loss 0.0907
# Validation epoch 37, loss 0.2393
# Training epoch 38, loss 0.0948
# Validation epoch 38, loss 0.2068
# Training epoch 39, loss 0.0882
# Validation epoch 39, loss 0.2194
# Training epoch 40, loss 0.0842
# Validation epoch 40, loss 0.2012
# Training epoch 41, loss 0.0831
# Validation epoch 41, loss 0.2092
# Training epoch 42, loss 0.0784
# Validation epoch 42, loss 0.2547
# Training epoch 43, loss 0.0775
# Validation epoch 43, loss 0.2095
# Training epoch 44, loss 0.0746
# Validation epoch 44, loss 0.2165
# Training epoch 45, loss 0.0796
# Validation epoch 45, loss 0.2157
# Training epoch 46, loss 0.0826
# Validation epoch 46, loss 0.2157
# Training epoch 47, loss 0.0811
# Validation epoch 47, loss 0.2023
# Training epoch 48, loss 0.0711
# Validation epoch 48, loss 0.2090
# Training epoch 49, loss 0.0674
# Validation epoch 49, loss 0.1975
# Training epoch 50, loss 0.0659
# Validation epoch 50, loss 0.2183
# Training epoch 51, loss 0.0679
# Validation epoch 51, loss 0.1998
# Training epoch 52, loss 0.0707
# Validation epoch 52, loss 0.2113
# Training epoch 53, loss 0.0628
# Validation epoch 53, loss 0.2052
# Training epoch 54, loss 0.0640
# Validation epoch 54, loss 0.2536
# Training epoch 55, loss 0.0691
# Validation epoch 55, loss 0.1981
# Training epoch 56, loss 0.0729
# Validation epoch 56, loss 0.1888
# Training epoch 57, loss 0.0714
# Validation epoch 57, loss 0.1952
# Training epoch 58, loss 0.0703
# Validation epoch 58, loss 0.2011
# Training epoch 59, loss 0.0683
# Validation epoch 59, loss 0.2134
# Training epoch 60, loss 0.0655
# Validation epoch 60, loss 0.1872
# Training epoch 61, loss 0.0575
# Validation epoch 61, loss 0.1921
# Training epoch 62, loss 0.0545
# Validation epoch 62, loss 0.1874
# Training epoch 63, loss 0.0512
# Validation epoch 63, loss 0.1899
# Training epoch 64, loss 0.0494
# Validation epoch 64, loss 0.1849
# Training epoch 65, loss 0.0482
# Validation epoch 65, loss 0.1901
# Training epoch 66, loss 0.0473
# Validation epoch 66, loss 0.1860
# Training epoch 67, loss 0.0467
# Validation epoch 67, loss 0.1853
# Training epoch 68, loss 0.0483
# Validation epoch 68, loss 0.1974
# Training epoch 69, loss 0.0512
# Validation epoch 69, loss 0.1962
# Training epoch 70, loss 0.0476
# Validation epoch 70, loss 0.1813
# Training epoch 71, loss 0.0454
# Validation epoch 71, loss 0.1847
# Training epoch 72, loss 0.0448
# Validation epoch 72, loss 0.1850
# Training epoch 73, loss 0.0452
# Validation epoch 73, loss 0.1902
# Training epoch 74, loss 0.0473
# Validation epoch 74, loss 0.1876
# Training epoch 75, loss 0.0502
# Validation epoch 75, loss 0.1820
# Training epoch 76, loss 0.0515
# Validation epoch 76, loss 0.1952
# Training epoch 77, loss 0.0488
# Validation epoch 77, loss 0.1912
# Training epoch 78, loss 0.0472
# Validation epoch 78, loss 0.2115
# Training epoch 79, loss 0.0493
# Validation epoch 79, loss 0.1995
# Training epoch 80, loss 0.0502
# Validation epoch 80, loss 0.1887
# Training epoch 81, loss 0.0547
# Validation epoch 81, loss 0.1925
# Training epoch 82, loss 0.0725
# Validation epoch 82, loss 0.2157
# Training epoch 83, loss 0.0572
# Training epoch 84, loss 0.0454
# Validation epoch 84, loss 0.1741
# Training epoch 85, loss 0.0423
# Validation epoch 85, loss 0.1854
# Training epoch 86, loss 0.0478
# Validation epoch 86, loss 0.1807
# Training epoch 87, loss 0.0403
# Validation epoch 87, loss 0.1791
# Training epoch 88, loss 0.0404
# Validation epoch 88, loss 0.1729
# Training epoch 89, loss 0.0412
# Validation epoch 89, loss 0.1856
# Training epoch 90, loss 0.0500
# Validation epoch 90, loss 0.1883
# Training epoch 91, loss 0.0705
# Validation epoch 91, loss 0.2264
# Training epoch 92, loss 0.0780
# Validation epoch 92, loss 0.2400
# Training epoch 93, loss 0.0574
# Validation epoch 93, loss 0.2265
# Training epoch 94, loss 0.0451
# Validation epoch 94, loss 0.2019
# Training epoch 95, loss 0.0396
# Validation epoch 95, loss 0.2075
# Training epoch 96, loss 0.0384
# Validation epoch 96, loss 0.1918
# Training epoch 97, loss 0.0365
# Validation epoch 97, loss 0.1889
# Training epoch 98, loss 0.0348
# Validation epoch 98, loss 0.1799
# Training epoch 99, loss 0.0338
# Validation epoch 99, loss 0.1798
# Training epoch 0, loss 18.4795
# Validation epoch 0, loss 0.5192
# Training epoch 1, loss 0.7001
# Validation epoch 1, loss 0.3894
# Training epoch 2, loss 0.5826
# Validation epoch 2, loss 0.3585
# Training epoch 3, loss 0.4860
# Validation epoch 3, loss 0.3330
# Training epoch 4, loss 0.3805
# Validation epoch 4, loss 0.3059
# Training epoch 5, loss 0.3145
# Validation epoch 5, loss 0.2781
# Training epoch 6, loss 0.2725
# Validation epoch 6, loss 0.2989
# Training epoch 7, loss 0.2434
# Validation epoch 7, loss 0.2522
# Training epoch 8, loss 0.2208
# Validation epoch 8, loss 0.2600
# Training epoch 9, loss 0.2041
# Validation epoch 9, loss 0.2504
# Training epoch 10, loss 0.1945
# Validation epoch 10, loss 0.2424
# Training epoch 11, loss 0.1857
# Validation epoch 11, loss 0.2423
# Training epoch 12, loss 0.1788
# Validation epoch 12, loss 0.2598
# Training epoch 13, loss 0.1698
# Validation epoch 13, loss 0.2807
# Training epoch 14, loss 0.1624
# Validation epoch 14, loss 0.2507
# Training epoch 15, loss 0.1551
# Validation epoch 15, loss 0.2430
# Training epoch 16, loss 0.1470
# Validation epoch 16, loss 0.2493
# Training epoch 17, loss 0.1433
# Validation epoch 17, loss 0.2461
# Training epoch 18, loss 0.1387
# Validation epoch 18, loss 0.2261
# Training epoch 19, loss 0.1378
# Validation epoch 19, loss 0.2286
# Training epoch 20, loss 0.1272
# Validation epoch 20, loss 0.2215
# Training epoch 21, loss 0.1231
# Validation epoch 21, loss 0.2295
# Training epoch 22, loss 0.1212
# Validation epoch 22, loss 0.2164
# Training epoch 23, loss 0.1145
# Validation epoch 23, loss 0.2436
# Training epoch 24, loss 0.1116
# Validation epoch 24, loss 0.2321
# Training epoch 25, loss 0.1075
# Validation epoch 25, loss 0.2336
# Training epoch 26, loss 0.1091
# Validation epoch 26, loss 0.2356
# Training epoch 27, loss 0.1057
# Validation epoch 27, loss 0.2318
# Training epoch 28, loss 0.1072
# Validation epoch 28, loss 0.2414
# Training epoch 29, loss 0.1032
# Validation epoch 29, loss 0.2437
# Training epoch 30, loss 0.0993
# Validation epoch 30, loss 0.2339
# Training epoch 31, loss 0.1010
# Validation epoch 31, loss 0.2203
# Training epoch 32, loss 0.1008
# Validation epoch 32, loss 0.2482
# Training epoch 33, loss 0.1007
# Validation epoch 33, loss 0.2095
# Training epoch 34, loss 0.0952
# Validation epoch 34, loss 0.2144
# Training epoch 35, loss 0.0984
# Validation epoch 35, loss 0.2068
# Training epoch 36, loss 0.1020
# Validation epoch 36, loss 0.2300
# Training epoch 37, loss 0.1066
# Validation epoch 37, loss 0.2380
# Training epoch 38, loss 0.0980
# Validation epoch 38, loss 0.2184
# Training epoch 39, loss 0.0900
# Validation epoch 39, loss 0.1998
# Training epoch 40, loss 0.0864
# Validation epoch 40, loss 0.1987
# Training epoch 41, loss 0.0795
# Validation epoch 41, loss 0.2192
# Training epoch 42, loss 0.0781
# Validation epoch 42, loss 0.2021
# Training epoch 43, loss 0.0745
# Validation epoch 43, loss 0.1949
# Training epoch 44, loss 0.0753
# Validation epoch 44, loss 0.1857
# Training epoch 45, loss 0.0724
# Validation epoch 45, loss 0.1935
# Training epoch 46, loss 0.0706
# Validation epoch 46, loss 0.1831
# Training epoch 47, loss 0.0664
# Validation epoch 47, loss 0.1889
# Training epoch 48, loss 0.0660
# Validation epoch 48, loss 0.1964
# Training epoch 49, loss 0.0656
# Validation epoch 49, loss 0.1946
# Training epoch 50, loss 0.0663
# Validation epoch 50, loss 0.2014
# Training epoch 51, loss 0.0675
# Validation epoch 51, loss 0.2151
# Training epoch 52, loss 0.0724
# Validation epoch 52, loss 0.2079
# Training epoch 53, loss 0.0811
# Validation epoch 53, loss 0.2451
# Training epoch 54, loss 0.0914
# Validation epoch 54, loss 0.2176
# Training epoch 55, loss 0.0958
# Validation epoch 55, loss 0.2108
# Training epoch 56, loss 0.0971
# Validation epoch 56, loss 0.2406
# Training epoch 57, loss 0.0791
# Validation epoch 57, loss 0.1884
# Training epoch 58, loss 0.0663
# Validation epoch 58, loss 0.1811
# Training epoch 59, loss 0.0605
# Validation epoch 59, loss 0.1756
# Training epoch 60, loss 0.0553
# Validation epoch 60, loss 0.1774
# Training epoch 61, loss 0.0522
# Validation epoch 61, loss 0.1737
# Training epoch 62, loss 0.0487
# Validation epoch 62, loss 0.1743
# Training epoch 63, loss 0.0482
# Validation epoch 63, loss 0.1769
# Training epoch 64, loss 0.0461
# Validation epoch 64, loss 0.1714
# Training epoch 65, loss 0.0447
# Validation epoch 65, loss 0.1754
# Training epoch 66, loss 0.0445
# Validation epoch 66, loss 0.1759
# Training epoch 67, loss 0.0450
# Validation epoch 67, loss 0.1815
# Training epoch 68, loss 0.0438
# Validation epoch 68, loss 0.1773
# Training epoch 69, loss 0.0444
# Validation epoch 69, loss 0.1740
# Training epoch 70, loss 0.0442
# Validation epoch 70, loss 0.1799
# Training epoch 71, loss 0.0455
# Validation epoch 71, loss 0.1838
# Training epoch 72, loss 0.0463
# Validation epoch 72, loss 0.1764
# Training epoch 73, loss 0.0490
# Validation epoch 73, loss 0.1766
# Training epoch 74, loss 0.0464
# Validation epoch 74, loss 0.1756
# Training epoch 75, loss 0.0490
# Validation epoch 75, loss 0.1735
# Training epoch 76, loss 0.0530
# Validation epoch 76, loss 0.1724
# Training epoch 77, loss 0.0655
# Validation epoch 77, loss 0.1947
# Training epoch 78, loss 0.0572
# Validation epoch 78, loss 0.1800
# Training epoch 79, loss 0.0468
# Validation epoch 79, loss 0.1809
# Training epoch 80, loss 0.0434
# Validation epoch 80, loss 0.1909
# Training epoch 81, loss 0.0459
# Validation epoch 81, loss 0.1773
# Training epoch 82, loss 0.0380
# Validation epoch 82, loss 0.1681
# Training epoch 83, loss 0.0355
# Validation epoch 83, loss 0.1673
# Training epoch 84, loss 0.0354
# Validation epoch 84, loss 0.1682
# Training epoch 85, loss 0.0342
# Validation epoch 85, loss 0.1711
# Training epoch 86, loss 0.0345
# Validation epoch 86, loss 0.1672
# Training epoch 87, loss 0.0339
# Validation epoch 87, loss 0.1734
# Training epoch 88, loss 0.0361
# Validation epoch 88, loss 0.1729
# Training epoch 89, loss 0.0395
# Validation epoch 89, loss 0.1680
# Training epoch 90, loss 0.0398
# Validation epoch 90, loss 0.1680
# Training epoch 91, loss 0.0394
# Validation epoch 91, loss 0.1700
# Training epoch 92, loss 0.0412
# Validation epoch 92, loss 0.1730
# Training epoch 93, loss 0.0490
# Validation epoch 93, loss 0.1807
# Training epoch 94, loss 0.0477
# Validation epoch 94, loss 0.2000
# Training epoch 95, loss 0.0408
# Validation epoch 95, loss 0.1844
# Training epoch 96, loss 0.0354
# Validation epoch 96, loss 0.1723
# Training epoch 97, loss 0.0328
# Validation epoch 97, loss 0.1733
# Training epoch 98, loss 0.0322
# Validation epoch 98, loss 0.1826
# Training epoch 99, loss 0.0317
# Validation epoch 99, loss 0.1680
# Training epoch 0, loss 19.7054
# Validation epoch 0, loss 0.5424
# Training epoch 1, loss 0.6624
# Validation epoch 1, loss 0.3977
# Training epoch 2, loss 0.5579
# Validation epoch 2, loss 0.4041
# Training epoch 3, loss 0.4817
# Validation epoch 3, loss 0.3359
# Training epoch 4, loss 0.3825
# Validation epoch 4, loss 0.3290
# Training epoch 5, loss 0.3171
# Validation epoch 5, loss 0.3364
# Training epoch 6, loss 0.2756
# Validation epoch 6, loss 0.2703
# Training epoch 7, loss 0.2492
# Validation epoch 7, loss 0.2603
# Training epoch 8, loss 0.2259
# Validation epoch 8, loss 0.2488
# Training epoch 9, loss 0.2127
# Validation epoch 9, loss 0.2457
# Training epoch 10, loss 0.1975
# Validation epoch 10, loss 0.2578
# Training epoch 11, loss 0.1881
# Validation epoch 11, loss 0.2589
# Training epoch 12, loss 0.1794
# Validation epoch 12, loss 0.2334
# Training epoch 13, loss 0.1703
# Validation epoch 13, loss 0.2412
# Training epoch 14, loss 0.1622
# Validation epoch 14, loss 0.2245
# Training epoch 15, loss 0.1516
# Validation epoch 15, loss 0.2285
# Training epoch 16, loss 0.1477
# Validation epoch 16, loss 0.2248
# Training epoch 17, loss 0.1430
# Validation epoch 17, loss 0.2170
# Training epoch 18, loss 0.1367
# Validation epoch 18, loss 0.2431
# Training epoch 19, loss 0.1336
# Validation epoch 19, loss 0.2190
# Training epoch 20, loss 0.1300
# Validation epoch 20, loss 0.2275
# Training epoch 21, loss 0.1252
# Validation epoch 21, loss 0.2191
# Training epoch 22, loss 0.1260
# Validation epoch 22, loss 0.2125
# Training epoch 23, loss 0.1243
# Validation epoch 23, loss 0.2217
# Training epoch 24, loss 0.1196
# Validation epoch 24, loss 0.2139
# Training epoch 25, loss 0.1128
# Validation epoch 25, loss 0.2333
# Training epoch 26, loss 0.1089
# Validation epoch 26, loss 0.2168
# Training epoch 27, loss 0.1061
# Validation epoch 27, loss 0.2133
# Training epoch 28, loss 0.1025
# Validation epoch 28, loss 0.2260
# Training epoch 29, loss 0.0978
# Validation epoch 29, loss 0.2130
# Training epoch 30, loss 0.0961
# Validation epoch 30, loss 0.2036
# Training epoch 31, loss 0.0952
# Validation epoch 31, loss 0.2078
# Training epoch 32, loss 0.0983
# Validation epoch 32, loss 0.2238
# Training epoch 33, loss 0.0958
# Validation epoch 33, loss 0.2088
# Training epoch 34, loss 0.0903
# Validation epoch 34, loss 0.2117
# Training epoch 35, loss 0.0954
# Validation epoch 35, loss 0.1964
# Training epoch 36, loss 0.0927
# Validation epoch 36, loss 0.2043
# Training epoch 37, loss 0.0997
# Validation epoch 37, loss 0.2006
# Training epoch 38, loss 0.0958
# Validation epoch 38, loss 0.1910
# Training epoch 39, loss 0.0949
# Validation epoch 39, loss 0.2030
# Training epoch 40, loss 0.0878
# Validation epoch 40, loss 0.1999
# Training epoch 41, loss 0.0842
# Validation epoch 41, loss 0.1999
# Training epoch 42, loss 0.0815
# Validation epoch 42, loss 0.1997
# Training epoch 43, loss 0.0775
# Validation epoch 43, loss 0.1953
# Training epoch 44, loss 0.0721
# Validation epoch 44, loss 0.1894
# Training epoch 45, loss 0.0697
# Validation epoch 45, loss 0.1872
# Training epoch 46, loss 0.0678
# Validation epoch 46, loss 0.1914
# Training epoch 47, loss 0.0686
# Validation epoch 47, loss 0.1866
# Training epoch 48, loss 0.0636
# Validation epoch 48, loss 0.1942
# Training epoch 49, loss 0.0628
# Validation epoch 49, loss 0.1864
# Training epoch 50, loss 0.0616
# Validation epoch 50, loss 0.1855
# Training epoch 51, loss 0.0649
# Validation epoch 51, loss 0.1899
# Training epoch 52, loss 0.0689
# Validation epoch 52, loss 0.2104
# Training epoch 53, loss 0.0763
# Validation epoch 53, loss 0.1860
# Training epoch 54, loss 0.0764
# Validation epoch 54, loss 0.1961
# Training epoch 55, loss 0.0728
# Validation epoch 55, loss 0.2056
# Training epoch 56, loss 0.0714
# Validation epoch 56, loss 0.1892
# Training epoch 57, loss 0.0668
# Validation epoch 57, loss 0.1846
# Training epoch 58, loss 0.0637
# Validation epoch 58, loss 0.1859
# Training epoch 59, loss 0.0633
# Validation epoch 59, loss 0.2180
# Training epoch 60, loss 0.0693
# Validation epoch 60, loss 0.1947
# Training epoch 61, loss 0.0682
# Validation epoch 61, loss 0.1834
# Training epoch 62, loss 0.0674
# Validation epoch 62, loss 0.1852
# Training epoch 63, loss 0.0681
# Validation epoch 63, loss 0.1918
# Training epoch 64, loss 0.0677
# Validation epoch 64, loss 0.2077
# Training epoch 65, loss 0.0626
# Validation epoch 65, loss 0.2032
# Training epoch 66, loss 0.0599
# Validation epoch 66, loss 0.2036
# Training epoch 67, loss 0.0607
# Validation epoch 67, loss 0.1947
# Training epoch 68, loss 0.0612
# Validation epoch 68, loss 0.2120
# Training epoch 69, loss 0.0693
# Validation epoch 69, loss 0.2220
# Training epoch 70, loss 0.0684
# Validation epoch 70, loss 0.1857
# Training epoch 71, loss 0.0615
# Validation epoch 71, loss 0.1779
# Training epoch 72, loss 0.0536
# Validation epoch 72, loss 0.1779
# Training epoch 73, loss 0.0491
# Validation epoch 73, loss 0.1809
# Training epoch 74, loss 0.0497
# Validation epoch 74, loss 0.1763
# Training epoch 75, loss 0.0474
# Validation epoch 75, loss 0.1764
# Training epoch 76, loss 0.0473
# Validation epoch 76, loss 0.1919
# Training epoch 77, loss 0.0472
# Validation epoch 77, loss 0.1786
# Training epoch 78, loss 0.0468
# Validation epoch 78, loss 0.1777
# Training epoch 79, loss 0.0488
# Validation epoch 79, loss 0.2206
# Training epoch 80, loss 0.0560
# Validation epoch 80, loss 0.2204
# Training epoch 81, loss 0.0675
# Validation epoch 81, loss 0.3057
# Training epoch 82, loss 0.0841
# Validation epoch 82, loss 0.2793
# Training epoch 83, loss 0.0720
# Validation epoch 83, loss 0.1984
# Training epoch 84, loss 0.0545
# Validation epoch 84, loss 0.1743
# Training epoch 85, loss 0.0514
# Validation epoch 85, loss 0.1711
# Training epoch 86, loss 0.0544
# Validation epoch 86, loss 0.1885
# Training epoch 87, loss 0.0584
# Validation epoch 87, loss 0.2005
# Training epoch 88, loss 0.0582
# Validation epoch 88, loss 0.1968
# Training epoch 89, loss 0.0560
# Validation epoch 89, loss 0.1851
# Training epoch 90, loss 0.0540
# Validation epoch 90, loss 0.1718
# Training epoch 91, loss 0.0521
# Validation epoch 91, loss 0.1758
# Training epoch 92, loss 0.0523
# Validation epoch 92, loss 0.1929
# Training epoch 93, loss 0.0503
# Validation epoch 93, loss 0.2134
# Training epoch 94, loss 0.0479
# Validation epoch 94, loss 0.2092
# Training epoch 95, loss 0.0455
# Validation epoch 95, loss 0.2004
# Training epoch 96, loss 0.0494
# Validation epoch 96, loss 0.1926
# Training epoch 97, loss 0.0538
# Validation epoch 97, loss 0.1889
# Training epoch 98, loss 0.0597
# Validation epoch 98, loss 0.1762
# Training epoch 99, loss 0.0612
# Validation epoch 99, loss 0.1760
# Training epoch 0, loss 16.3652
# Validation epoch 0, loss 0.5928
# Training epoch 1, loss 0.7139
# Validation epoch 1, loss 0.4046
# Training epoch 2, loss 0.5847
# Validation epoch 2, loss 0.5787
# Training epoch 3, loss 0.4416
# Validation epoch 3, loss 0.3852
# Training epoch 4, loss 0.3565
# Validation epoch 4, loss 0.3094
# Training epoch 5, loss 0.2959
# Validation epoch 5, loss 0.3097
# Training epoch 6, loss 0.2649
# Validation epoch 6, loss 0.2993
# Training epoch 7, loss 0.2457
# Validation epoch 7, loss 0.2639
# Training epoch 8, loss 0.2321
# Validation epoch 8, loss 0.2819
# Training epoch 9, loss 0.2156
# Validation epoch 9, loss 0.2901
# Training epoch 10, loss 0.2058
# Validation epoch 10, loss 0.2735
# Training epoch 11, loss 0.1952
# Validation epoch 11, loss 0.2768
# Training epoch 12, loss 0.1855
# Validation epoch 12, loss 0.2507
# Training epoch 13, loss 0.1761
# Validation epoch 13, loss 0.2629
# Training epoch 14, loss 0.1678
# Validation epoch 14, loss 0.2492
# Training epoch 15, loss 0.1678
# Validation epoch 15, loss 0.3012
# Training epoch 16, loss 0.1682
# Validation epoch 16, loss 0.2420
# Training epoch 17, loss 0.1558
# Validation epoch 17, loss 0.2791
# Training epoch 18, loss 0.1470
# Validation epoch 18, loss 0.2524
# Training epoch 19, loss 0.1408
# Validation epoch 19, loss 0.2315
# Training epoch 20, loss 0.1349
# Validation epoch 20, loss 0.2475
# Training epoch 21, loss 0.1305
# Validation epoch 21, loss 0.2289
# Training epoch 22, loss 0.1250
# Validation epoch 22, loss 0.2211
# Training epoch 23, loss 0.1316
# Validation epoch 23, loss 0.2311
# Training epoch 24, loss 0.1211
# Validation epoch 24, loss 0.2400
# Training epoch 25, loss 0.1300
# Validation epoch 25, loss 0.2162
# Training epoch 26, loss 0.1213
# Validation epoch 26, loss 0.2396
# Training epoch 27, loss 0.1191
# Validation epoch 27, loss 0.2036
# Training epoch 28, loss 0.1050
# Validation epoch 28, loss 0.2242
# Training epoch 29, loss 0.0998
# Validation epoch 29, loss 0.2062
# Training epoch 30, loss 0.0964
# Validation epoch 30, loss 0.2060
# Training epoch 31, loss 0.0948
# Validation epoch 31, loss 0.2059
# Training epoch 32, loss 0.0924
# Validation epoch 32, loss 0.2052
# Training epoch 33, loss 0.0919
# Validation epoch 33, loss 0.2028
# Training epoch 34, loss 0.0953
# Validation epoch 34, loss 0.2215
# Training epoch 35, loss 0.0911
# Validation epoch 35, loss 0.2225
# Training epoch 36, loss 0.0901
# Validation epoch 36, loss 0.2231
# Training epoch 37, loss 0.0932
# Validation epoch 37, loss 0.2178
# Training epoch 38, loss 0.0883
# Validation epoch 38, loss 0.2042
# Training epoch 39, loss 0.0848
# Validation epoch 39, loss 0.2005
# Training epoch 40, loss 0.0847
# Validation epoch 40, loss 0.2018
# Training epoch 41, loss 0.0837
# Validation epoch 41, loss 0.2045
# Training epoch 42, loss 0.0793
# Validation epoch 42, loss 0.2031
# Training epoch 43, loss 0.0795
# Validation epoch 43, loss 0.1889
# Training epoch 44, loss 0.0776
# Validation epoch 44, loss 0.1938
# Training epoch 45, loss 0.0819
# Validation epoch 45, loss 0.1997
# Training epoch 46, loss 0.0778
# Validation epoch 46, loss 0.1965
# Training epoch 47, loss 0.0764
# Validation epoch 47, loss 0.2096
# Training epoch 48, loss 0.0696
# Validation epoch 48, loss 0.1936
# Training epoch 49, loss 0.0700
# Validation epoch 49, loss 0.1998
# Training epoch 50, loss 0.0676
# Validation epoch 50, loss 0.2120
# Training epoch 51, loss 0.0655
# Validation epoch 51, loss 0.2014
# Training epoch 52, loss 0.0676
# Validation epoch 52, loss 0.2302
# Training epoch 53, loss 0.0691
# Validation epoch 53, loss 0.2510
# Training epoch 54, loss 0.0763
# Validation epoch 54, loss 0.1948
# Training epoch 55, loss 0.0675
# Validation epoch 55, loss 0.2082
# Training epoch 56, loss 0.0622
# Validation epoch 56, loss 0.1914
# Training epoch 57, loss 0.0617
# Validation epoch 57, loss 0.1946
# Training epoch 58, loss 0.0598
# Validation epoch 58, loss 0.1986
# Training epoch 59, loss 0.0608
# Validation epoch 59, loss 0.1858
# Training epoch 60, loss 0.0572
# Validation epoch 60, loss 0.1916
# Training epoch 61, loss 0.0616
# Validation epoch 61, loss 0.1903
# Training epoch 62, loss 0.0544
# Validation epoch 62, loss 0.1828
# Training epoch 63, loss 0.0526
# Validation epoch 63, loss 0.2069
# Training epoch 64, loss 0.0522
# Validation epoch 64, loss 0.1960
# Training epoch 65, loss 0.0518
# Validation epoch 65, loss 0.1954
# Training epoch 66, loss 0.0511
# Validation epoch 66, loss 0.1939
# Training epoch 67, loss 0.0550
# Validation epoch 67, loss 0.1840
# Training epoch 68, loss 0.0584
# Validation epoch 68, loss 0.1925
# Training epoch 69, loss 0.0616
# Validation epoch 69, loss 0.2067
# Training epoch 70, loss 0.0680
# Validation epoch 70, loss 0.2340
# Training epoch 71, loss 0.0708
# Validation epoch 71, loss 0.2286
# Training epoch 72, loss 0.0648
# Validation epoch 72, loss 0.1839
# Training epoch 73, loss 0.0585
# Validation epoch 73, loss 0.1780
# Training epoch 74, loss 0.0520
# Validation epoch 74, loss 0.1761
# Training epoch 75, loss 0.0516
# Validation epoch 75, loss 0.1828
# Training epoch 76, loss 0.0518
# Validation epoch 76, loss 0.1898
# Training epoch 77, loss 0.0520
# Validation epoch 77, loss 0.1873
# Training epoch 78, loss 0.0478
# Validation epoch 78, loss 0.1779
# Training epoch 79, loss 0.0427
# Validation epoch 79, loss 0.1800
# Training epoch 80, loss 0.0416
# Validation epoch 80, loss 0.1945
# Training epoch 81, loss 0.0444
# Validation epoch 81, loss 0.1869
# Training epoch 82, loss 0.0431
# Validation epoch 82, loss 0.1899
# Training epoch 83, loss 0.0425
# Validation epoch 83, loss 0.1916
# Training epoch 84, loss 0.0473
# Validation epoch 84, loss 0.2011
# Training epoch 85, loss 0.0471
# Validation epoch 85, loss 0.2241
# Training epoch 86, loss 0.0445
# Validation epoch 86, loss 0.1900
# Training epoch 87, loss 0.0477
# Validation epoch 87, loss 0.1791
# Training epoch 88, loss 0.0440
# Validation epoch 88, loss 0.1809
# Training epoch 89, loss 0.0401
# Validation epoch 89, loss 0.1722
# Training epoch 90, loss 0.0408
# Validation epoch 90, loss 0.1763
# Training epoch 91, loss 0.0395
# Validation epoch 91, loss 0.1824
# Training epoch 92, loss 0.0426
# Validation epoch 92, loss 0.1848
# Training epoch 93, loss 0.0499
# Validation epoch 93, loss 0.2240
# Training epoch 94, loss 0.0467
# Validation epoch 94, loss 0.2093
# Training epoch 95, loss 0.0423
# Validation epoch 95, loss 0.1870
# Training epoch 96, loss 0.0421
# Validation epoch 96, loss 0.1943
# Training epoch 97, loss 0.0401
# Validation epoch 97, loss 0.1927
# Training epoch 98, loss 0.0395
# Validation epoch 98, loss 0.1813
# Training epoch 99, loss 0.0497
# Validation epoch 99, loss 0.1842
# 5-fold CVMSE: 0.16967267200667804
