# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:(2**16+2**15)+(2**13)-1, "uniprotID"]    # 5
ligand = dataset.loc[:(2**16+2**15)+(2**13)-1, "chemblID"]
kiba = list(dataset.loc[:(2**16+2**15)+(2**13)-1, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros(((2**16+2**15)+(2**13), 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :1400]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros(((2**16+2**15)+(2**13), 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, smileseq, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**16+2**15]
validset = shuffled_dataset[2**16+2**15:(2**16+2**15) + (2**13)]

del shuffled_dataset

# %%
#%% Make collate func.
def collate(samples):
    sequences, smileseq, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_emlayer = nn.Embedding(21, 10)
        
        self.prt_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 12),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size=1379)
                        )

        ######################################################################
        ######################################################################
        
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
            
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(192, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, prt_seq, lgn_seq):   
        p = self.prt_emlayer(prt_seq)
        p = p.permute(0, 2, 1)
        p = self.prt_cv1dlayers(p)
        p = p.squeeze()
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p, l), axis=1).cuda()
        out = self.mlplayers(cat)
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 256
hp_d['num_epochs'] = 300

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% training and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
# optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
#     weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

optimizer = optim.Adam(model.parameters(), lr=0.001)

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.6985213481988329
# va_var: 0.692295664014448
# total params: 3249107
# Training epoch 0, loss 7.4863
# Validation epoch 0, loss 0.6014
# Training epoch 1, loss 0.5044
# Validation epoch 1, loss 0.4548
# Training epoch 2, loss 0.4014
# Validation epoch 2, loss 0.3718
# Training epoch 3, loss 0.3624
# Validation epoch 3, loss 0.3475
# Training epoch 4, loss 0.3451
# Validation epoch 4, loss 0.3411
# Training epoch 5, loss 0.3221
# Validation epoch 5, loss 0.4122
# Training epoch 6, loss 0.3136
# Validation epoch 6, loss 0.3289
# Training epoch 7, loss 0.3023
# Validation epoch 7, loss 0.3048
# Training epoch 8, loss 0.2870
# Validation epoch 8, loss 0.2950
# Training epoch 9, loss 0.2701
# Validation epoch 9, loss 0.2999
# Training epoch 10, loss 0.2545
# Validation epoch 10, loss 0.2621
# Training epoch 11, loss 0.2437
# Validation epoch 11, loss 0.3270
# Training epoch 12, loss 0.2373
# Validation epoch 12, loss 0.2529
# Training epoch 13, loss 0.2272
# Validation epoch 13, loss 0.2616
# Training epoch 14, loss 0.2218
# Validation epoch 14, loss 0.2625
# Training epoch 15, loss 0.2086
# Validation epoch 15, loss 0.2805
# Training epoch 16, loss 0.2037
# Validation epoch 16, loss 0.2866
# Training epoch 17, loss 0.1899
# Validation epoch 17, loss 0.2815
# Training epoch 18, loss 0.1815
# Validation epoch 18, loss 0.2807
# Training epoch 19, loss 0.1746
# Validation epoch 19, loss 0.2405
# Training epoch 20, loss 0.1768
# Validation epoch 20, loss 0.3021
# Training epoch 21, loss 0.1778
# Validation epoch 21, loss 0.2521
# Training epoch 22, loss 0.1606
# Validation epoch 22, loss 0.2971
# Training epoch 23, loss 0.1543
# Validation epoch 23, loss 0.2692
# Training epoch 24, loss 0.1491
# Validation epoch 24, loss 0.2374
# Training epoch 25, loss 0.1462
# Validation epoch 25, loss 0.2355
# Training epoch 26, loss 0.1396
# Validation epoch 26, loss 0.2396
# Training epoch 27, loss 0.1388
# Validation epoch 27, loss 0.2587
# Training epoch 28, loss 0.1329
# Validation epoch 28, loss 0.2143
# Training epoch 29, loss 0.1327
# Validation epoch 29, loss 0.2125
# Training epoch 30, loss 0.1255
# Validation epoch 30, loss 0.1977
# Training epoch 31, loss 0.1174
# Validation epoch 31, loss 0.2045
# Training epoch 32, loss 0.1178
# Validation epoch 32, loss 0.2061
# Training epoch 33, loss 0.1241
# Validation epoch 33, loss 0.1942
# Training epoch 34, loss 0.1227
# Validation epoch 34, loss 0.2101
# Training epoch 35, loss 0.1144
# Validation epoch 35, loss 0.1875
# Training epoch 36, loss 0.1119
# Validation epoch 36, loss 0.2035
# Training epoch 37, loss 0.1125
# Validation epoch 37, loss 0.1911
# Training epoch 38, loss 0.1105
# Validation epoch 38, loss 0.1952
# Training epoch 39, loss 0.1096
# Validation epoch 39, loss 0.2010
# Training epoch 40, loss 0.1181
# Validation epoch 40, loss 0.1893
# Training epoch 41, loss 0.1129
# Validation epoch 41, loss 0.1850
# Training epoch 42, loss 0.1056
# Validation epoch 42, loss 0.1885
# Training epoch 43, loss 0.1010
# Validation epoch 43, loss 0.1901
# Training epoch 44, loss 0.0957
# Validation epoch 44, loss 0.1960
# Training epoch 45, loss 0.0946
# Validation epoch 45, loss 0.2045
# Training epoch 46, loss 0.0986
# Validation epoch 46, loss 0.2370
# Training epoch 47, loss 0.0992
# Validation epoch 47, loss 0.2453
# Training epoch 48, loss 0.1024
# Validation epoch 48, loss 0.2232
# Training epoch 49, loss 0.1048
# Validation epoch 49, loss 0.2335
# Training epoch 50, loss 0.0958
# Validation epoch 50, loss 0.2635
# Training epoch 51, loss 0.0874
# Validation epoch 51, loss 0.2103
# Training epoch 52, loss 0.0886
# Validation epoch 52, loss 0.1967
# Training epoch 53, loss 0.0877
# Validation epoch 53, loss 0.1954
# Training epoch 54, loss 0.0884
# Validation epoch 54, loss 0.2179
# Training epoch 55, loss 0.0871
# Validation epoch 55, loss 0.2318
# Training epoch 56, loss 0.0843
# Validation epoch 56, loss 0.1917
# Training epoch 57, loss 0.0809
# Validation epoch 57, loss 0.1918
# Training epoch 58, loss 0.0801
# Validation epoch 58, loss 0.1866
# Training epoch 59, loss 0.0827
# Validation epoch 59, loss 0.1853
# Training epoch 60, loss 0.0833
# Validation epoch 60, loss 0.2466
# Training epoch 61, loss 0.0836
# Validation epoch 61, loss 0.2330
# Training epoch 62, loss 0.0822
# Validation epoch 62, loss 0.1922
# Training epoch 63, loss 0.0752
# Validation epoch 63, loss 0.1995
# Training epoch 64, loss 0.0690
# Validation epoch 64, loss 0.1692
# Training epoch 65, loss 0.0681
# Validation epoch 65, loss 0.1918
# Training epoch 66, loss 0.0710
# Validation epoch 66, loss 0.1823
# Training epoch 67, loss 0.0809
# Validation epoch 67, loss 0.1920
# Training epoch 68, loss 0.0948
# Validation epoch 68, loss 0.2280
# Training epoch 69, loss 0.0980
# Validation epoch 69, loss 0.2940
# Training epoch 70, loss 0.0922
# Validation epoch 70, loss 0.2972
# Training epoch 71, loss 0.0852
# Validation epoch 71, loss 0.2754
# Training epoch 72, loss 0.0794
# Validation epoch 72, loss 0.1864
# Training epoch 73, loss 0.0781
# Validation epoch 73, loss 0.2470
# Training epoch 74, loss 0.0796
# Validation epoch 74, loss 0.2861
# Training epoch 75, loss 0.0784
# Validation epoch 75, loss 0.3017
# Training epoch 76, loss 0.0828
# Validation epoch 76, loss 0.2264
# Training epoch 77, loss 0.0812
# Validation epoch 77, loss 0.1762
# Training epoch 78, loss 0.0747
# Validation epoch 78, loss 0.1758
# Training epoch 79, loss 0.0725
# Validation epoch 79, loss 0.2016
# Training epoch 80, loss 0.0745
# Validation epoch 80, loss 0.2628
# Training epoch 81, loss 0.0702
# Validation epoch 81, loss 0.2981
# Training epoch 82, loss 0.0692
# Validation epoch 82, loss 0.2074
# Training epoch 83, loss 0.0753
# Validation epoch 83, loss 0.1646
# Training epoch 84, loss 0.0793
# Validation epoch 84, loss 0.1651
# Training epoch 85, loss 0.0817
# Validation epoch 85, loss 0.1891
# Training epoch 86, loss 0.0759
# Validation epoch 86, loss 0.1635
# Training epoch 87, loss 0.0684
# Validation epoch 87, loss 0.1623
# Training epoch 88, loss 0.0633
# Validation epoch 88, loss 0.1688
# Training epoch 89, loss 0.0630
# Validation epoch 89, loss 0.1800
# Training epoch 90, loss 0.0660
# Validation epoch 90, loss 0.2027
# Training epoch 91, loss 0.0675
# Validation epoch 91, loss 0.1697
# Training epoch 92, loss 0.0748
# Validation epoch 92, loss 0.1692
# Training epoch 93, loss 0.0811
# Validation epoch 93, loss 0.1912
# Training epoch 94, loss 0.0762
# Validation epoch 94, loss 0.1616
# Training epoch 95, loss 0.0759
# Validation epoch 95, loss 0.1659
# Training epoch 96, loss 0.0730
# Validation epoch 96, loss 0.1614
# Training epoch 97, loss 0.0716
# Validation epoch 97, loss 0.1653
# Training epoch 98, loss 0.0683
# Validation epoch 98, loss 0.1667
# Training epoch 99, loss 0.0700
# Validation epoch 99, loss 0.1838
# Training epoch 100, loss 0.0658
# Validation epoch 100, loss 0.1637
# Training epoch 101, loss 0.0642
# Validation epoch 101, loss 0.1654
# Training epoch 102, loss 0.0662
# Validation epoch 102, loss 0.1933
# Training epoch 103, loss 0.0668
# Validation epoch 103, loss 0.1705
# Training epoch 104, loss 0.0668
# Validation epoch 104, loss 0.1696
# Training epoch 105, loss 0.0653
# Validation epoch 105, loss 0.1889
# Training epoch 106, loss 0.0649
# Validation epoch 106, loss 0.2162
# Training epoch 107, loss 0.0676
# Validation epoch 107, loss 0.2364
# Training epoch 108, loss 0.0673
# Validation epoch 108, loss 0.1864
# Training epoch 109, loss 0.0649
# Validation epoch 109, loss 0.2056
# Training epoch 110, loss 0.0634
# Validation epoch 110, loss 0.3016
# Training epoch 111, loss 0.0620
# Validation epoch 111, loss 0.2544
# Training epoch 112, loss 0.0609
# Validation epoch 112, loss 0.1650
# Training epoch 113, loss 0.0648
# Validation epoch 113, loss 0.1804
# Training epoch 114, loss 0.0646
# Validation epoch 114, loss 0.2087
# Training epoch 115, loss 0.0641
# Validation epoch 115, loss 0.2381
# Training epoch 116, loss 0.0637
# Validation epoch 116, loss 0.2321
# Training epoch 117, loss 0.0638
# Validation epoch 117, loss 0.1898
# Training epoch 118, loss 0.0632
# Validation epoch 118, loss 0.1607
# Training epoch 119, loss 0.0653
# Validation epoch 119, loss 0.1615
# Training epoch 120, loss 0.0644
# Validation epoch 120, loss 0.1692
# Training epoch 121, loss 0.0614
# Validation epoch 121, loss 0.1702
# Training epoch 122, loss 0.0555
# Validation epoch 122, loss 0.1568
# Training epoch 123, loss 0.0541
# Validation epoch 123, loss 0.1577
# Training epoch 124, loss 0.0532
# Validation epoch 124, loss 0.1589
# Training epoch 125, loss 0.0550
# Validation epoch 125, loss 0.1627
# Training epoch 126, loss 0.0582
# Validation epoch 126, loss 0.1641
# Training epoch 127, loss 0.0593
# Validation epoch 127, loss 0.1623
# Training epoch 128, loss 0.0631
# Validation epoch 128, loss 0.1550
# Training epoch 129, loss 0.0655
# Validation epoch 129, loss 0.1580
# Training epoch 130, loss 0.0608
# Validation epoch 130, loss 0.1672
# Training epoch 131, loss 0.0592
# Validation epoch 131, loss 0.1668
# Training epoch 132, loss 0.0549
# Validation epoch 132, loss 0.1587
# Training epoch 133, loss 0.0534
# Validation epoch 133, loss 0.1669
# Training epoch 134, loss 0.0531
# Validation epoch 134, loss 0.1755
# Training epoch 135, loss 0.0561
# Validation epoch 135, loss 0.1649
# Training epoch 136, loss 0.0551
# Validation epoch 136, loss 0.1809
# Training epoch 137, loss 0.0553
# Validation epoch 137, loss 0.1896
# Training epoch 138, loss 0.0555
# Validation epoch 138, loss 0.1890
# Training epoch 139, loss 0.0567
# Validation epoch 139, loss 0.1912
# Training epoch 140, loss 0.0538
# Validation epoch 140, loss 0.1996
# Training epoch 141, loss 0.0508
# Validation epoch 141, loss 0.1841
# Training epoch 142, loss 0.0502
# Validation epoch 142, loss 0.1656
# Training epoch 143, loss 0.0528
# Validation epoch 143, loss 0.1965
# Training epoch 144, loss 0.0544
# Validation epoch 144, loss 0.1913
# Training epoch 145, loss 0.0526
# Validation epoch 145, loss 0.1910
# Training epoch 146, loss 0.0492
# Validation epoch 146, loss 0.1585
# Training epoch 147, loss 0.0477
# Validation epoch 147, loss 0.1850
# Training epoch 148, loss 0.0467
# Validation epoch 148, loss 0.2250
# Training epoch 149, loss 0.0485
# Validation epoch 149, loss 0.2012
# Training epoch 150, loss 0.0497
# Validation epoch 150, loss 0.1626
# Training epoch 151, loss 0.0543
# Validation epoch 151, loss 0.1715
# Training epoch 152, loss 0.0530
# Validation epoch 152, loss 0.2055
# Training epoch 153, loss 0.0491
# Validation epoch 153, loss 0.2143
# Training epoch 154, loss 0.0449
# Validation epoch 154, loss 0.1864
# Training epoch 155, loss 0.0425
# Validation epoch 155, loss 0.1598
# Training epoch 156, loss 0.0405
# Validation epoch 156, loss 0.1553
# Training epoch 157, loss 0.0399
# Validation epoch 157, loss 0.1718
# Training epoch 158, loss 0.0437
# Validation epoch 158, loss 0.1823
# Training epoch 159, loss 0.0456
# Validation epoch 159, loss 0.1661
# Training epoch 160, loss 0.0506
# Validation epoch 160, loss 0.1651
# Training epoch 161, loss 0.0507
# Validation epoch 161, loss 0.1728
# Training epoch 162, loss 0.0470
# Validation epoch 162, loss 0.1665
# Training epoch 163, loss 0.0461
# Validation epoch 163, loss 0.1677
# Training epoch 164, loss 0.0456
# Validation epoch 164, loss 0.1597
# Training epoch 165, loss 0.0470
# Validation epoch 165, loss 0.1658
# Training epoch 166, loss 0.0462
# Validation epoch 166, loss 0.1629
# Training epoch 167, loss 0.0462
# Validation epoch 167, loss 0.2079
# Training epoch 168, loss 0.0446
# Validation epoch 168, loss 0.1889
# Training epoch 169, loss 0.0451
# Validation epoch 169, loss 0.1583
# Training epoch 170, loss 0.0456
# Validation epoch 170, loss 0.1706
# Training epoch 171, loss 0.0421
# Validation epoch 171, loss 0.1596
# Training epoch 172, loss 0.0416
# Validation epoch 172, loss 0.1633
# Training epoch 173, loss 0.0438
# Validation epoch 173, loss 0.1659
# Training epoch 174, loss 0.0463
# Validation epoch 174, loss 0.1718
# Training epoch 175, loss 0.0435
# Validation epoch 175, loss 0.1640
# Training epoch 176, loss 0.0438
# Validation epoch 176, loss 0.1638
# Training epoch 177, loss 0.0433
# Validation epoch 177, loss 0.1740
# Training epoch 178, loss 0.0437
# Validation epoch 178, loss 0.1718
# Training epoch 179, loss 0.0463
# Validation epoch 179, loss 0.1567
# Training epoch 180, loss 0.0431
# Validation epoch 180, loss 0.1677
# Training epoch 181, loss 0.0386
# Validation epoch 181, loss 0.1671
# Training epoch 182, loss 0.0340
# Validation epoch 182, loss 0.1794
# Training epoch 183, loss 0.0314
# Validation epoch 183, loss 0.1906
# Training epoch 184, loss 0.0321
# Validation epoch 184, loss 0.2124
# Training epoch 185, loss 0.0343
# Validation epoch 185, loss 0.2156
# Training epoch 186, loss 0.0379
# Validation epoch 186, loss 0.1834
# Training epoch 187, loss 0.0446
# Validation epoch 187, loss 0.1878
# Training epoch 188, loss 0.0456
# Validation epoch 188, loss 0.2030
# Training epoch 189, loss 0.0474
# Validation epoch 189, loss 0.1952
# Training epoch 190, loss 0.0517
# Validation epoch 190, loss 0.1864
# Training epoch 191, loss 0.0470
# Validation epoch 191, loss 0.1590
# Training epoch 192, loss 0.0381
# Validation epoch 192, loss 0.1548
# Training epoch 193, loss 0.0319
# Validation epoch 193, loss 0.1512
# Training epoch 194, loss 0.0294
# Validation epoch 194, loss 0.1550
# Training epoch 195, loss 0.0281
# Validation epoch 195, loss 0.1607
# Training epoch 196, loss 0.0283
# Validation epoch 196, loss 0.1529
# Training epoch 197, loss 0.0336
# Validation epoch 197, loss 0.1681
# Training epoch 198, loss 0.0430
# Validation epoch 198, loss 0.1688
# Training epoch 199, loss 0.0407
# Validation epoch 199, loss 0.1601
# Training epoch 200, loss 0.0335
# Validation epoch 200, loss 0.1578
# Training epoch 201, loss 0.0276
# Validation epoch 201, loss 0.1710
# Training epoch 202, loss 0.0250
# Validation epoch 202, loss 0.1921
# Training epoch 203, loss 0.0260
# Validation epoch 203, loss 0.1998
# Training epoch 204, loss 0.0281
# Validation epoch 204, loss 0.1650
# Training epoch 205, loss 0.0348
# Validation epoch 205, loss 0.1770
# Training epoch 206, loss 0.0383
# Validation epoch 206, loss 0.1857
# Training epoch 207, loss 0.0378
# Validation epoch 207, loss 0.1644
# Training epoch 208, loss 0.0351
# Validation epoch 208, loss 0.1666
# Training epoch 209, loss 0.0300
# Validation epoch 209, loss 0.1949
# Training epoch 210, loss 0.0258
# Validation epoch 210, loss 0.1966
# Training epoch 211, loss 0.0264
# Validation epoch 211, loss 0.1628
# Training epoch 212, loss 0.0287
# Validation epoch 212, loss 0.1576
# Training epoch 213, loss 0.0315
# Validation epoch 213, loss 0.1648
# Training epoch 214, loss 0.0311
# Validation epoch 214, loss 0.1685
# Training epoch 215, loss 0.0295
# Validation epoch 215, loss 0.1864
# Training epoch 216, loss 0.0286
# Validation epoch 216, loss 0.1959
# Training epoch 217, loss 0.0270
# Validation epoch 217, loss 0.1744
# Training epoch 218, loss 0.0265
# Validation epoch 218, loss 0.1658
# Training epoch 219, loss 0.0269
# Validation epoch 219, loss 0.1707
# Training epoch 220, loss 0.0278
# Validation epoch 220, loss 0.1678
# Training epoch 221, loss 0.0290
# Validation epoch 221, loss 0.1609
# Training epoch 222, loss 0.0299
# Validation epoch 222, loss 0.1914
# Training epoch 223, loss 0.0303
# Validation epoch 223, loss 0.1852
# Training epoch 224, loss 0.0303
# Validation epoch 224, loss 0.1622
# Training epoch 225, loss 0.0305
# Validation epoch 225, loss 0.1767
# Training epoch 226, loss 0.0308
# Validation epoch 226, loss 0.1652
# Training epoch 227, loss 0.0285
# Validation epoch 227, loss 0.1616
# Training epoch 228, loss 0.0257
# Validation epoch 228, loss 0.1646
# Training epoch 229, loss 0.0270
# Validation epoch 229, loss 0.1566
# Training epoch 230, loss 0.0276
# Validation epoch 230, loss 0.1927
# Training epoch 231, loss 0.0321
# Validation epoch 231, loss 0.1667
# Training epoch 232, loss 0.0337
# Validation epoch 232, loss 0.1585
# Training epoch 233, loss 0.0325
# Validation epoch 233, loss 0.1606
# Training epoch 234, loss 0.0332
# Validation epoch 234, loss 0.1857
# Training epoch 235, loss 0.0334
# Validation epoch 235, loss 0.1812
# Training epoch 236, loss 0.0358
# Validation epoch 236, loss 0.1678
# Training epoch 237, loss 0.0345
# Validation epoch 237, loss 0.1885
# Training epoch 238, loss 0.0338
# Validation epoch 238, loss 0.1889
# Training epoch 239, loss 0.0316
# Validation epoch 239, loss 0.1712
# Training epoch 240, loss 0.0305
# Validation epoch 240, loss 0.1612
# Training epoch 241, loss 0.0292
# Validation epoch 241, loss 0.1678
# Training epoch 242, loss 0.0284
# Validation epoch 242, loss 0.1908
# Training epoch 243, loss 0.0292
# Validation epoch 243, loss 0.1771
# Training epoch 244, loss 0.0299
# Validation epoch 244, loss 0.1598
# Training epoch 245, loss 0.0326
# Validation epoch 245, loss 0.1832
# Training epoch 246, loss 0.0329
# Validation epoch 246, loss 0.2090
# Training epoch 247, loss 0.0321
# Validation epoch 247, loss 0.1713
# Training epoch 248, loss 0.0299
# Validation epoch 248, loss 0.1651
# Training epoch 249, loss 0.0251
# Validation epoch 249, loss 0.1833
# Training epoch 250, loss 0.0228
# Validation epoch 250, loss 0.1930
# Training epoch 251, loss 0.0225
# Validation epoch 251, loss 0.1756
# Training epoch 252, loss 0.0254
# Validation epoch 252, loss 0.1593
# Training epoch 253, loss 0.0278
# Validation epoch 253, loss 0.1679
# Training epoch 254, loss 0.0328
# Validation epoch 254, loss 0.2071
# Training epoch 255, loss 0.0374
# Validation epoch 255, loss 0.1852
# Training epoch 256, loss 0.0342
# Validation epoch 256, loss 0.1653
# Training epoch 257, loss 0.0275
# Validation epoch 257, loss 0.1783
# Training epoch 258, loss 0.0233
# Validation epoch 258, loss 0.1596
# Training epoch 259, loss 0.0213
# Validation epoch 259, loss 0.1518
# Training epoch 260, loss 0.0208
# Validation epoch 260, loss 0.1627
# Training epoch 261, loss 0.0221
# Validation epoch 261, loss 0.1824
# Training epoch 262, loss 0.0257
# Validation epoch 262, loss 0.1959
# Training epoch 263, loss 0.0328
# Validation epoch 263, loss 0.1737
# Training epoch 264, loss 0.0365
# Validation epoch 264, loss 0.1629
# Training epoch 265, loss 0.0340
# Validation epoch 265, loss 0.1656
# Training epoch 266, loss 0.0280
# Validation epoch 266, loss 0.1608
# Training epoch 267, loss 0.0241
# Validation epoch 267, loss 0.1636
# Training epoch 268, loss 0.0233
# Validation epoch 268, loss 0.1704
# Training epoch 269, loss 0.0246
# Validation epoch 269, loss 0.1761
# Training epoch 270, loss 0.0255
# Validation epoch 270, loss 0.1844
# Training epoch 271, loss 0.0285
# Validation epoch 271, loss 0.1686
# Training epoch 272, loss 0.0331
# Validation epoch 272, loss 0.1659
# Training epoch 273, loss 0.0347
# Validation epoch 273, loss 0.1688
# Training epoch 274, loss 0.0309
# Validation epoch 274, loss 0.1587
# Training epoch 275, loss 0.0244
# Validation epoch 275, loss 0.1614
# Training epoch 276, loss 0.0213
# Validation epoch 276, loss 0.1622
# Training epoch 277, loss 0.0203
# Validation epoch 277, loss 0.1666
# Training epoch 278, loss 0.0209
# Validation epoch 278, loss 0.1613
# Training epoch 279, loss 0.0242
# Validation epoch 279, loss 0.1614
# Training epoch 280, loss 0.0304
# Validation epoch 280, loss 0.1679
# Training epoch 281, loss 0.0305
# Validation epoch 281, loss 0.1619
# Training epoch 282, loss 0.0308
# Validation epoch 282, loss 0.1723
# Training epoch 283, loss 0.0287
# Validation epoch 283, loss 0.1875
# Training epoch 284, loss 0.0244
# Validation epoch 284, loss 0.1728
# Training epoch 285, loss 0.0219
# Validation epoch 285, loss 0.1613
# Training epoch 286, loss 0.0212
# Validation epoch 286, loss 0.1683
# Training epoch 287, loss 0.0215
# Validation epoch 287, loss 0.1680
# Training epoch 288, loss 0.0231
# Validation epoch 288, loss 0.1621
# Training epoch 289, loss 0.0262
# Validation epoch 289, loss 0.1690
# Training epoch 290, loss 0.0297
# Validation epoch 290, loss 0.1857
# Training epoch 291, loss 0.0265
# Validation epoch 291, loss 0.1716
# Training epoch 292, loss 0.0229
# Validation epoch 292, loss 0.1630
# Training epoch 293, loss 0.0213
# Validation epoch 293, loss 0.1651
# Training epoch 294, loss 0.0199
# Validation epoch 294, loss 0.1681
# Training epoch 295, loss 0.0225
# Validation epoch 295, loss 0.1682
# Training epoch 296, loss 0.0251
# Validation epoch 296, loss 0.1599
# Training epoch 297, loss 0.0273
# Validation epoch 297, loss 0.1698
# Training epoch 298, loss 0.0252
# Validation epoch 298, loss 0.1761
# Training epoch 299, loss 0.0235
# Validation epoch 299, loss 0.1673
# time elapsed: 12484.72572684288

# %%
#%%
np.save('ModifiedDeepDTA_v6_2_tr_losses', tr_epoch_losses)
np.save('ModifiedDeepDTA_v6_2_va_losses', va_epoch_losses)

# %%
min(va_epoch_losses)
# Out:
# 0.15121634560637176
