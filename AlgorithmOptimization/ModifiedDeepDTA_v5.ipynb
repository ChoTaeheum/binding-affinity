# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:(2**16+2**15)+(2**13)-1, "uniprotID"]    # 5
ligand = dataset.loc[:(2**16+2**15)+(2**13)-1, "chemblID"]
kiba = list(dataset.loc[:(2**16+2**15)+(2**13)-1, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros(((2**16+2**15)+(2**13), 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :1400]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros(((2**16+2**15)+(2**13), 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]
    
smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, smileseq, kiba))
shuffled_dataset = shuffle(revised_dataset); del revised_dataset
trainset = shuffled_dataset[:2**16+2**15]
validset = shuffled_dataset[2**16+2**15:(2**16+2**15) + (2**13)]

del shuffled_dataset

# %%
#%% Make collate func.
def collate(samples):
    sequences, smileseq, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%%
class Conv1d(nn.Module):
    def __init__(self, in_planes, out_planes, kernel_size, stride, padding=0):
        super(Conv1d, self).__init__()
        
        self.conv = nn.Conv1d(in_planes, out_planes,
                              kernel_size=9, stride=stride,
                              padding=padding, bias=False) # verify bias false
        self.bn = nn.BatchNorm1d(out_planes,
                                 eps=0.001, # value found in tensorflow
                                 momentum=0.1, # default pytorch value
                                 affine=True)

    def forward(self, x):
        x = self.conv(x)
        out = self.bn(x)
        return out
    
    
class Block1(nn.Module):
    def __init__(self):
        super(Block1, self).__init__()
        
        self.conv = nn.Sequential(
            Conv1d(32, 32, kernel_size=10, stride=1),
            nn.ReLU(),
            nn.MaxPool1d(2)         
            )
        
    def forward(self, x):
        out = self.conv(x)
        return out
    
    
class IBlock(nn.Module):
    def __init__(self, in_planes, out_planes):
        super(IBlock, self).__init__()
        
        self.branch0 = nn.Sequential(
            Conv1d(in_planes, out_planes, kernel_size=9, stride=1)
            )
        
        self.branch1 = nn.Sequential(
            Conv1d(in_planes, in_planes, kernel_size=9, stride=1)
            nn.ReLU(),
            Conv1d(in_planes, out_planes, kernel_size=9, stride=1, padding=4)
            )
            
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x0 = self.branch0(x)
        x1 = self.branch1(x)
        x2 = x0 + x1
        out = self.relu(x2)
        
        return out

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_emlayer = nn.Embedding(21, 10)
        
        self.prt_cv2dlayer = nn.Sequential(
                        nn.Conv2d(1, 32, kernel_size = (4, 10)),
                        nn.BatchNorm2d(num_features = 32),
                        nn.ReLU()    # batch, channel, input_len, embedding
                        )    
        
        self.prt_cv1dlayers = nn.Sequential(
                        Conv1d(32, 64, kernel_size = 8, stride=1),
                        nn.BatchNorm1d(64),
                        nn.ReLU(),
                        nn.MaxPool1d(4),
                        Conv1d(64, 96, kernel_size = 12, stride=1),
                        nn.BatchNorm1d(96),
                        nn.ReLU(),
                        nn.MaxPool1d(339)
                        )
            
        ######################################################################
        ######################################################################
        
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv2dlayer = nn.Sequential(
                        nn.Conv2d(1, 32, kernel_size = (2, 10)),
                        nn.BatchNorm2d(num_features = 32),
                        nn.ReLU()
                        )
        
        self.lgn_cv1dlayers = nn.Sequential(
                        Block1(),
                        IBlock(32, 64),
                        nn.MaxPool1d(2),
                        IBlock(64, 96),
                        nn.MaxPool1d(10)
                        )
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(192, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(512, 768),
                        nn.BatchNorm1d(768),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                        nn.Linear(768, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, prt_seq, lgn_seq):   
        p = self.prt_emlayer(prt_seq)
        p = p.unsqueeze(1)
        p = self.prt_cv2dlayer(p)
        p = p.squeeze()
        p = self.prt_cv1dlayers(p)     # batch, channel(->input_size), seq_len
        p = p.squeeze()
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.unsqueeze(1)
        l = self.lgn_cv2dlayer(l)
        l = l.squeeze()
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
#         print(p.size(), l.size())
        
        cat = tc.cat((p, l), axis=1).cuda()
        out = self.mlplayers(cat)
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 256
hp_d['num_epochs'] = 300

hp_d['init_learning_rate'] = 10 ** -3.70183
hp_d['eps'] = 10 ** -8.39981
hp_d['weight_decay'] = 10 ** -3.59967

# %%
#%% training and validation
tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
loss_func = nn.MSELoss(reduction='mean').cuda()
optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

print('tr_var:', np.var(np.array([s[2] for s in trainset])))
print('va_var:', np.var(np.array([s[2] for s in validset])))
print('total params:', total_params)

tr_epoch_losses = []
va_epoch_losses = []

start = time.time()

for epoch in range(hp_d['num_epochs']):                          #!! epoch-loop
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(tr_data_loader):  #!! batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        tr_epoch_loss += loss.detach().item()
    
    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
    tr_epoch_losses.append(tr_epoch_loss)

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()
        
        va_epoch_loss += loss.detach().item()
        
    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
    va_epoch_losses.append(va_epoch_loss)
    
end = time.time()
print('time elapsed:', end-start)
# Out:
# tr_var: 0.6973572077706937
# va_var: 0.7063622712020676
# total params: 1172179
# Training epoch 0, loss 32.1507
# Validation epoch 0, loss 1.3180
# Training epoch 1, loss 0.9798
# Validation epoch 1, loss 0.5799
# Training epoch 2, loss 0.7246
# Validation epoch 2, loss 0.4902
# Training epoch 3, loss 0.5531
# Validation epoch 3, loss 0.4416
# Training epoch 4, loss 0.4382
# Validation epoch 4, loss 0.3714
# Training epoch 5, loss 0.3707
# Validation epoch 5, loss 0.3367
# Training epoch 6, loss 0.3385
# Validation epoch 6, loss 0.3696
# Training epoch 7, loss 0.3202
# Validation epoch 7, loss 0.3385
# Training epoch 8, loss 0.3056
# Validation epoch 8, loss 0.3563
# Training epoch 9, loss 0.2953
# Validation epoch 9, loss 0.3316
# Training epoch 10, loss 0.2867
# Validation epoch 10, loss 0.3216
# Training epoch 11, loss 0.2749
# Validation epoch 11, loss 0.3060
# Training epoch 12, loss 0.2659
# Validation epoch 12, loss 0.3150
# Training epoch 13, loss 0.2564
# Validation epoch 13, loss 0.2818
# Training epoch 14, loss 0.2471
# Validation epoch 14, loss 0.2709
# Training epoch 15, loss 0.2386
# Validation epoch 15, loss 0.2993
# Training epoch 16, loss 0.2285
# Validation epoch 16, loss 0.2577
# Training epoch 17, loss 0.2211
# Validation epoch 17, loss 0.2805
# Training epoch 18, loss 0.2133
# Validation epoch 18, loss 0.2549
# Training epoch 19, loss 0.2058
# Validation epoch 19, loss 0.2602
# Training epoch 20, loss 0.1992
# Validation epoch 20, loss 0.2425
# Training epoch 21, loss 0.1944
# Validation epoch 21, loss 0.2412
# Training epoch 22, loss 0.1899
# Validation epoch 22, loss 0.2393
# Training epoch 23, loss 0.1855
# Validation epoch 23, loss 0.2373
# Training epoch 24, loss 0.1787
# Validation epoch 24, loss 0.2293
# Training epoch 25, loss 0.1749
# Validation epoch 25, loss 0.2232
# Training epoch 26, loss 0.1695
# Validation epoch 26, loss 0.2253
# Training epoch 27, loss 0.1660
# Validation epoch 27, loss 0.2220
# Training epoch 28, loss 0.1605
# Validation epoch 28, loss 0.2406
# Training epoch 29, loss 0.1561
# Validation epoch 29, loss 0.2274
# Training epoch 30, loss 0.1523
# Validation epoch 30, loss 0.2148
# Training epoch 31, loss 0.1487
# Validation epoch 31, loss 0.2214
# Training epoch 32, loss 0.1448
# Validation epoch 32, loss 0.2140
# Training epoch 33, loss 0.1409
# Validation epoch 33, loss 0.2159
# Training epoch 34, loss 0.1406
# Validation epoch 34, loss 0.2100
# Training epoch 35, loss 0.1407
# Validation epoch 35, loss 0.2212
# Training epoch 36, loss 0.1391
# Validation epoch 36, loss 0.2172
# Training epoch 37, loss 0.1338
# Validation epoch 37, loss 0.2083
# Training epoch 38, loss 0.1309
# Validation epoch 38, loss 0.2051
# Training epoch 39, loss 0.1295
# Validation epoch 39, loss 0.2110
# Training epoch 40, loss 0.1283
# Validation epoch 40, loss 0.2122
# Training epoch 41, loss 0.1266
# Validation epoch 41, loss 0.2053
# Training epoch 42, loss 0.1243
# Validation epoch 42, loss 0.2105
# Training epoch 43, loss 0.1248
# Validation epoch 43, loss 0.2225
# Training epoch 44, loss 0.1247
# Validation epoch 44, loss 0.2187
# Training epoch 45, loss 0.1269
# Validation epoch 45, loss 0.2295
# Training epoch 46, loss 0.1271
# Validation epoch 46, loss 0.2147
# Training epoch 47, loss 0.1187
# Validation epoch 47, loss 0.2070
# Training epoch 48, loss 0.1143
# Validation epoch 48, loss 0.2089
# Training epoch 49, loss 0.1118
# Validation epoch 49, loss 0.2136
# Training epoch 50, loss 0.1107
# Validation epoch 50, loss 0.2236
# Training epoch 51, loss 0.1099
# Validation epoch 51, loss 0.2116
# Training epoch 52, loss 0.1075
# Validation epoch 52, loss 0.2087
# Training epoch 53, loss 0.1041
# Validation epoch 53, loss 0.2212
# Training epoch 54, loss 0.1016
# Validation epoch 54, loss 0.2115
# Training epoch 55, loss 0.1004
# Validation epoch 55, loss 0.2080
# Training epoch 56, loss 0.1024
# Validation epoch 56, loss 0.2128
# Training epoch 57, loss 0.1023
# Validation epoch 57, loss 0.2058
# Training epoch 58, loss 0.1006
# Validation epoch 58, loss 0.2218
# Training epoch 59, loss 0.0989
# Validation epoch 59, loss 0.2301
# Training epoch 60, loss 0.0973
# Validation epoch 60, loss 0.2169
# Training epoch 61, loss 0.0951
# Validation epoch 61, loss 0.2116
# Training epoch 62, loss 0.0963
# Validation epoch 62, loss 0.2049
# Training epoch 63, loss 0.0939
# Validation epoch 63, loss 0.2101
# Training epoch 64, loss 0.0972
# Validation epoch 64, loss 0.2143
# Training epoch 65, loss 0.0957
# Validation epoch 65, loss 0.1975
# Training epoch 66, loss 0.0910
# Validation epoch 66, loss 0.2063
# Training epoch 67, loss 0.0918
# Validation epoch 67, loss 0.2071
# Training epoch 68, loss 0.0902
# Validation epoch 68, loss 0.2349
# Training epoch 69, loss 0.0902
# Validation epoch 69, loss 0.2138
# Training epoch 70, loss 0.0918
# Validation epoch 70, loss 0.2177
# Training epoch 71, loss 0.0879
# Validation epoch 71, loss 0.2126
# Training epoch 72, loss 0.0905
# Validation epoch 72, loss 0.2173
# Training epoch 73, loss 0.0884
# Validation epoch 73, loss 0.2082
# Training epoch 74, loss 0.0875
# Validation epoch 74, loss 0.2053
# Training epoch 75, loss 0.0873
# Validation epoch 75, loss 0.2035
# Training epoch 76, loss 0.0864
# Validation epoch 76, loss 0.2044
# Training epoch 77, loss 0.0829
# Validation epoch 77, loss 0.2107
# Training epoch 78, loss 0.0853
# Validation epoch 78, loss 0.2066
# Training epoch 79, loss 0.0826
# Validation epoch 79, loss 0.2066
# Training epoch 80, loss 0.0836
# Validation epoch 80, loss 0.2104
# Training epoch 81, loss 0.0815
# Validation epoch 81, loss 0.2104
# Training epoch 82, loss 0.0828
# Validation epoch 82, loss 0.2317
# Training epoch 83, loss 0.0828
# Validation epoch 83, loss 0.2238
# Training epoch 84, loss 0.0811
# Validation epoch 84, loss 0.2130
# Training epoch 85, loss 0.0785
# Validation epoch 85, loss 0.2126
# Training epoch 86, loss 0.0807
# Validation epoch 86, loss 0.2058
# Training epoch 87, loss 0.0791
# Validation epoch 87, loss 0.2028
# Training epoch 88, loss 0.0778
# Validation epoch 88, loss 0.2164
# Training epoch 89, loss 0.0809
# Validation epoch 89, loss 0.2236
# Training epoch 90, loss 0.0767
# Validation epoch 90, loss 0.2285
# Training epoch 91, loss 0.0771
# Validation epoch 91, loss 0.2097
# Training epoch 92, loss 0.0778
# Validation epoch 92, loss 0.2121
# Training epoch 93, loss 0.0752
# Validation epoch 93, loss 0.2087
# Training epoch 94, loss 0.0767
# Validation epoch 94, loss 0.2331
# Training epoch 95, loss 0.0768
# Validation epoch 95, loss 0.2088
# Training epoch 96, loss 0.0744
# Validation epoch 96, loss 0.2102
# Training epoch 97, loss 0.0738
# Validation epoch 97, loss 0.2094
# Training epoch 98, loss 0.0738
# Validation epoch 98, loss 0.2137
# Training epoch 99, loss 0.0748
# Validation epoch 99, loss 0.2166
# Training epoch 100, loss 0.0727
# Validation epoch 100, loss 0.2198
# Training epoch 101, loss 0.0734
# Validation epoch 101, loss 0.2213
# Training epoch 102, loss 0.0714
# Validation epoch 102, loss 0.2090
# Training epoch 103, loss 0.0697
# Validation epoch 103, loss 0.2106
# Training epoch 104, loss 0.0702
# Validation epoch 104, loss 0.2150
# Training epoch 105, loss 0.0699
# Validation epoch 105, loss 0.2246
# Training epoch 106, loss 0.0699
# Validation epoch 106, loss 0.2215
# Training epoch 107, loss 0.0687
# Validation epoch 107, loss 0.2121
# Training epoch 108, loss 0.0689
# Validation epoch 108, loss 0.2409
# Training epoch 109, loss 0.0714
# Validation epoch 109, loss 0.2215
# Training epoch 110, loss 0.0698
# Validation epoch 110, loss 0.2078
# Training epoch 111, loss 0.0690
# Validation epoch 111, loss 0.2054
# Training epoch 112, loss 0.0745
# Validation epoch 112, loss 0.2086
# Training epoch 113, loss 0.0755
# Validation epoch 113, loss 0.2103
# Training epoch 114, loss 0.0694
# Validation epoch 114, loss 0.2074
# Training epoch 115, loss 0.0660
# Validation epoch 115, loss 0.2082
# Training epoch 116, loss 0.0648
# Validation epoch 116, loss 0.2140
# Training epoch 117, loss 0.0658
# Validation epoch 117, loss 0.2143
# Training epoch 118, loss 0.0661
# Validation epoch 118, loss 0.2181
# Training epoch 119, loss 0.0656
# Validation epoch 119, loss 0.2123
# Training epoch 120, loss 0.0634
# Validation epoch 120, loss 0.2088
# Training epoch 121, loss 0.0649
# Validation epoch 121, loss 0.2105
# Training epoch 122, loss 0.0678
# Validation epoch 122, loss 0.2031
# Training epoch 123, loss 0.0676
# Validation epoch 123, loss 0.2006
# Training epoch 124, loss 0.0656
# Validation epoch 124, loss 0.2059
# Training epoch 125, loss 0.0646
# Validation epoch 125, loss 0.2065
# Training epoch 126, loss 0.0655
# Validation epoch 126, loss 0.2127
# Training epoch 127, loss 0.0664
# Validation epoch 127, loss 0.2012
# Training epoch 128, loss 0.0640
# Validation epoch 128, loss 0.2029
# Training epoch 129, loss 0.0629
# Validation epoch 129, loss 0.2065
# Training epoch 130, loss 0.0643
# Validation epoch 130, loss 0.1990
# Training epoch 131, loss 0.0624
# Validation epoch 131, loss 0.2080
# Training epoch 132, loss 0.0638
# Validation epoch 132, loss 0.2091
# Training epoch 133, loss 0.0629
# Validation epoch 133, loss 0.2030
# Training epoch 134, loss 0.0622
# Validation epoch 134, loss 0.2123
# Training epoch 135, loss 0.0627
# Validation epoch 135, loss 0.2190
# Training epoch 136, loss 0.0619
# Validation epoch 136, loss 0.2129
# Training epoch 137, loss 0.0628
# Validation epoch 137, loss 0.2151
# Training epoch 138, loss 0.0640
# Validation epoch 138, loss 0.1969
# Training epoch 139, loss 0.0615
# Validation epoch 139, loss 0.2039
# Training epoch 140, loss 0.0619
# Validation epoch 140, loss 0.1985
# Training epoch 141, loss 0.0606
# Validation epoch 141, loss 0.2142
# Training epoch 142, loss 0.0618
# Validation epoch 142, loss 0.2159
# Training epoch 143, loss 0.0615
# Validation epoch 143, loss 0.2078
# Training epoch 144, loss 0.0588
# Validation epoch 144, loss 0.2124
# Training epoch 145, loss 0.0611
# Validation epoch 145, loss 0.2144
# Training epoch 146, loss 0.0628
# Validation epoch 146, loss 0.2126
# Training epoch 147, loss 0.0649
# Validation epoch 147, loss 0.2217
# Training epoch 148, loss 0.0598
# Validation epoch 148, loss 0.2162
# Training epoch 149, loss 0.0593
# Validation epoch 149, loss 0.2372
# Training epoch 150, loss 0.0598
# Validation epoch 150, loss 0.2134
# Training epoch 151, loss 0.0587
# Validation epoch 151, loss 0.2200
# Training epoch 152, loss 0.0595
# Validation epoch 152, loss 0.2324
# Training epoch 153, loss 0.0585
# Validation epoch 153, loss 0.2053
# Training epoch 154, loss 0.0603
# Validation epoch 154, loss 0.2220
# Training epoch 155, loss 0.0587
# Validation epoch 155, loss 0.2095
# Training epoch 156, loss 0.0632
# Validation epoch 156, loss 0.2043
# Training epoch 157, loss 0.0581
# Validation epoch 157, loss 0.2214
# Training epoch 158, loss 0.0572
# Validation epoch 158, loss 0.2174
# Training epoch 159, loss 0.0582
# Validation epoch 159, loss 0.2333
# Training epoch 160, loss 0.0583
# Validation epoch 160, loss 0.2382
# Training epoch 161, loss 0.0590
# Validation epoch 161, loss 0.2294
# Training epoch 162, loss 0.0577
# Validation epoch 162, loss 0.2510
# Training epoch 163, loss 0.0584
# Validation epoch 163, loss 0.2165
# Training epoch 164, loss 0.0580
# Validation epoch 164, loss 0.2398
# Training epoch 165, loss 0.0572
# Validation epoch 165, loss 0.2214
# Training epoch 166, loss 0.0614
# Validation epoch 166, loss 0.2124
# Training epoch 167, loss 0.0615
# Validation epoch 167, loss 0.2273
# Training epoch 168, loss 0.0578
# Validation epoch 168, loss 0.2088
# Training epoch 169, loss 0.0558
# Validation epoch 169, loss 0.2130
# Training epoch 170, loss 0.0552
# Validation epoch 170, loss 0.2165
# Training epoch 171, loss 0.0564
# Validation epoch 171, loss 0.2195
# Training epoch 172, loss 0.0540
# Validation epoch 172, loss 0.2191
# Training epoch 173, loss 0.0564
# Validation epoch 173, loss 0.2083
# Training epoch 174, loss 0.0551
# Validation epoch 174, loss 0.2045
# Training epoch 175, loss 0.0552
# Validation epoch 175, loss 0.2071
# Training epoch 176, loss 0.0557
# Validation epoch 176, loss 0.2067
# Training epoch 177, loss 0.0598
# Validation epoch 177, loss 0.2096
# Training epoch 178, loss 0.0594
# Validation epoch 178, loss 0.2130
# Training epoch 179, loss 0.0559
# Validation epoch 179, loss 0.2089
# Training epoch 180, loss 0.0548
# Validation epoch 180, loss 0.2034
# Training epoch 181, loss 0.0547
# Validation epoch 181, loss 0.2121
# Training epoch 182, loss 0.0547
# Validation epoch 182, loss 0.2079
# Training epoch 183, loss 0.0543
# Validation epoch 183, loss 0.2167
# Training epoch 184, loss 0.0542
# Validation epoch 184, loss 0.2087
# Training epoch 185, loss 0.0534
# Validation epoch 185, loss 0.2099
# Training epoch 186, loss 0.0540
# Validation epoch 186, loss 0.2040
# Training epoch 187, loss 0.0536
# Validation epoch 187, loss 0.1984
# Training epoch 188, loss 0.0551
# Validation epoch 188, loss 0.2184
# Training epoch 189, loss 0.0563
# Validation epoch 189, loss 0.2251
# Training epoch 190, loss 0.0552
# Validation epoch 190, loss 0.2109
# Training epoch 191, loss 0.0569
# Validation epoch 191, loss 0.2144
# Training epoch 192, loss 0.0568
# Validation epoch 192, loss 0.2218
# Training epoch 193, loss 0.0551
# Validation epoch 193, loss 0.2155
# Training epoch 194, loss 0.0523
# Validation epoch 194, loss 0.2086
# Training epoch 195, loss 0.0527
# Validation epoch 195, loss 0.2044
# Training epoch 196, loss 0.0519
# Validation epoch 196, loss 0.2071
# Training epoch 197, loss 0.0551
# Validation epoch 197, loss 0.2065
# Training epoch 198, loss 0.0530
# Validation epoch 198, loss 0.2013
# Training epoch 199, loss 0.0534
# Validation epoch 199, loss 0.2083
# Training epoch 200, loss 0.0518
# Validation epoch 200, loss 0.1962
# Training epoch 201, loss 0.0517
# Validation epoch 201, loss 0.1970
# Training epoch 202, loss 0.0519
# Validation epoch 202, loss 0.1938
# Training epoch 203, loss 0.0528
# Validation epoch 203, loss 0.1947
# Training epoch 204, loss 0.0522
# Validation epoch 204, loss 0.2052
# Training epoch 205, loss 0.0546
# Validation epoch 205, loss 0.2071
# Training epoch 206, loss 0.0551
# Validation epoch 206, loss 0.1941
# Training epoch 207, loss 0.0539
# Validation epoch 207, loss 0.2170
# Training epoch 208, loss 0.0530
# Validation epoch 208, loss 0.2003
# Training epoch 209, loss 0.0555
# Validation epoch 209, loss 0.2125
# Training epoch 210, loss 0.0525
# Validation epoch 210, loss 0.1986
# Training epoch 211, loss 0.0524
# Validation epoch 211, loss 0.2168
# Training epoch 212, loss 0.0524
# Validation epoch 212, loss 0.2056
# Training epoch 213, loss 0.0534
# Validation epoch 213, loss 0.2012
# Training epoch 214, loss 0.0527
# Validation epoch 214, loss 0.2165
# Training epoch 215, loss 0.0628
# Validation epoch 215, loss 0.1995
# Training epoch 216, loss 0.0605
# Validation epoch 216, loss 0.2051
# Training epoch 217, loss 0.0548
# Validation epoch 217, loss 0.1972
# Training epoch 218, loss 0.0522
# Validation epoch 218, loss 0.2096
# Training epoch 219, loss 0.0503
# Validation epoch 219, loss 0.2072
# Training epoch 220, loss 0.0509
# Validation epoch 220, loss 0.2133
# Training epoch 221, loss 0.0518
# Validation epoch 221, loss 0.2276
# Training epoch 222, loss 0.0515
# Validation epoch 222, loss 0.1998
# Training epoch 223, loss 0.0514
# Validation epoch 223, loss 0.2098
# Training epoch 224, loss 0.0521
# Validation epoch 224, loss 0.1985
# Training epoch 225, loss 0.0510
# Validation epoch 225, loss 0.1949
# Training epoch 226, loss 0.0528
# Validation epoch 226, loss 0.2156
# Training epoch 227, loss 0.0525
# Validation epoch 227, loss 0.1985
# Training epoch 228, loss 0.0510
# Validation epoch 228, loss 0.2054
# Training epoch 229, loss 0.0522
# Validation epoch 229, loss 0.1963
# Training epoch 230, loss 0.0521
# Validation epoch 230, loss 0.1887
# Training epoch 231, loss 0.0522
# Validation epoch 231, loss 0.2088
# Training epoch 232, loss 0.0520
# Validation epoch 232, loss 0.1957
# Training epoch 233, loss 0.0529
# Validation epoch 233, loss 0.2006
# Training epoch 234, loss 0.0546
# Validation epoch 234, loss 0.1940
# Training epoch 235, loss 0.0543
# Validation epoch 235, loss 0.2049
# Training epoch 236, loss 0.0527
# Validation epoch 236, loss 0.2058
# Training epoch 237, loss 0.0518
# Validation epoch 237, loss 0.2112
# Training epoch 238, loss 0.0499
# Validation epoch 238, loss 0.1937
# Training epoch 239, loss 0.0496
# Validation epoch 239, loss 0.2209
# Training epoch 240, loss 0.0502
# Validation epoch 240, loss 0.2017
# Training epoch 241, loss 0.0501
# Validation epoch 241, loss 0.2015
# Training epoch 242, loss 0.0497
# Validation epoch 242, loss 0.2104
# Training epoch 243, loss 0.0508
# Validation epoch 243, loss 0.2047
# Training epoch 244, loss 0.0514
# Validation epoch 244, loss 0.2117
# Training epoch 245, loss 0.0513
# Validation epoch 245, loss 0.1981
# Training epoch 246, loss 0.0520
# Validation epoch 246, loss 0.2035
# Training epoch 247, loss 0.0501
# Validation epoch 247, loss 0.2212
# Training epoch 248, loss 0.0517
# Validation epoch 248, loss 0.1991
# Training epoch 249, loss 0.0510
# Validation epoch 249, loss 0.2093
# Training epoch 250, loss 0.0546
# Validation epoch 250, loss 0.2083
# Training epoch 251, loss 0.0495
# Validation epoch 251, loss 0.1969
# Training epoch 252, loss 0.0480
# Validation epoch 252, loss 0.2062
# Training epoch 253, loss 0.0481
# Validation epoch 253, loss 0.1922
# Training epoch 254, loss 0.0483
# Validation epoch 254, loss 0.1960
# Training epoch 255, loss 0.0480
# Validation epoch 255, loss 0.1936
# Training epoch 256, loss 0.0483
# Validation epoch 256, loss 0.2061
# Training epoch 257, loss 0.0505
# Validation epoch 257, loss 0.1986
# Training epoch 258, loss 0.0488
# Validation epoch 258, loss 0.1880
# Training epoch 259, loss 0.0484
# Validation epoch 259, loss 0.1982
# Training epoch 260, loss 0.0481
# Validation epoch 260, loss 0.1993
# Training epoch 261, loss 0.0483
# Validation epoch 261, loss 0.1999
# Training epoch 262, loss 0.0506
# Validation epoch 262, loss 0.1973
# Training epoch 263, loss 0.0491
# Validation epoch 263, loss 0.1965
# Training epoch 264, loss 0.0494
# Validation epoch 264, loss 0.1972
# Training epoch 265, loss 0.0493
# Validation epoch 265, loss 0.2013
# Training epoch 266, loss 0.0495
# Validation epoch 266, loss 0.2062
# Training epoch 267, loss 0.0488
# Validation epoch 267, loss 0.2003
# Training epoch 268, loss 0.0468
# Validation epoch 268, loss 0.2065
# Training epoch 269, loss 0.0472
# Validation epoch 269, loss 0.1985
# Training epoch 270, loss 0.0482
# Validation epoch 270, loss 0.1984
# Training epoch 271, loss 0.0482
# Validation epoch 271, loss 0.2198
# Training epoch 272, loss 0.0478
# Validation epoch 272, loss 0.2230
# Training epoch 273, loss 0.0485
# Validation epoch 273, loss 0.2106
# Training epoch 274, loss 0.0465
# Validation epoch 274, loss 0.2067
# Training epoch 275, loss 0.0480
# Validation epoch 275, loss 0.2112
# Training epoch 276, loss 0.0485
# Validation epoch 276, loss 0.2022
# Training epoch 277, loss 0.0490
# Validation epoch 277, loss 0.1976
# Training epoch 278, loss 0.0492
# Validation epoch 278, loss 0.1965
# Training epoch 279, loss 0.0480
# Validation epoch 279, loss 0.2029
# Training epoch 280, loss 0.0462
# Validation epoch 280, loss 0.2131
# Training epoch 281, loss 0.0464
# Validation epoch 281, loss 0.2075
# Training epoch 282, loss 0.0494
# Validation epoch 282, loss 0.2038
# Training epoch 283, loss 0.0476
# Validation epoch 283, loss 0.2025
# Training epoch 284, loss 0.0505
# Validation epoch 284, loss 0.1991
# Training epoch 285, loss 0.0468
# Validation epoch 285, loss 0.1999
# Training epoch 286, loss 0.0459
# Validation epoch 286, loss 0.2016
# Training epoch 287, loss 0.0451
# Validation epoch 287, loss 0.2000
# Training epoch 288, loss 0.0466
# Validation epoch 288, loss 0.2047
# Training epoch 289, loss 0.0476
# Validation epoch 289, loss 0.2158
# Training epoch 290, loss 0.0477
# Validation epoch 290, loss 0.2031
# Training epoch 291, loss 0.0468
# Validation epoch 291, loss 0.2054
# Training epoch 292, loss 0.0460
# Validation epoch 292, loss 0.2048
# Training epoch 293, loss 0.0474
# Validation epoch 293, loss 0.2094
# Training epoch 294, loss 0.0477
# Validation epoch 294, loss 0.1976
# Training epoch 295, loss 0.0470
# Validation epoch 295, loss 0.2014
# Training epoch 296, loss 0.0476
# Validation epoch 296, loss 0.2025
# Training epoch 297, loss 0.0474
# Validation epoch 297, loss 0.2048
# Training epoch 298, loss 0.0463
# Validation epoch 298, loss 0.2004
# Training epoch 299, loss 0.0469
# Validation epoch 299, loss 0.1987
# time elapsed: 13472.677270174026

# %%
#%%
np.save('ModifiedDeepDTA_v5_tr_losses', tr_epoch_losses)
np.save('ModifiedDeepDTA_v5_va_losses', va_epoch_losses)

# %%
min(va_epoch_losses)
# Out:
# 0.1879951625596732
