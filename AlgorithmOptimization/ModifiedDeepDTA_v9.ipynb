# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial
from sklearn.model_selection import KFold

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = dataset.loc[:, "chemblID"]
kiba = list(dataset.loc[:, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_lstm.txt', 'rb')
seq_voc, _ = pickle.load(f)
f.close()

sequence = np.zeros((datalen, 4128))
for i, s in enumerate(protein):
    sequence[i] = seq_voc[s]

sequence = sequence[:, :1400]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros((datalen, 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(sequence, smileseq, kiba))
shuffled_dataset = np.array(shuffle(revised_dataset, random_state=0)); del revised_dataset

# %%
#%% Make collate func.
def collate(samples):
    sequences, smileseq, labels = map(list, zip(*samples))
    return tc.LongTensor(sequences).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_emlayer = nn.Embedding(21, 10)
        
        self.prt_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 12),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size=1379)
                        )
        
        ######################################################################
        ######################################################################
        
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
        
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(192, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, prt_seq, lgn_seq):   
        p = self.prt_emlayer(prt_seq)
        p = p.permute(0, 2, 1)
        p = self.prt_cv1dlayers(p)
        p = p.squeeze()
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p, l), axis=1).cuda()
        out = self.mlplayers(cat)
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 512
hp_d['num_epochs'] = 400

hp_d['init_learning_rate'] = 10 ** -3.563
hp_d['eps'] = 10 ** -8
hp_d['weight_decay'] = 10 ** -5

# %%
#%% training 80%, validation 10%, test 10%
data_len = len(shuffled_dataset)
train_len = int(data_len * (8/10))
valid_len = int(data_len * (1/10))
test_len = int(data_len * (1/10))

trainset = shuffled_dataset[:train_len]
validset = shuffled_dataset[train_len:train_len+valid_len]
testset = shuffled_dataset[-test_len:]

with open('testset.npy', 'wb') as f:
    np.save(f, testset)

trainset = tuple(trainset); validset = tuple(validset); testset = tuple(testset)

tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
ts_data_loader = DataLoader(testset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
loss_func = nn.MSELoss(reduction='mean').cuda()

optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

best_loss = 100

for epoch in range(hp_d['num_epochs']):                             #!! epoch-loop
# ===========================================================================
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(tr_data_loader):       #!! batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tr_epoch_loss += loss.detach().item()

    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()

        va_epoch_loss += loss.detach().item()

    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))    
    
    if va_epoch_loss < best_loss:
        torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': va_epoch_loss
                }, 'results/model9_weight1.pt')
        best_loss = va_epoch_loss

# ===========================================================================
    # test session
checkpoint = torch.load('results/model9_wheight.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']

model.eval()
ts_epoch_loss = 0

for iter, (seq, smi, label) in enumerate(ts_data_loader):  # batch-loop
    prediction = model(seq, smi).view(-1).cuda()
    loss = loss_func(prediction, label).cuda()
    
    ts_epoch_loss += loss.detach().item()
    
ts_epoch_loss /= (iter + 1)
print('Test loss {:.4f}'.format(epoch, ts_epoch_loss)) 


prediction = np.array(prediction.detach().cpu())
label = np.array(label.detach().cpu())
print('prediction-label corr coef:', np.corrcoef(prediction, label))

temp_pre = prediction.argsort()
rank_pre = np.empty_like(temp_pre)
rank_pre[temp_pre] = np.arange(len(prediction))

temp_lab = label.argsort()
rank_lab = np.empty_like(temp_lab)
rank_lab[temp_lab] = np.arange(len(label))

print('rank-order corr coef:',np.corrcoef(rank_pre, rank_lab))

# %%
#%% training 90%, validation 10%
data_len = len(shuffled_dataset)
train_len = int(data_len * (9/10))
valid_len = int(data_len * (1/10))

trainset = shuffled_dataset[:train_len]
validset = shuffled_dataset[-valid_len:]

trainset = tuple(trainset); validset = tuple(validset);

tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
va_data_loader = DataLoader(validset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

model = Regressor().to(torch.device('cuda:0'))
loss_func = nn.MSELoss(reduction='mean').cuda()

optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
    weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

best_loss = 100

for epoch in range(hp_d['num_epochs']):                             #!! epoch-loop
# ===========================================================================
    # training session
    model.train()
    tr_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(tr_data_loader):       #!! batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tr_epoch_loss += loss.detach().item()

    tr_epoch_loss /= (iter + 1)
    print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))

# ===========================================================================
    # validation session
    model.eval()
    va_epoch_loss = 0

    for iter, (seq, smi, label) in enumerate(va_data_loader):  # batch-loop
        prediction = model(seq, smi).view(-1).cuda()
        loss = loss_func(prediction, label).cuda()

        va_epoch_loss += loss.detach().item()

    va_epoch_loss /= (iter + 1)
    print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))    
    
    if va_epoch_loss < best_loss:
        torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': va_epoch_loss
                }, 'results/model9_weight2.pt')
        best_loss = va_epoch_loss
# Out:
# Training epoch 0, loss 40.7391
# Validation epoch 0, loss 2.7955
# Training epoch 1, loss 1.1354
# Validation epoch 1, loss 0.4640
# Training epoch 2, loss 0.6872
# Validation epoch 2, loss 0.3659
# Training epoch 3, loss 0.5870
# Validation epoch 3, loss 0.3225
# Training epoch 4, loss 0.4929
# Validation epoch 4, loss 0.3249
# Training epoch 5, loss 0.4042
# Validation epoch 5, loss 0.3504
# Training epoch 6, loss 0.3302
# Validation epoch 6, loss 0.3057
# Training epoch 7, loss 0.2835
# Validation epoch 7, loss 0.2717
# Training epoch 8, loss 0.2544
# Validation epoch 8, loss 0.2517
# Training epoch 9, loss 0.2325
# Validation epoch 9, loss 0.2569
# Training epoch 10, loss 0.2200
# Validation epoch 10, loss 0.2345
# Training epoch 11, loss 0.2080
# Validation epoch 11, loss 0.2268
# Training epoch 12, loss 0.1984
# Validation epoch 12, loss 0.2222
# Training epoch 13, loss 0.1881
# Validation epoch 13, loss 0.2250
# Training epoch 14, loss 0.1815
# Validation epoch 14, loss 0.2248
# Training epoch 15, loss 0.1727
# Validation epoch 15, loss 0.2159
# Training epoch 16, loss 0.1654
# Validation epoch 16, loss 0.2256
# Training epoch 17, loss 0.1596
# Validation epoch 17, loss 0.2156
# Training epoch 18, loss 0.1542
# Validation epoch 18, loss 0.2159
# Training epoch 19, loss 0.1479
# Validation epoch 19, loss 0.2286
# Training epoch 20, loss 0.1416
# Validation epoch 20, loss 0.2975
# Training epoch 21, loss 0.1404
# Validation epoch 21, loss 0.2034
# Training epoch 22, loss 0.1343
# Validation epoch 22, loss 0.2380
# Training epoch 23, loss 0.1321
# Validation epoch 23, loss 0.2076
# Training epoch 24, loss 0.1280
# Validation epoch 24, loss 0.2123
# Training epoch 25, loss 0.1245
# Validation epoch 25, loss 0.2227
# Training epoch 26, loss 0.1219
# Validation epoch 26, loss 0.2103
# Training epoch 27, loss 0.1198
# Validation epoch 27, loss 0.1984
# Training epoch 28, loss 0.1146
# Validation epoch 28, loss 0.1954
# Training epoch 29, loss 0.1138
# Validation epoch 29, loss 0.2128
# Training epoch 30, loss 0.1072
# Validation epoch 30, loss 0.2161
# Training epoch 31, loss 0.1063
# Validation epoch 31, loss 0.2125
# Training epoch 32, loss 0.1078
# Validation epoch 32, loss 0.1975
# Training epoch 33, loss 0.1028
# Validation epoch 33, loss 0.2025
# Training epoch 34, loss 0.0980
# Validation epoch 34, loss 0.2133
# Training epoch 35, loss 0.0947
# Validation epoch 35, loss 0.2076
# Training epoch 36, loss 0.0917
# Validation epoch 36, loss 0.1999
# Training epoch 37, loss 0.0928
# Validation epoch 37, loss 0.1941
# Training epoch 38, loss 0.0886
# Validation epoch 38, loss 0.1842
# Training epoch 39, loss 0.0850
# Validation epoch 39, loss 0.1820
# Training epoch 40, loss 0.0875
# Validation epoch 40, loss 0.1883
# Training epoch 41, loss 0.0845
# Validation epoch 41, loss 0.1845
# Training epoch 42, loss 0.0802
# Validation epoch 42, loss 0.1920
# Training epoch 43, loss 0.0766
# Validation epoch 43, loss 0.1855
# Training epoch 44, loss 0.0743
# Validation epoch 44, loss 0.1987
# Training epoch 45, loss 0.0731
# Validation epoch 45, loss 0.1768
# Training epoch 46, loss 0.0750
# Validation epoch 46, loss 0.1918
# Training epoch 47, loss 0.0753
# Validation epoch 47, loss 0.1996
# Training epoch 48, loss 0.0736
# Validation epoch 48, loss 0.1991
# Training epoch 49, loss 0.0721
# Validation epoch 49, loss 0.2067
# Training epoch 50, loss 0.0709
# Validation epoch 50, loss 0.1910
# Training epoch 51, loss 0.0666
# Validation epoch 51, loss 0.1792
# Training epoch 52, loss 0.0653
# Validation epoch 52, loss 0.1850
# Training epoch 53, loss 0.0652
# Validation epoch 53, loss 0.1746
# Training epoch 54, loss 0.0649
# Validation epoch 54, loss 0.1796
# Training epoch 55, loss 0.0616
# Validation epoch 55, loss 0.1881
# Training epoch 56, loss 0.0630
# Validation epoch 56, loss 0.1936
# Training epoch 57, loss 0.0627
# Validation epoch 57, loss 0.1998
# Training epoch 58, loss 0.0628
# Validation epoch 58, loss 0.1885
# Training epoch 59, loss 0.0649
# Validation epoch 59, loss 0.2131
# Training epoch 60, loss 0.0703
# Validation epoch 60, loss 0.1983
# Training epoch 61, loss 0.0715
# Validation epoch 61, loss 0.1993
# Training epoch 62, loss 0.0755
# Validation epoch 62, loss 0.1827
# Training epoch 63, loss 0.0650
# Validation epoch 63, loss 0.1787
# Training epoch 64, loss 0.0600
# Validation epoch 64, loss 0.1729
# Training epoch 65, loss 0.0562
# Validation epoch 65, loss 0.1748
# Training epoch 66, loss 0.0533
# Validation epoch 66, loss 0.1720
# Training epoch 67, loss 0.0512
# Validation epoch 67, loss 0.1722
# Training epoch 68, loss 0.0501
# Validation epoch 68, loss 0.1678
# Training epoch 69, loss 0.0479
# Validation epoch 69, loss 0.1715
# Training epoch 70, loss 0.0480
# Validation epoch 70, loss 0.1705
# Training epoch 71, loss 0.0517
# Validation epoch 71, loss 0.1683
# Training epoch 72, loss 0.0545
# Validation epoch 72, loss 0.1747
# Training epoch 73, loss 0.0489
# Validation epoch 73, loss 0.1694
# Training epoch 74, loss 0.0462
# Validation epoch 74, loss 0.1626
# Training epoch 75, loss 0.0456
# Validation epoch 75, loss 0.1637
# Training epoch 76, loss 0.0453
# Validation epoch 76, loss 0.1592
# Training epoch 77, loss 0.0442
# Validation epoch 77, loss 0.1639
# Training epoch 78, loss 0.0452
# Validation epoch 78, loss 0.1724
# Training epoch 79, loss 0.0456
# Validation epoch 79, loss 0.1705
# Training epoch 80, loss 0.0483
# Validation epoch 80, loss 0.1778
# Training epoch 81, loss 0.0497
# Validation epoch 81, loss 0.1750
# Training epoch 82, loss 0.0491
# Validation epoch 82, loss 0.1673
# Training epoch 83, loss 0.0457
# Validation epoch 83, loss 0.1748
# Training epoch 84, loss 0.0442
# Validation epoch 84, loss 0.1791
# Training epoch 85, loss 0.0441
# Validation epoch 85, loss 0.1683
# Training epoch 86, loss 0.0420
# Validation epoch 86, loss 0.1747
# Training epoch 87, loss 0.0417
# Validation epoch 87, loss 0.1707
# Training epoch 88, loss 0.0407
# Validation epoch 88, loss 0.1649
# Training epoch 89, loss 0.0418
# Validation epoch 89, loss 0.1718
# Training epoch 90, loss 0.0432
# Validation epoch 90, loss 0.1735
# Training epoch 91, loss 0.0463
# Validation epoch 91, loss 0.2011
# Training epoch 92, loss 0.0487
# Validation epoch 92, loss 0.1894
# Training epoch 93, loss 0.0516
# Validation epoch 93, loss 0.1712
# Training epoch 94, loss 0.0486
# Validation epoch 94, loss 0.1894
# Training epoch 95, loss 0.0461
# Validation epoch 95, loss 0.2304
# Training epoch 96, loss 0.0473
# Validation epoch 96, loss 0.2259
# Training epoch 97, loss 0.0495
# Validation epoch 97, loss 0.1769
# Training epoch 98, loss 0.0466
# Validation epoch 98, loss 0.1771
# Training epoch 99, loss 0.0459
# Validation epoch 99, loss 0.1661
# Training epoch 100, loss 0.0412
# Validation epoch 100, loss 0.1738
# Training epoch 101, loss 0.0393
# Validation epoch 101, loss 0.1722
# Training epoch 102, loss 0.0404
# Validation epoch 102, loss 0.1672
# Training epoch 103, loss 0.0411
# Validation epoch 103, loss 0.1785
# Training epoch 104, loss 0.0401
# Validation epoch 104, loss 0.1897
# Training epoch 105, loss 0.0409
# Validation epoch 105, loss 0.1839
# Training epoch 106, loss 0.0406
# Validation epoch 106, loss 0.2020
# Training epoch 107, loss 0.0432
# Validation epoch 107, loss 0.1957
# Training epoch 108, loss 0.0488
# Validation epoch 108, loss 0.2025
# Training epoch 109, loss 0.0541
# Validation epoch 109, loss 0.1820
# Training epoch 110, loss 0.0541
# Validation epoch 110, loss 0.1733
# Training epoch 111, loss 0.0476
# Validation epoch 111, loss 0.1682
# Training epoch 112, loss 0.0413
# Validation epoch 112, loss 0.1689
# Training epoch 113, loss 0.0378
# Validation epoch 113, loss 0.1612
# Training epoch 114, loss 0.0347
# Validation epoch 114, loss 0.1589
# Training epoch 115, loss 0.0358
# Validation epoch 115, loss 0.1619
# Training epoch 116, loss 0.0352
# Validation epoch 116, loss 0.1616
# Training epoch 117, loss 0.0344
# Validation epoch 117, loss 0.1628
# Training epoch 118, loss 0.0321
# Validation epoch 118, loss 0.1605
# Training epoch 119, loss 0.0317
# Validation epoch 119, loss 0.1577
# Training epoch 120, loss 0.0324
# Validation epoch 120, loss 0.1568
# Training epoch 121, loss 0.0328
# Validation epoch 121, loss 0.1617
# Training epoch 122, loss 0.0338
# Validation epoch 122, loss 0.1640
# Training epoch 123, loss 0.0356
# Validation epoch 123, loss 0.1677
# Training epoch 124, loss 0.0393
# Validation epoch 124, loss 0.1632
# Training epoch 125, loss 0.0428
# Validation epoch 125, loss 0.1616
# Training epoch 126, loss 0.0421
# Validation epoch 126, loss 0.1629
# Training epoch 127, loss 0.0404
# Validation epoch 127, loss 0.1672
# Training epoch 128, loss 0.0373
# Validation epoch 128, loss 0.1675
# Training epoch 129, loss 0.0335
# Validation epoch 129, loss 0.1743
# Training epoch 130, loss 0.0327
# Validation epoch 130, loss 0.1800
# Training epoch 131, loss 0.0327
# Validation epoch 131, loss 0.1746
# Training epoch 132, loss 0.0322
# Validation epoch 132, loss 0.1682
# Training epoch 133, loss 0.0353
# Validation epoch 133, loss 0.1665
# Training epoch 134, loss 0.0425
# Validation epoch 134, loss 0.1733
# Training epoch 135, loss 0.0416
# Validation epoch 135, loss 0.1892
# Training epoch 136, loss 0.0411
# Validation epoch 136, loss 0.1755
# Training epoch 137, loss 0.0412
# Validation epoch 137, loss 0.1900
# Training epoch 138, loss 0.0401
# Validation epoch 138, loss 0.1900
# Training epoch 139, loss 0.0374
# Validation epoch 139, loss 0.1666
# Training epoch 140, loss 0.0355
# Validation epoch 140, loss 0.1608
# Training epoch 141, loss 0.0329
# Validation epoch 141, loss 0.1573
# Training epoch 142, loss 0.0314
# Validation epoch 142, loss 0.1612
# Training epoch 143, loss 0.0314
# Validation epoch 143, loss 0.1586
# Training epoch 144, loss 0.0315
# Validation epoch 144, loss 0.1661
# Training epoch 145, loss 0.0334
# Validation epoch 145, loss 0.1671
# Training epoch 146, loss 0.0328
# Validation epoch 146, loss 0.1735
# Training epoch 147, loss 0.0407
# Validation epoch 147, loss 0.1740
# Training epoch 148, loss 0.0421
# Validation epoch 148, loss 0.1719
# Training epoch 149, loss 0.0400
# Validation epoch 149, loss 0.1719
# Training epoch 150, loss 0.0384
# Validation epoch 150, loss 0.1721
# Training epoch 151, loss 0.0375
# Validation epoch 151, loss 0.1689
# Training epoch 152, loss 0.0369
# Validation epoch 152, loss 0.1663
# Training epoch 153, loss 0.0386
# Validation epoch 153, loss 0.1735
# Training epoch 154, loss 0.0395
# Validation epoch 154, loss 0.1674
# Training epoch 155, loss 0.0387
# Validation epoch 155, loss 0.1713
# Training epoch 156, loss 0.0363
# Validation epoch 156, loss 0.1721
# Training epoch 157, loss 0.0318
# Validation epoch 157, loss 0.1655
# Training epoch 158, loss 0.0278
# Validation epoch 158, loss 0.1667
# Training epoch 159, loss 0.0263
# Validation epoch 159, loss 0.1569
# Training epoch 160, loss 0.0253
# Validation epoch 160, loss 0.1551
# Training epoch 161, loss 0.0244
# Validation epoch 161, loss 0.1554
# Training epoch 162, loss 0.0245
# Validation epoch 162, loss 0.1578
# Training epoch 163, loss 0.0254
# Validation epoch 163, loss 0.1609
# Training epoch 164, loss 0.0282
# Validation epoch 164, loss 0.1650
# Training epoch 165, loss 0.0287
# Validation epoch 165, loss 0.1672
# Training epoch 166, loss 0.0313
# Validation epoch 166, loss 0.1710
# Training epoch 167, loss 0.0353
# Validation epoch 167, loss 0.1905
# Training epoch 168, loss 0.0352
# Validation epoch 168, loss 0.1844
# Training epoch 169, loss 0.0332
# Validation epoch 169, loss 0.1568
# Training epoch 170, loss 0.0297
# Validation epoch 170, loss 0.1554
# Training epoch 171, loss 0.0254
# Validation epoch 171, loss 0.1568
# Training epoch 172, loss 0.0237
# Validation epoch 172, loss 0.1615
# Training epoch 173, loss 0.0235
# Validation epoch 173, loss 0.1664
# Training epoch 174, loss 0.0259
# Validation epoch 174, loss 0.1588
# Training epoch 175, loss 0.0294
# Validation epoch 175, loss 0.1557
# Training epoch 176, loss 0.0278
# Validation epoch 176, loss 0.1549
# Training epoch 177, loss 0.0292
# Validation epoch 177, loss 0.1594
# Training epoch 178, loss 0.0284
# Validation epoch 178, loss 0.1548
# Training epoch 179, loss 0.0263
# Validation epoch 179, loss 0.1582
# Training epoch 180, loss 0.0266
# Validation epoch 180, loss 0.1553
# Training epoch 181, loss 0.0297
# Validation epoch 181, loss 0.1755
# Training epoch 182, loss 0.0268
# Validation epoch 182, loss 0.1832
# Training epoch 183, loss 0.0261
# Validation epoch 183, loss 0.1745
# Training epoch 184, loss 0.0281
# Validation epoch 184, loss 0.1550
# Training epoch 185, loss 0.0256
# Validation epoch 185, loss 0.1537
# Training epoch 186, loss 0.0250
# Validation epoch 186, loss 0.1526
# Training epoch 187, loss 0.0248
# Validation epoch 187, loss 0.1577
# Training epoch 188, loss 0.0233
# Validation epoch 188, loss 0.1549
# Training epoch 189, loss 0.0240
# Validation epoch 189, loss 0.1535
# Training epoch 190, loss 0.0244
# Validation epoch 190, loss 0.1584
# Training epoch 191, loss 0.0279
# Validation epoch 191, loss 0.1639
# Training epoch 192, loss 0.0302
# Validation epoch 192, loss 0.1675
# Training epoch 193, loss 0.0336
# Validation epoch 193, loss 0.1762
# Training epoch 194, loss 0.0293
# Validation epoch 194, loss 0.1705
# Training epoch 195, loss 0.0248
# Validation epoch 195, loss 0.1698
# Training epoch 196, loss 0.0244
# Validation epoch 196, loss 0.1701
# Training epoch 197, loss 0.0249
# Validation epoch 197, loss 0.1784
# Training epoch 198, loss 0.0229
# Validation epoch 198, loss 0.1748
# Training epoch 199, loss 0.0216
# Validation epoch 199, loss 0.1623
# Training epoch 200, loss 0.0210
# Validation epoch 200, loss 0.1720
# Training epoch 201, loss 0.0206
# Validation epoch 201, loss 0.1790
# Training epoch 202, loss 0.0216
# Validation epoch 202, loss 0.1611
# Training epoch 203, loss 0.0222
# Validation epoch 203, loss 0.1543
# Training epoch 204, loss 0.0256
# Validation epoch 204, loss 0.1677
# Training epoch 205, loss 0.0250
# Validation epoch 205, loss 0.1687
# Training epoch 206, loss 0.0234
# Validation epoch 206, loss 0.1790
# Training epoch 207, loss 0.0226
# Validation epoch 207, loss 0.1815
# Training epoch 208, loss 0.0236
# Validation epoch 208, loss 0.1829
# Training epoch 209, loss 0.0242
# Validation epoch 209, loss 0.2068
# Training epoch 210, loss 0.0243
# Validation epoch 210, loss 0.1981
# Training epoch 211, loss 0.0258
# Validation epoch 211, loss 0.1905
# Training epoch 212, loss 0.0282
# Validation epoch 212, loss 0.1676
# Training epoch 213, loss 0.0301
# Validation epoch 213, loss 0.1674
# Training epoch 214, loss 0.0265
# Validation epoch 214, loss 0.1646
# Training epoch 215, loss 0.0221
# Validation epoch 215, loss 0.1623
# Training epoch 216, loss 0.0201
# Validation epoch 216, loss 0.1529
# Training epoch 217, loss 0.0206
# Validation epoch 217, loss 0.1572
# Training epoch 218, loss 0.0202
# Validation epoch 218, loss 0.1540
# Training epoch 219, loss 0.0191
# Validation epoch 219, loss 0.1606
# Training epoch 220, loss 0.0192
# Validation epoch 220, loss 0.1593
# Training epoch 221, loss 0.0192
# Validation epoch 221, loss 0.1579
# Training epoch 222, loss 0.0206
# Validation epoch 222, loss 0.1655
# Training epoch 223, loss 0.0204
# Validation epoch 223, loss 0.1618
# Training epoch 224, loss 0.0202
# Validation epoch 224, loss 0.1603
# Training epoch 225, loss 0.0206
# Validation epoch 225, loss 0.1576
# Training epoch 226, loss 0.0214
# Validation epoch 226, loss 0.1572
# Training epoch 227, loss 0.0235
# Validation epoch 227, loss 0.1604
# Training epoch 228, loss 0.0251
# Validation epoch 228, loss 0.1795
# Training epoch 229, loss 0.0247
# Validation epoch 229, loss 0.1688
# Training epoch 230, loss 0.0272
# Validation epoch 230, loss 0.1652
# Training epoch 231, loss 0.0310
# Validation epoch 231, loss 0.1617
# Training epoch 232, loss 0.0327
# Validation epoch 232, loss 0.1779
# Training epoch 233, loss 0.0283
# Validation epoch 233, loss 0.1638
# Training epoch 234, loss 0.0240
# Validation epoch 234, loss 0.1605
# Training epoch 235, loss 0.0212
# Validation epoch 235, loss 0.1584
# Training epoch 236, loss 0.0205
# Validation epoch 236, loss 0.1561
# Training epoch 237, loss 0.0191
# Validation epoch 237, loss 0.1568
# Training epoch 238, loss 0.0187
# Validation epoch 238, loss 0.1600
# Training epoch 239, loss 0.0186
# Validation epoch 239, loss 0.1613
# Training epoch 240, loss 0.0188
# Validation epoch 240, loss 0.1616
# Training epoch 241, loss 0.0188
# Validation epoch 241, loss 0.1572
# Training epoch 242, loss 0.0181
# Validation epoch 242, loss 0.1695
# Training epoch 243, loss 0.0182
# Validation epoch 243, loss 0.1720
# Training epoch 244, loss 0.0187
# Validation epoch 244, loss 0.1636
# Training epoch 245, loss 0.0193
# Validation epoch 245, loss 0.1634
# Training epoch 246, loss 0.0214
# Validation epoch 246, loss 0.1709
# Training epoch 247, loss 0.0220
# Validation epoch 247, loss 0.1679
# Training epoch 248, loss 0.0260
# Validation epoch 248, loss 0.1664
# Training epoch 249, loss 0.0251
# Validation epoch 249, loss 0.1584
# Training epoch 250, loss 0.0238
# Validation epoch 250, loss 0.1575
# Training epoch 251, loss 0.0214
# Validation epoch 251, loss 0.1574
# Training epoch 252, loss 0.0191
# Validation epoch 252, loss 0.1564
# Training epoch 253, loss 0.0188
# Validation epoch 253, loss 0.1611
# Training epoch 254, loss 0.0182
# Validation epoch 254, loss 0.1802
# Training epoch 255, loss 0.0183
# Validation epoch 255, loss 0.1871
# Training epoch 256, loss 0.0231
# Validation epoch 256, loss 0.1923
# Training epoch 257, loss 0.0203
# Validation epoch 257, loss 0.1726
# Training epoch 258, loss 0.0204
# Validation epoch 258, loss 0.1922
# Training epoch 259, loss 0.0194
# Validation epoch 259, loss 0.1767
# Training epoch 260, loss 0.0188
# Validation epoch 260, loss 0.1779
# Training epoch 261, loss 0.0187
# Validation epoch 261, loss 0.1586
# Training epoch 262, loss 0.0203
# Validation epoch 262, loss 0.1544
# Training epoch 263, loss 0.0226
# Validation epoch 263, loss 0.1507
# Training epoch 264, loss 0.0239
# Validation epoch 264, loss 0.1825
# Training epoch 265, loss 0.0245
# Validation epoch 265, loss 0.1597
# Training epoch 266, loss 0.0244
# Validation epoch 266, loss 0.1543
# Training epoch 267, loss 0.0238
# Validation epoch 267, loss 0.1539
# Training epoch 268, loss 0.0219
# Validation epoch 268, loss 0.1501
# Training epoch 269, loss 0.0208
# Validation epoch 269, loss 0.1597
# Training epoch 270, loss 0.0211
# Validation epoch 270, loss 0.1641
# Training epoch 271, loss 0.0214
# Validation epoch 271, loss 0.1561
# Training epoch 272, loss 0.0236
# Validation epoch 272, loss 0.1748
# Training epoch 273, loss 0.0235
# Validation epoch 273, loss 0.1881
# Training epoch 274, loss 0.0250
# Validation epoch 274, loss 0.1745
# Training epoch 275, loss 0.0251
# Validation epoch 275, loss 0.1561
# Training epoch 276, loss 0.0203
# Validation epoch 276, loss 0.1549
# Training epoch 277, loss 0.0184
# Validation epoch 277, loss 0.1571
# Training epoch 278, loss 0.0169
# Validation epoch 278, loss 0.1668
# Training epoch 279, loss 0.0169
# Validation epoch 279, loss 0.1737
# Training epoch 280, loss 0.0165
# Validation epoch 280, loss 0.1615
# Training epoch 281, loss 0.0170
# Validation epoch 281, loss 0.1661
# Training epoch 282, loss 0.0261
# Validation epoch 282, loss 0.1702
# Training epoch 283, loss 0.0212
# Validation epoch 283, loss 0.1566
# Training epoch 284, loss 0.0202
# Validation epoch 284, loss 0.1617
# Training epoch 285, loss 0.0198
# Validation epoch 285, loss 0.1565
# Training epoch 286, loss 0.0184
# Validation epoch 286, loss 0.1600
# Training epoch 287, loss 0.0168
# Validation epoch 287, loss 0.1637
# Training epoch 288, loss 0.0165
# Validation epoch 288, loss 0.1623
# Training epoch 289, loss 0.0170
# Validation epoch 289, loss 0.1781
# Training epoch 290, loss 0.0177
# Validation epoch 290, loss 0.1742
# Training epoch 291, loss 0.0190
# Validation epoch 291, loss 0.1594
# Training epoch 292, loss 0.0196
# Validation epoch 292, loss 0.1577
# Training epoch 293, loss 0.0183
# Validation epoch 293, loss 0.1582
# Training epoch 294, loss 0.0179
# Validation epoch 294, loss 0.1553
# Training epoch 295, loss 0.0188
# Validation epoch 295, loss 0.1576
# Training epoch 296, loss 0.0197
# Validation epoch 296, loss 0.1615
# Training epoch 297, loss 0.0201
# Validation epoch 297, loss 0.1590
# Training epoch 298, loss 0.0224
# Validation epoch 298, loss 0.1611
# Training epoch 299, loss 0.0204
# Validation epoch 299, loss 0.1565
# Training epoch 300, loss 0.0183
# Validation epoch 300, loss 0.1665
# Training epoch 301, loss 0.0185
# Validation epoch 301, loss 0.1630
# Training epoch 302, loss 0.0179
# Validation epoch 302, loss 0.1586
# Training epoch 303, loss 0.0178
# Validation epoch 303, loss 0.1602
# Training epoch 304, loss 0.0182
# Validation epoch 304, loss 0.1724
# Training epoch 305, loss 0.0182
# Validation epoch 305, loss 0.1750
# Training epoch 306, loss 0.0199
# Validation epoch 306, loss 0.2081
# Training epoch 307, loss 0.0232
# Validation epoch 307, loss 0.2408
# Training epoch 308, loss 0.0296
# Validation epoch 308, loss 0.1777
# Training epoch 309, loss 0.0297
# Validation epoch 309, loss 0.1587
# Training epoch 310, loss 0.0223
# Validation epoch 310, loss 0.1515
# Training epoch 311, loss 0.0170
# Validation epoch 311, loss 0.1495
# Training epoch 312, loss 0.0151
# Validation epoch 312, loss 0.1518
# Training epoch 313, loss 0.0140
# Validation epoch 313, loss 0.1592
# Training epoch 314, loss 0.0139
# Validation epoch 314, loss 0.1553
# Training epoch 315, loss 0.0134
# Validation epoch 315, loss 0.1554
# Training epoch 316, loss 0.0142
# Validation epoch 316, loss 0.1560
# Training epoch 317, loss 0.0155
# Validation epoch 317, loss 0.1624
# Training epoch 318, loss 0.0174
# Validation epoch 318, loss 0.1603
# Training epoch 319, loss 0.0210
# Validation epoch 319, loss 0.1694
# Training epoch 320, loss 0.0197
# Validation epoch 320, loss 0.1616
# Training epoch 321, loss 0.0180
# Validation epoch 321, loss 0.1670
# Training epoch 322, loss 0.0159
# Validation epoch 322, loss 0.1620
# Training epoch 323, loss 0.0154
# Validation epoch 323, loss 0.1516
# Training epoch 324, loss 0.0152
# Validation epoch 324, loss 0.1648
# Training epoch 325, loss 0.0151
# Validation epoch 325, loss 0.1560
# Training epoch 326, loss 0.0160
# Validation epoch 326, loss 0.1604
# Training epoch 327, loss 0.0169
# Validation epoch 327, loss 0.1589
# Training epoch 328, loss 0.0176
# Validation epoch 328, loss 0.1599
# Training epoch 329, loss 0.0185
# Validation epoch 329, loss 0.1634
# Training epoch 330, loss 0.0195
# Validation epoch 330, loss 0.1650
# Training epoch 331, loss 0.0207
# Validation epoch 331, loss 0.1636
# Training epoch 332, loss 0.0204
# Validation epoch 332, loss 0.1705
# Training epoch 333, loss 0.0212
# Validation epoch 333, loss 0.1706
# Training epoch 334, loss 0.0199
# Validation epoch 334, loss 0.1546
# Training epoch 335, loss 0.0169
# Validation epoch 335, loss 0.1542
# Training epoch 336, loss 0.0159
# Validation epoch 336, loss 0.1526
# Training epoch 337, loss 0.0156
# Validation epoch 337, loss 0.1548
# Training epoch 338, loss 0.0162
# Validation epoch 338, loss 0.1548
# Training epoch 339, loss 0.0162
# Validation epoch 339, loss 0.1551
# Training epoch 340, loss 0.0160
# Validation epoch 340, loss 0.1562
# Training epoch 341, loss 0.0156
# Validation epoch 341, loss 0.1568
# Training epoch 342, loss 0.0174
# Validation epoch 342, loss 0.1716
# Training epoch 343, loss 0.0193
# Validation epoch 343, loss 0.1586
# Training epoch 344, loss 0.0204
# Validation epoch 344, loss 0.1640
# Training epoch 345, loss 0.0203
# Validation epoch 345, loss 0.1658
# Training epoch 346, loss 0.0191
# Validation epoch 346, loss 0.1547
# Training epoch 347, loss 0.0179
# Validation epoch 347, loss 0.1565
# Training epoch 348, loss 0.0162
# Validation epoch 348, loss 0.1579
# Training epoch 349, loss 0.0161
# Validation epoch 349, loss 0.1575
# Training epoch 350, loss 0.0160
# Validation epoch 350, loss 0.1608
# Training epoch 351, loss 0.0168
# Validation epoch 351, loss 0.1616
# Training epoch 352, loss 0.0181
# Validation epoch 352, loss 0.1652
# Training epoch 353, loss 0.0211
# Validation epoch 353, loss 0.2043
# Training epoch 354, loss 0.0239
# Validation epoch 354, loss 0.1671
# Training epoch 355, loss 0.0227
# Validation epoch 355, loss 0.1656
# Training epoch 356, loss 0.0213
# Validation epoch 356, loss 0.1544
# Training epoch 357, loss 0.0154
# Validation epoch 357, loss 0.1555
# Training epoch 358, loss 0.0132
# Validation epoch 358, loss 0.1535
# Training epoch 359, loss 0.0123
# Validation epoch 359, loss 0.1538
# Training epoch 360, loss 0.0135
# Validation epoch 360, loss 0.1546
# Training epoch 361, loss 0.0168
# Validation epoch 361, loss 0.1589
# Training epoch 362, loss 0.0180
# Validation epoch 362, loss 0.1616
# Training epoch 363, loss 0.0195
# Validation epoch 363, loss 0.1790
# Training epoch 364, loss 0.0171
# Validation epoch 364, loss 0.1613
# Training epoch 365, loss 0.0163
# Validation epoch 365, loss 0.1593
# Training epoch 366, loss 0.0179
# Validation epoch 366, loss 0.1592
# Training epoch 367, loss 0.0207
# Validation epoch 367, loss 0.1608
# Training epoch 368, loss 0.0233
# Validation epoch 368, loss 0.1611
# Training epoch 369, loss 0.0184
# Validation epoch 369, loss 0.1564
# Training epoch 370, loss 0.0151
# Validation epoch 370, loss 0.1593
# Training epoch 371, loss 0.0141
# Validation epoch 371, loss 0.1598
# Training epoch 372, loss 0.0136
# Validation epoch 372, loss 0.1614
# Training epoch 373, loss 0.0148
# Validation epoch 373, loss 0.1622
# Training epoch 374, loss 0.0169
# Validation epoch 374, loss 0.1565
# Training epoch 375, loss 0.0215
# Validation epoch 375, loss 0.1797
# Training epoch 376, loss 0.0287
# Validation epoch 376, loss 0.1693
# Training epoch 377, loss 0.0245
# Validation epoch 377, loss 0.1741
# Training epoch 378, loss 0.0206
# Validation epoch 378, loss 0.1729
# Training epoch 379, loss 0.0180
# Validation epoch 379, loss 0.1737
# Training epoch 380, loss 0.0164
# Validation epoch 380, loss 0.1633
# Training epoch 381, loss 0.0161
# Validation epoch 381, loss 0.1544
# Training epoch 382, loss 0.0159
# Validation epoch 382, loss 0.1565
# Training epoch 383, loss 0.0172
# Validation epoch 383, loss 0.1618
# Training epoch 384, loss 0.0171
# Validation epoch 384, loss 0.1636
# Training epoch 385, loss 0.0180
# Validation epoch 385, loss 0.1632
# Training epoch 386, loss 0.0203
# Validation epoch 386, loss 0.1635
# Training epoch 387, loss 0.0255
# Validation epoch 387, loss 0.1634
# Training epoch 388, loss 0.0249
# Validation epoch 388, loss 0.1653
# Training epoch 389, loss 0.0225
# Validation epoch 389, loss 0.1574
# Training epoch 390, loss 0.0206
# Validation epoch 390, loss 0.1570
# Training epoch 391, loss 0.0176
# Validation epoch 391, loss 0.1628
# Training epoch 392, loss 0.0155
# Validation epoch 392, loss 0.1617
# Training epoch 393, loss 0.0150
# Validation epoch 393, loss 0.1622
# Training epoch 394, loss 0.0159
# Validation epoch 394, loss 0.1722
# Training epoch 395, loss 0.0177
# Validation epoch 395, loss 0.1717
# Training epoch 396, loss 0.0165
# Validation epoch 396, loss 0.1826
# Training epoch 397, loss 0.0168
# Validation epoch 397, loss 0.1641
# Training epoch 398, loss 0.0171
# Validation epoch 398, loss 0.1617
# Training epoch 399, loss 0.0156
# Validation epoch 399, loss 0.1586

# %%
#%% K-fold training, validation and test
kf = KFold(n_splits=5); kf.get_n_splits(shuffled_dataset)
val_err = 0
for tr_idx, ts_idx in kf.split(shuffled_dataset):
    trainset, testset = shuffled_dataset[tr_idx], shuffled_dataset[ts_idx]
    trainset = tuple(trainset); testset = tuple(testset)

    tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
    va_data_loader = DataLoader(testset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

    model = Regressor().to(torch.device('cuda:0'))
    loss_func = nn.MSELoss(reduction='mean').cuda()

    optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
        weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

    tr_epoch_losses = []
    va_epoch_losses = []

    for epoch in range(hp_d['num_epochs']):                             #!! epoch-loop
        # training session
        model.train()
        tr_epoch_loss = 0

        for iter, (seq, smi, label) in enumerate(tr_data_loader):       #!! batch-loop
            prediction = model(seq, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tr_epoch_loss += loss.detach().item()

        tr_epoch_loss /= (iter + 1)
        print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
        tr_epoch_losses.append(tr_epoch_loss)

    # ===========================================================================
        # validation session
        model.eval()
        va_epoch_loss = 0

        for iter, (seq, smi, label) in enumerate(va_data_loader):  # batch-loop
            prediction = model(seq, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            va_epoch_loss += loss.detach().item()

        va_epoch_loss /= (iter + 1)
        print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
        va_epoch_losses.append(va_epoch_loss)
    val_err += min(va_epoch_losses)
print('10-fold CVMSE:', val_err/10)
