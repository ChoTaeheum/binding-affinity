# %%
#%% library import
import numpy as np
import pandas as pd
import networkx as nx
import torch as tc
import torch
import pprint
import pickle
import time

from torch.autograd import Variable
from sklearn.utils import shuffle
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import DataLoader
from functools import partial
from sklearn.model_selection import KFold

# %%
#%% Load dataset and cuda
dataset = pd.read_csv("datasets/KIBA.csv")
datalen = len(dataset)
cuda = tc.device('cuda')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
#%% protein-ligand-kiba split
protein = dataset.loc[:, "uniprotID"]    # 5
ligand = dataset.loc[:, "chemblID"]
kiba = list(dataset.loc[:, 'KIBA'])
del dataset

# %%
#%% protein sequence load
f = open('datasets/dictionaries/prt_tfidf.txt', 'rb')
tfidf_dic = pickle.load(f)
f.close()

tfidf = np.zeros((datalen, 400))
for i, s in enumerate(protein):
    tfidf[i] = tfidf_dic[s]

# %%
#%% ligand smiles load
f = open('datasets/dictionaries/lgn_smiecoding.txt', 'rb')
smi_dic = pickle.load(f)
f.close()

smileseq = np.zeros((datalen, 590))
for i, e in enumerate(ligand):
    smileseq[i] = smi_dic[e]

smileseq = smileseq[:, :100]

# %%
#%% dataset zip
revised_dataset = list(zip(tfidf, smileseq, kiba))
shuffled_dataset = np.array(shuffle(revised_dataset)); del revised_dataset

# %%
#%% Make collate func.
def collate(samples):
    tfidf, smileseq, labels = map(list, zip(*samples))
    return tc.tensor(tfidf, dtype=tc.float).cuda(), tc.LongTensor(smileseq).cuda(), tc.tensor(labels).cuda()

# %%
#%% learning module 선언
class Regressor(nn.Module):
    def __init__(self):
        super(Regressor, self).__init__()    # method 상속받고 __init__()은 여기서 하겠다.
        
        self.prt_cv1dlayers = nn.Sequential(
                        nn.Conv1d(1, 1, kernel_size = 32),
                        nn.BatchNorm1d(num_features = 1),
                        nn.ReLU()
                        )
        
        self.fc = nn.Linear(369, 256, F.relu)
        
        
        ######################################################################
        ######################################################################
        
        self.lgn_emlayer = nn.Embedding(64, 10)
        
        self.lgn_cv1dlayers = nn.Sequential(
                        nn.Conv1d(10, 32, kernel_size = 4),
                        nn.BatchNorm1d(num_features = 32),
                        nn.ReLU(),
                        nn.Conv1d(32, 64, kernel_size = 6),
                        nn.BatchNorm1d(num_features = 64),
                        nn.ReLU(),
                        nn.Conv1d(64, 96, kernel_size = 8),
                        nn.BatchNorm1d(num_features = 96),
                        nn.ReLU(),
                        nn.MaxPool1d(kernel_size = 85)
                        )
        
        
        self.mlplayers = nn.Sequential(
                        nn.Linear(352, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 1024),
                        nn.BatchNorm1d(1024),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(1024, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU(),
                        nn.Dropout(0.1),
                        nn.Linear(512, 512),
                        nn.BatchNorm1d(512),
                        nn.ReLU()
                        )

        self.regress = nn.Linear(512, 1)    # regression

    def forward(self, prt_seq, lgn_seq):   
        p = prt_seq.unsqueeze(1)
        p = self.prt_cv1dlayers(p)
        p = p.squeeze()
        p = self.fc(p)
        
        l = self.lgn_emlayer(lgn_seq)
        l = l.permute(0, 2, 1)
        l = self.lgn_cv1dlayers(l)
        l = l.squeeze()
        
        cat = tc.cat((p, l), axis=1).cuda()
        out = self.mlplayers(cat)
        out = out.squeeze()
        
        return self.regress(out).cuda()

# %%
#%% Set hyperparameter
hp_d = {}

# FIXME: 학습 관련 하이퍼파라미터
hp_d['batch_size'] = 512
hp_d['num_epochs'] = 100

hp_d['init_learning_rate'] = 10 ** -3.493
hp_d['eps'] = 10 ** -8.493
hp_d['weight_decay'] = 10 ** -5.972

# %%
#%% training and validation
kf = KFold(n_splits=5); kf.get_n_splits(shuffled_dataset)
val_err = 0
for tr_idx, ts_idx in kf.split(shuffled_dataset):
    trainset, testset = shuffled_dataset[tr_idx], shuffled_dataset[ts_idx]
    trainset = tuple(trainset); testset = tuple(testset)

    tr_data_loader = DataLoader(trainset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)
    va_data_loader = DataLoader(testset, batch_size=hp_d['batch_size'], shuffle=False, collate_fn=collate)

    model = Regressor().to(torch.device('cuda:0'))
    loss_func = nn.MSELoss(reduction='mean').cuda()

    optimizer = optim.Adam(model.parameters(), lr=hp_d['init_learning_rate'], 
        weight_decay=hp_d['weight_decay'], eps=hp_d['eps'])

    tr_epoch_losses = []
    va_epoch_losses = []

    for epoch in range(hp_d['num_epochs']):                             #!! epoch-loop
        # training session
        model.train()
        tr_epoch_loss = 0

        for iter, (tfidf, smi, label) in enumerate(tr_data_loader):       #!! batch-loop
            prediction = model(tfidf, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tr_epoch_loss += loss.detach().item()

        tr_epoch_loss /= (iter + 1)
        print('Training epoch {}, loss {:.4f}'.format(epoch, tr_epoch_loss))
        tr_epoch_losses.append(tr_epoch_loss)

    # ===========================================================================
        # validation session
        model.eval()
        va_epoch_loss = 0

        for iter, (tfidf, smi, label) in enumerate(va_data_loader):  # batch-loop
            prediction = model(tfidf, smi).view(-1).cuda()
            loss = loss_func(prediction, label).cuda()

            va_epoch_loss += loss.detach().item()

        va_epoch_loss /= (iter + 1)
        print('Validation epoch {}, loss {:.4f}'.format(epoch, va_epoch_loss))
        va_epoch_losses.append(va_epoch_loss)
    val_err += min(va_epoch_losses)
print('5-fold CVMSE:', val_err/5)
# Out:
# Training epoch 0, loss 35.7098
# Validation epoch 0, loss 2.0925
# Training epoch 1, loss 0.9075
# Validation epoch 1, loss 0.5333
# Training epoch 2, loss 0.6346
# Validation epoch 2, loss 0.5028
# Training epoch 3, loss 0.5493
# Validation epoch 3, loss 0.4240
# Training epoch 4, loss 0.4763
# Validation epoch 4, loss 0.3912
# Training epoch 5, loss 0.3952
# Validation epoch 5, loss 0.3447
# Training epoch 6, loss 0.3361
# Validation epoch 6, loss 0.3271
# Training epoch 7, loss 0.3029
# Validation epoch 7, loss 0.3117
# Training epoch 8, loss 0.2800
# Validation epoch 8, loss 0.2916
# Training epoch 9, loss 0.2666
# Validation epoch 9, loss 0.2805
# Training epoch 10, loss 0.2516
# Validation epoch 10, loss 0.2869
# Training epoch 11, loss 0.2427
# Validation epoch 11, loss 0.2631
# Training epoch 12, loss 0.2422
# Validation epoch 12, loss 0.2555
# Training epoch 13, loss 0.2389
# Validation epoch 13, loss 0.2834
# Training epoch 14, loss 0.2278
# Validation epoch 14, loss 0.2738
# Training epoch 15, loss 0.2225
# Validation epoch 15, loss 0.2551
# Training epoch 16, loss 0.2175
# Validation epoch 16, loss 0.2707
# Training epoch 17, loss 0.2056
# Validation epoch 17, loss 0.2592
# Training epoch 18, loss 0.2012
# Validation epoch 18, loss 0.2536
# Training epoch 19, loss 0.1925
# Validation epoch 19, loss 0.3455
# Training epoch 20, loss 0.1790
# Validation epoch 20, loss 0.2785
# Training epoch 21, loss 0.1764
# Validation epoch 21, loss 0.3120
# Training epoch 22, loss 0.1812
# Validation epoch 22, loss 0.2847
# Training epoch 23, loss 0.1784
# Validation epoch 23, loss 0.2692
# Training epoch 24, loss 0.1711
# Validation epoch 24, loss 0.2631
# Training epoch 25, loss 0.1567
# Validation epoch 25, loss 0.2372
# Training epoch 26, loss 0.1549
# Validation epoch 26, loss 0.2345
# Training epoch 27, loss 0.1494
# Validation epoch 27, loss 0.3300
# Training epoch 28, loss 0.1496
# Validation epoch 28, loss 0.2351
# Training epoch 29, loss 0.1427
# Validation epoch 29, loss 0.2298
# Training epoch 30, loss 0.1388
# Validation epoch 30, loss 0.2180
# Training epoch 31, loss 0.1342
# Validation epoch 31, loss 0.2726
# Training epoch 32, loss 0.1290
# Validation epoch 32, loss 0.2259
# Training epoch 33, loss 0.1314
# Validation epoch 33, loss 0.2574
# Training epoch 34, loss 0.1285
# Validation epoch 34, loss 0.2352
# Training epoch 35, loss 0.1315
# Validation epoch 35, loss 0.2224
# Training epoch 36, loss 0.1320
# Validation epoch 36, loss 0.2410
# Training epoch 37, loss 0.1287
# Validation epoch 37, loss 0.2117
# Training epoch 38, loss 0.1316
# Validation epoch 38, loss 0.2118
# Training epoch 39, loss 0.1278
# Validation epoch 39, loss 0.2101
# Training epoch 40, loss 0.1280
# Validation epoch 40, loss 0.2161
# Training epoch 41, loss 0.1349
# Validation epoch 41, loss 0.2145
# Training epoch 42, loss 0.1315
# Validation epoch 42, loss 0.2138
# Training epoch 43, loss 0.1314
# Validation epoch 43, loss 0.2267
# Training epoch 44, loss 0.1352
# Validation epoch 44, loss 0.2329
# Training epoch 45, loss 0.1246
# Validation epoch 45, loss 0.2441
# Training epoch 46, loss 0.1223
# Validation epoch 46, loss 0.2327
# Training epoch 47, loss 0.1184
# Validation epoch 47, loss 0.2747
# Training epoch 48, loss 0.1178
# Validation epoch 48, loss 0.2744
# Training epoch 49, loss 0.1003
# Validation epoch 49, loss 0.2772
# Training epoch 50, loss 0.1004
# Validation epoch 50, loss 0.2223
# Training epoch 51, loss 0.0961
# Validation epoch 51, loss 0.1965
# Training epoch 52, loss 0.0951
# Validation epoch 52, loss 0.2118
# Training epoch 53, loss 0.1014
# Validation epoch 53, loss 0.2171
# Training epoch 54, loss 0.0933
# Validation epoch 54, loss 0.2156
# Training epoch 55, loss 0.0957
# Validation epoch 55, loss 0.2393
# Training epoch 56, loss 0.0953
# Validation epoch 56, loss 0.2347
# Training epoch 57, loss 0.0959
# Validation epoch 57, loss 0.2705
# Training epoch 58, loss 0.0960
# Validation epoch 58, loss 0.2744
# Training epoch 59, loss 0.0982
# Validation epoch 59, loss 0.2110
# Training epoch 60, loss 0.0946
# Validation epoch 60, loss 0.2435
# Training epoch 61, loss 0.1058
# Validation epoch 61, loss 0.2730
# Training epoch 62, loss 0.0975
# Validation epoch 62, loss 0.2599
# Training epoch 63, loss 0.1041
# Validation epoch 63, loss 0.2157
# Training epoch 64, loss 0.1052
# Validation epoch 64, loss 0.2028
# Training epoch 65, loss 0.1017
# Validation epoch 65, loss 0.1942
# Training epoch 66, loss 0.0955
# Validation epoch 66, loss 0.1914
# Training epoch 67, loss 0.0965
# Validation epoch 67, loss 0.2130
# Training epoch 68, loss 0.0905
# Validation epoch 68, loss 0.2381
# Training epoch 69, loss 0.0968
# Validation epoch 69, loss 0.2155
# Training epoch 70, loss 0.0856
# Validation epoch 70, loss 0.2545
# Training epoch 71, loss 0.0877
# Validation epoch 71, loss 0.2201
# Training epoch 72, loss 0.0946
# Validation epoch 72, loss 0.2903
# Training epoch 73, loss 0.0893
# Validation epoch 73, loss 0.2543
# Training epoch 74, loss 0.0827
# Validation epoch 74, loss 0.2488
# Training epoch 75, loss 0.0781
# Validation epoch 75, loss 0.2141
# Training epoch 76, loss 0.0759
# Validation epoch 76, loss 0.2071
# Training epoch 77, loss 0.0763
# Validation epoch 77, loss 0.1788
# Training epoch 78, loss 0.0715
# Validation epoch 78, loss 0.2083
# Training epoch 79, loss 0.0758
# Validation epoch 79, loss 0.2051
# Training epoch 80, loss 0.0753
# Validation epoch 80, loss 0.2097
# Training epoch 81, loss 0.0811
# Validation epoch 81, loss 0.2126
# Training epoch 82, loss 0.0713
# Validation epoch 82, loss 0.2023
# Training epoch 83, loss 0.0671
# Validation epoch 83, loss 0.2597
# Training epoch 84, loss 0.0677
# Validation epoch 84, loss 0.2346
# Training epoch 85, loss 0.0657
# Validation epoch 85, loss 0.1863
# Training epoch 86, loss 0.0720
# Validation epoch 86, loss 0.2327
# Training epoch 87, loss 0.0658
# Validation epoch 87, loss 0.2204
# Training epoch 88, loss 0.0675
# Validation epoch 88, loss 0.2109
# Training epoch 89, loss 0.0694
# Validation epoch 89, loss 0.2039
# Training epoch 90, loss 0.0741
# Validation epoch 90, loss 0.1858
# Training epoch 91, loss 0.0673
# Validation epoch 91, loss 0.1778
# Training epoch 92, loss 0.0708
# Validation epoch 92, loss 0.1808
# Training epoch 93, loss 0.0725
# Validation epoch 93, loss 0.1984
# Training epoch 94, loss 0.0729
# Validation epoch 94, loss 0.1787
# Training epoch 95, loss 0.0640
# Validation epoch 95, loss 0.1881
# Training epoch 96, loss 0.0625
# Validation epoch 96, loss 0.2034
# Training epoch 97, loss 0.0639
# Validation epoch 97, loss 0.2234
# Training epoch 98, loss 0.0693
# Validation epoch 98, loss 0.1943
# Training epoch 99, loss 0.0681
# Validation epoch 99, loss 0.1908
# Training epoch 0, loss 34.7990
# Validation epoch 0, loss 1.5858
# Training epoch 1, loss 0.8664
# Validation epoch 1, loss 0.5228
# Training epoch 2, loss 0.6214
# Validation epoch 2, loss 0.4499
# Training epoch 3, loss 0.5441
# Validation epoch 3, loss 0.3942
# Training epoch 4, loss 0.4636
# Validation epoch 4, loss 0.3356
# Training epoch 5, loss 0.3979
# Validation epoch 5, loss 0.3348
# Training epoch 6, loss 0.3377
# Validation epoch 6, loss 0.3016
# Training epoch 7, loss 0.2941
# Validation epoch 7, loss 0.2920
# Training epoch 8, loss 0.2656
# Validation epoch 8, loss 0.2724
# Training epoch 9, loss 0.2576
# Validation epoch 9, loss 0.2695
# Training epoch 10, loss 0.2492
# Validation epoch 10, loss 0.2717
# Training epoch 11, loss 0.2330
# Validation epoch 11, loss 0.2679
# Training epoch 12, loss 0.2220
# Validation epoch 12, loss 0.2848
# Training epoch 13, loss 0.2052
# Validation epoch 13, loss 0.3185
# Training epoch 14, loss 0.1979
# Validation epoch 14, loss 0.2585
# Training epoch 15, loss 0.1957
# Validation epoch 15, loss 0.2877
# Training epoch 16, loss 0.1984
# Validation epoch 16, loss 0.3311
# Training epoch 17, loss 0.1926
# Validation epoch 17, loss 0.3406
# Training epoch 18, loss 0.1909
# Validation epoch 18, loss 0.3120
# Training epoch 19, loss 0.1906
# Validation epoch 19, loss 0.2530
# Training epoch 20, loss 0.1797
# Validation epoch 20, loss 0.2834
# Training epoch 21, loss 0.1694
# Validation epoch 21, loss 0.2459
# Training epoch 22, loss 0.1575
# Validation epoch 22, loss 0.2412
# Training epoch 23, loss 0.1595
# Validation epoch 23, loss 0.2866
# Training epoch 24, loss 0.1549
# Validation epoch 24, loss 0.4149
# Training epoch 25, loss 0.1498
# Validation epoch 25, loss 0.2784
# Training epoch 26, loss 0.1423
# Validation epoch 26, loss 0.2545
# Training epoch 27, loss 0.1411
# Validation epoch 27, loss 0.2358
# Training epoch 28, loss 0.1416
# Validation epoch 28, loss 0.2233
# Training epoch 29, loss 0.1348
# Validation epoch 29, loss 0.2409
# Training epoch 30, loss 0.1373
# Validation epoch 30, loss 0.2238
# Training epoch 31, loss 0.1400
# Validation epoch 31, loss 0.2441
# Training epoch 32, loss 0.1419
# Validation epoch 32, loss 0.3018
# Training epoch 33, loss 0.1367
# Validation epoch 33, loss 0.2435
# Training epoch 34, loss 0.1292
# Validation epoch 34, loss 0.2253
# Training epoch 35, loss 0.1168
# Validation epoch 35, loss 0.2214
# Training epoch 36, loss 0.1221
# Validation epoch 36, loss 0.2300
# Training epoch 37, loss 0.1227
# Validation epoch 37, loss 0.2844
# Training epoch 38, loss 0.1359
# Validation epoch 38, loss 0.2193
# Training epoch 39, loss 0.1183
# Validation epoch 39, loss 0.2363
# Training epoch 40, loss 0.1204
# Validation epoch 40, loss 0.2369
# Training epoch 41, loss 0.1198
# Validation epoch 41, loss 0.2285
# Training epoch 42, loss 0.1163
# Validation epoch 42, loss 0.2309
# Training epoch 43, loss 0.1253
# Validation epoch 43, loss 0.2619
# Training epoch 44, loss 0.1215
# Validation epoch 44, loss 0.2833
# Training epoch 45, loss 0.1131
# Validation epoch 45, loss 0.2645
# Training epoch 46, loss 0.1145
# Validation epoch 46, loss 0.2501
# Training epoch 47, loss 0.1127
# Validation epoch 47, loss 0.2309
# Training epoch 48, loss 0.1195
# Validation epoch 48, loss 0.2256
# Training epoch 49, loss 0.1087
# Validation epoch 49, loss 0.2494
# Training epoch 50, loss 0.1065
# Validation epoch 50, loss 0.2690
# Training epoch 51, loss 0.1055
# Validation epoch 51, loss 0.2324
# Training epoch 52, loss 0.1031
# Validation epoch 52, loss 0.2332
# Training epoch 53, loss 0.1052
# Validation epoch 53, loss 0.2107
# Training epoch 54, loss 0.1069
# Validation epoch 54, loss 0.2215
# Training epoch 55, loss 0.1085
# Validation epoch 55, loss 0.2346
# Training epoch 56, loss 0.1052
# Validation epoch 56, loss 0.2284
# Training epoch 57, loss 0.0902
# Validation epoch 57, loss 0.1953
# Training epoch 58, loss 0.0895
# Validation epoch 58, loss 0.2083
# Training epoch 59, loss 0.0925
# Validation epoch 59, loss 0.2205
# Training epoch 60, loss 0.0897
# Validation epoch 60, loss 0.2043
# Training epoch 61, loss 0.0856
# Validation epoch 61, loss 0.2087
# Training epoch 62, loss 0.0870
# Validation epoch 62, loss 0.2040
# Training epoch 63, loss 0.0889
# Validation epoch 63, loss 0.2071
# Training epoch 64, loss 0.0847
# Validation epoch 64, loss 0.2466
# Training epoch 65, loss 0.0850
# Validation epoch 65, loss 0.2184
# Training epoch 66, loss 0.0813
# Validation epoch 66, loss 0.2287
# Training epoch 67, loss 0.0861
# Validation epoch 67, loss 0.2275
# Training epoch 68, loss 0.0896
# Validation epoch 68, loss 0.2270
# Training epoch 69, loss 0.0906
# Validation epoch 69, loss 0.2373
# Training epoch 70, loss 0.0879
# Validation epoch 70, loss 0.2351
# Training epoch 71, loss 0.0890
# Validation epoch 71, loss 0.2105
# Training epoch 72, loss 0.0927
# Validation epoch 72, loss 0.2082
# Training epoch 73, loss 0.0874
# Validation epoch 73, loss 0.2256
# Training epoch 74, loss 0.0810
# Validation epoch 74, loss 0.2407
# Training epoch 75, loss 0.0773
# Validation epoch 75, loss 0.3128
# Training epoch 76, loss 0.0796
# Validation epoch 76, loss 0.2888
# Training epoch 77, loss 0.0815
# Validation epoch 77, loss 0.2461
# Training epoch 78, loss 0.0886
# Validation epoch 78, loss 0.2382
# Training epoch 79, loss 0.0866
# Validation epoch 79, loss 0.1982
# Training epoch 80, loss 0.0775
# Validation epoch 80, loss 0.1944
# Training epoch 81, loss 0.0813
# Validation epoch 81, loss 0.1997
# Training epoch 82, loss 0.0728
# Validation epoch 82, loss 0.2097
# Training epoch 83, loss 0.0740
# Validation epoch 83, loss 0.2114
# Training epoch 84, loss 0.0779
# Validation epoch 84, loss 0.1973
# Training epoch 85, loss 0.0706
# Validation epoch 85, loss 0.2164
# Training epoch 86, loss 0.0697
# Validation epoch 86, loss 0.2098
# Training epoch 87, loss 0.0680
# Validation epoch 87, loss 0.1875
# Training epoch 88, loss 0.0684
# Validation epoch 88, loss 0.1991
# Training epoch 89, loss 0.0694
# Validation epoch 89, loss 0.2110
# Training epoch 90, loss 0.0685
# Validation epoch 90, loss 0.2536
# Training epoch 91, loss 0.0649
# Validation epoch 91, loss 0.2990
# Training epoch 92, loss 0.0711
# Validation epoch 92, loss 0.2893
# Training epoch 93, loss 0.0751
# Validation epoch 93, loss 0.3001
# Training epoch 94, loss 0.0719
# Validation epoch 94, loss 0.2820
# Training epoch 95, loss 0.0671
# Validation epoch 95, loss 0.2175
# Training epoch 96, loss 0.0627
# Validation epoch 96, loss 0.2309
# Training epoch 97, loss 0.0653
# Validation epoch 97, loss 0.1938
# Training epoch 98, loss 0.0626
# Validation epoch 98, loss 0.1908
# Training epoch 99, loss 0.0649
# Validation epoch 99, loss 0.1913
# Training epoch 0, loss 37.8368
# Validation epoch 0, loss 2.1010
# Training epoch 1, loss 0.9021
# Validation epoch 1, loss 0.4737
# Training epoch 2, loss 0.6147
# Validation epoch 2, loss 0.4363
# Training epoch 3, loss 0.5313
# Validation epoch 3, loss 0.4207
# Training epoch 4, loss 0.4662
# Validation epoch 4, loss 0.3830
# Training epoch 5, loss 0.3881
# Validation epoch 5, loss 0.3274
# Training epoch 6, loss 0.3221
# Validation epoch 6, loss 0.3284
# Training epoch 7, loss 0.2772
# Validation epoch 7, loss 0.3152
# Training epoch 8, loss 0.2536
# Validation epoch 8, loss 0.3069
# Training epoch 9, loss 0.2466
# Validation epoch 9, loss 0.3118
# Training epoch 10, loss 0.2364
# Validation epoch 10, loss 0.2475
# Training epoch 11, loss 0.2252
# Validation epoch 11, loss 0.2632
# Training epoch 12, loss 0.2141
# Validation epoch 12, loss 0.2869
# Training epoch 13, loss 0.2154
# Validation epoch 13, loss 0.2738
# Training epoch 14, loss 0.2019
# Validation epoch 14, loss 0.2583
# Training epoch 15, loss 0.1992
# Validation epoch 15, loss 0.2508
# Training epoch 16, loss 0.1885
# Validation epoch 16, loss 0.2382
# Training epoch 17, loss 0.1766
# Validation epoch 17, loss 0.2443
# Training epoch 18, loss 0.1786
# Validation epoch 18, loss 0.2865
# Training epoch 19, loss 0.1696
# Validation epoch 19, loss 0.2601
# Training epoch 20, loss 0.1648
# Validation epoch 20, loss 0.2604
# Training epoch 21, loss 0.1608
# Validation epoch 21, loss 0.2344
# Training epoch 22, loss 0.1604
# Validation epoch 22, loss 0.2513
# Training epoch 23, loss 0.1631
# Validation epoch 23, loss 0.2437
# Training epoch 24, loss 0.1593
# Validation epoch 24, loss 0.2423
# Training epoch 25, loss 0.1567
# Validation epoch 25, loss 0.2346
# Training epoch 26, loss 0.1648
# Validation epoch 26, loss 0.2362
# Training epoch 27, loss 0.1552
# Validation epoch 27, loss 0.2177
# Training epoch 28, loss 0.1479
# Validation epoch 28, loss 0.2234
# Training epoch 29, loss 0.1439
# Validation epoch 29, loss 0.2236
# Training epoch 30, loss 0.1366
# Validation epoch 30, loss 0.2220
# Training epoch 31, loss 0.1309
# Validation epoch 31, loss 0.2105
# Training epoch 32, loss 0.1345
# Validation epoch 32, loss 0.2587
# Training epoch 33, loss 0.1326
# Validation epoch 33, loss 0.2369
# Training epoch 34, loss 0.1350
# Validation epoch 34, loss 0.2605
# Training epoch 35, loss 0.1337
# Validation epoch 35, loss 0.3162
# Training epoch 36, loss 0.1255
# Validation epoch 36, loss 0.2350
# Training epoch 37, loss 0.1175
# Validation epoch 37, loss 0.2070
# Training epoch 38, loss 0.1194
# Validation epoch 38, loss 0.3070
# Training epoch 39, loss 0.1189
# Validation epoch 39, loss 0.2624
# Training epoch 40, loss 0.1190
# Validation epoch 40, loss 0.2490
# Training epoch 41, loss 0.1150
# Validation epoch 41, loss 0.2398
# Training epoch 42, loss 0.1135
# Validation epoch 42, loss 0.2530
# Training epoch 43, loss 0.1098
# Validation epoch 43, loss 0.2045
# Training epoch 44, loss 0.1127
# Validation epoch 44, loss 0.2381
# Training epoch 45, loss 0.1177
# Validation epoch 45, loss 0.2401
# Training epoch 46, loss 0.1178
# Validation epoch 46, loss 0.2570
# Training epoch 47, loss 0.1107
# Validation epoch 47, loss 0.2924
# Training epoch 48, loss 0.1076
# Validation epoch 48, loss 0.2168
# Training epoch 49, loss 0.1013
# Validation epoch 49, loss 0.2003
# Training epoch 50, loss 0.1021
# Validation epoch 50, loss 0.1965
# Training epoch 51, loss 0.1041
# Validation epoch 51, loss 0.1965
# Training epoch 52, loss 0.1017
# Validation epoch 52, loss 0.2563
# Training epoch 53, loss 0.1032
# Validation epoch 53, loss 0.2089
# Training epoch 54, loss 0.1043
# Validation epoch 54, loss 0.1836
# Training epoch 55, loss 0.0965
# Validation epoch 55, loss 0.1888
# Training epoch 56, loss 0.0945
# Validation epoch 56, loss 0.1875
# Training epoch 57, loss 0.0983
# Validation epoch 57, loss 0.1925
# Training epoch 58, loss 0.0900
# Validation epoch 58, loss 0.1984
# Training epoch 59, loss 0.0891
# Validation epoch 59, loss 0.1874
# Training epoch 60, loss 0.0963
# Validation epoch 60, loss 0.1961
# Training epoch 61, loss 0.0932
# Validation epoch 61, loss 0.2031
# Training epoch 62, loss 0.0853
# Validation epoch 62, loss 0.2075
# Training epoch 63, loss 0.0847
# Validation epoch 63, loss 0.2129
# Training epoch 64, loss 0.0866
# Validation epoch 64, loss 0.2159
# Training epoch 65, loss 0.0863
# Validation epoch 65, loss 0.2171
# Training epoch 66, loss 0.0826
# Validation epoch 66, loss 0.2598
# Training epoch 67, loss 0.0840
# Validation epoch 67, loss 0.2274
# Training epoch 68, loss 0.0861
# Validation epoch 68, loss 0.2306
# Training epoch 69, loss 0.0842
# Validation epoch 69, loss 0.1921
# Training epoch 70, loss 0.0777
# Validation epoch 70, loss 0.1934
# Training epoch 71, loss 0.0776
# Validation epoch 71, loss 0.1876
# Training epoch 72, loss 0.0737
# Validation epoch 72, loss 0.1797
# Training epoch 73, loss 0.0777
# Validation epoch 73, loss 0.1818
# Training epoch 74, loss 0.0800
# Validation epoch 74, loss 0.2172
# Training epoch 75, loss 0.0821
# Validation epoch 75, loss 0.2306
# Training epoch 76, loss 0.0844
# Validation epoch 76, loss 0.2075
# Training epoch 77, loss 0.0906
# Validation epoch 77, loss 0.2382
# Training epoch 78, loss 0.0884
# Validation epoch 78, loss 0.2208
# Training epoch 79, loss 0.0859
# Validation epoch 79, loss 0.2078
# Training epoch 80, loss 0.0845
# Validation epoch 80, loss 0.2321
# Training epoch 81, loss 0.0753
# Validation epoch 81, loss 0.2061
# Training epoch 82, loss 0.0733
# Validation epoch 82, loss 0.2388
# Training epoch 83, loss 0.0718
# Validation epoch 83, loss 0.2296
# Training epoch 84, loss 0.0633
# Validation epoch 84, loss 0.1779
# Training epoch 85, loss 0.0600
# Validation epoch 85, loss 0.1782
# Training epoch 86, loss 0.0619
# Validation epoch 86, loss 0.1724
# Training epoch 87, loss 0.0613
# Validation epoch 87, loss 0.1835
# Training epoch 88, loss 0.0623
# Validation epoch 88, loss 0.1944
# Training epoch 89, loss 0.0627
# Validation epoch 89, loss 0.1716
# Training epoch 90, loss 0.0629
# Validation epoch 90, loss 0.1791
# Training epoch 91, loss 0.0652
# Validation epoch 91, loss 0.1876
# Training epoch 92, loss 0.0662
# Validation epoch 92, loss 0.2362
# Training epoch 93, loss 0.0697
# Validation epoch 93, loss 0.2595
# Training epoch 94, loss 0.0664
# Validation epoch 94, loss 0.2388
# Training epoch 95, loss 0.0625
# Validation epoch 95, loss 0.2122
# Training epoch 96, loss 0.0575
# Validation epoch 96, loss 0.2243
# Training epoch 97, loss 0.0652
# Validation epoch 97, loss 0.2036
# Training epoch 98, loss 0.0581
# Validation epoch 98, loss 0.1958
# Training epoch 99, loss 0.0579
# Validation epoch 99, loss 0.2116
# Training epoch 0, loss 40.6485
# Validation epoch 0, loss 2.1167
# Training epoch 1, loss 0.8892
# Validation epoch 1, loss 0.4898
# Training epoch 2, loss 0.6046
# Validation epoch 2, loss 0.4199
# Training epoch 3, loss 0.5125
# Validation epoch 3, loss 0.5336
# Training epoch 4, loss 0.4249
# Validation epoch 4, loss 0.3764
# Training epoch 5, loss 0.3547
# Validation epoch 5, loss 0.3052
# Training epoch 6, loss 0.3181
# Validation epoch 6, loss 0.2866
# Training epoch 7, loss 0.2997
# Validation epoch 7, loss 0.2928
# Training epoch 8, loss 0.2839
# Validation epoch 8, loss 0.2870
# Training epoch 9, loss 0.2792
# Validation epoch 9, loss 0.3073
# Training epoch 10, loss 0.2760
# Validation epoch 10, loss 0.3136
# Training epoch 11, loss 0.2557
# Validation epoch 11, loss 0.2913
# Training epoch 12, loss 0.2508
# Validation epoch 12, loss 0.3641
# Training epoch 13, loss 0.2444
# Validation epoch 13, loss 0.2695
# Training epoch 14, loss 0.2296
# Validation epoch 14, loss 0.2470
# Training epoch 15, loss 0.2277
# Validation epoch 15, loss 0.2345
# Training epoch 16, loss 0.2361
# Validation epoch 16, loss 0.2379
# Training epoch 17, loss 0.2075
# Validation epoch 17, loss 0.2282
# Training epoch 18, loss 0.1974
# Validation epoch 18, loss 0.2307
# Training epoch 19, loss 0.1936
# Validation epoch 19, loss 0.2370
# Training epoch 20, loss 0.1929
# Validation epoch 20, loss 0.2519
# Training epoch 21, loss 0.1829
# Validation epoch 21, loss 0.2180
# Training epoch 22, loss 0.1740
# Validation epoch 22, loss 0.2375
# Training epoch 23, loss 0.1855
# Validation epoch 23, loss 0.2505
# Training epoch 24, loss 0.1851
# Validation epoch 24, loss 0.2492
# Training epoch 25, loss 0.1772
# Validation epoch 25, loss 0.2383
# Training epoch 26, loss 0.1738
# Validation epoch 26, loss 0.2198
# Training epoch 27, loss 0.1642
# Validation epoch 27, loss 0.2415
# Training epoch 28, loss 0.1558
# Validation epoch 28, loss 0.2444
# Training epoch 29, loss 0.1478
# Validation epoch 29, loss 0.3030
# Training epoch 30, loss 0.1456
# Validation epoch 30, loss 0.3262
# Training epoch 31, loss 0.1498
# Validation epoch 31, loss 0.3069
# Training epoch 32, loss 0.1456
# Validation epoch 32, loss 0.2719
# Training epoch 33, loss 0.1445
# Validation epoch 33, loss 0.2857
# Training epoch 34, loss 0.1373
# Validation epoch 34, loss 0.2693
# Training epoch 35, loss 0.1352
# Validation epoch 35, loss 0.2544
# Training epoch 36, loss 0.1348
# Validation epoch 36, loss 0.2597
# Training epoch 37, loss 0.1355
# Validation epoch 37, loss 0.2135
# Training epoch 38, loss 0.1340
# Validation epoch 38, loss 0.2095
# Training epoch 39, loss 0.1302
# Validation epoch 39, loss 0.2101
# Training epoch 40, loss 0.1330
# Validation epoch 40, loss 0.2271
# Training epoch 41, loss 0.1227
# Validation epoch 41, loss 0.2121
# Training epoch 42, loss 0.1226
# Validation epoch 42, loss 0.2245
# Training epoch 43, loss 0.1219
# Validation epoch 43, loss 0.2422
# Training epoch 44, loss 0.1223
# Validation epoch 44, loss 0.2602
# Training epoch 45, loss 0.1145
# Validation epoch 45, loss 0.2159
# Training epoch 46, loss 0.1134
# Validation epoch 46, loss 0.2296
# Training epoch 47, loss 0.1126
# Validation epoch 47, loss 0.2406
# Training epoch 48, loss 0.1144
# Validation epoch 48, loss 0.2553
# Training epoch 49, loss 0.1125
# Validation epoch 49, loss 0.2703
# Training epoch 50, loss 0.1078
# Validation epoch 50, loss 0.2578
# Training epoch 51, loss 0.1004
# Validation epoch 51, loss 0.3106
# Training epoch 52, loss 0.1008
# Validation epoch 52, loss 0.2647
# Training epoch 53, loss 0.1029
# Validation epoch 53, loss 0.2220
# Training epoch 54, loss 0.1037
# Validation epoch 54, loss 0.2102
# Training epoch 55, loss 0.1157
# Validation epoch 55, loss 0.2149
# Training epoch 56, loss 0.1067
# Validation epoch 56, loss 0.2025
# Training epoch 57, loss 0.0966
# Validation epoch 57, loss 0.1935
# Training epoch 58, loss 0.0981
# Validation epoch 58, loss 0.2095
# Training epoch 59, loss 0.0943
# Validation epoch 59, loss 0.2546
# Training epoch 60, loss 0.0957
# Validation epoch 60, loss 0.2730
# Training epoch 61, loss 0.0958
# Validation epoch 61, loss 0.2136
# Training epoch 62, loss 0.0875
# Validation epoch 62, loss 0.2575
# Training epoch 63, loss 0.0877
# Validation epoch 63, loss 0.2748
# Training epoch 64, loss 0.0907
# Validation epoch 64, loss 0.2450
# Training epoch 65, loss 0.0904
# Validation epoch 65, loss 0.2870
# Training epoch 66, loss 0.0827
# Validation epoch 66, loss 0.2027
# Training epoch 67, loss 0.0815
# Validation epoch 67, loss 0.1777
# Training epoch 68, loss 0.0818
# Validation epoch 68, loss 0.2146
# Training epoch 69, loss 0.0877
# Validation epoch 69, loss 0.2090
# Training epoch 70, loss 0.0932
# Validation epoch 70, loss 0.2056
# Training epoch 71, loss 0.0881
# Validation epoch 71, loss 0.1830
# Training epoch 72, loss 0.0886
# Validation epoch 72, loss 0.1866
# Training epoch 73, loss 0.0861
# Validation epoch 73, loss 0.1945
# Training epoch 74, loss 0.0831
# Validation epoch 74, loss 0.1817
# Training epoch 75, loss 0.0752
# Validation epoch 75, loss 0.1864
# Training epoch 76, loss 0.0696
# Validation epoch 76, loss 0.2047
# Training epoch 77, loss 0.0696
# Validation epoch 77, loss 0.1866
# Training epoch 78, loss 0.0677
# Validation epoch 78, loss 0.1828
# Training epoch 79, loss 0.0636
# Validation epoch 79, loss 0.1683
# Training epoch 80, loss 0.0652
# Validation epoch 80, loss 0.1753
# Training epoch 81, loss 0.0681
# Validation epoch 81, loss 0.1958
# Training epoch 82, loss 0.0709
# Validation epoch 82, loss 0.2038
# Training epoch 83, loss 0.0740
# Validation epoch 83, loss 0.1943
# Training epoch 84, loss 0.0659
# Validation epoch 84, loss 0.1828
# Training epoch 85, loss 0.0705
# Validation epoch 85, loss 0.1797
# Training epoch 86, loss 0.0701
# Validation epoch 86, loss 0.1939
# Training epoch 87, loss 0.0735
# Validation epoch 87, loss 0.1808
# Training epoch 88, loss 0.0734
# Validation epoch 88, loss 0.1728
# Training epoch 89, loss 0.0704
# Validation epoch 89, loss 0.1765
# Training epoch 90, loss 0.0739
# Validation epoch 90, loss 0.1832
# Training epoch 91, loss 0.0726
# Validation epoch 91, loss 0.1993
# Training epoch 92, loss 0.0740
# Validation epoch 92, loss 0.2134
# Training epoch 93, loss 0.0699
# Validation epoch 93, loss 0.1915
# Training epoch 94, loss 0.0791
# Validation epoch 94, loss 0.2059
# Training epoch 95, loss 0.0810
# Validation epoch 95, loss 0.2435
# Training epoch 96, loss 0.0775
# Validation epoch 96, loss 0.2907
# Training epoch 97, loss 0.0810
# Validation epoch 97, loss 0.2487
# Training epoch 98, loss 0.0735
# Validation epoch 98, loss 0.2159
# Training epoch 99, loss 0.0730
# Validation epoch 99, loss 0.1744
# Training epoch 0, loss 32.6399
# Validation epoch 0, loss 1.6621
# Training epoch 1, loss 0.8323
# Validation epoch 1, loss 0.5004
# Training epoch 2, loss 0.6054
# Validation epoch 2, loss 0.3905
# Training epoch 3, loss 0.5173
# Validation epoch 3, loss 0.3654
# Training epoch 4, loss 0.4455
# Validation epoch 4, loss 0.3547
# Training epoch 5, loss 0.3779
# Validation epoch 5, loss 0.3928
# Training epoch 6, loss 0.3281
# Validation epoch 6, loss 0.3584
# Training epoch 7, loss 0.2892
# Validation epoch 7, loss 0.3335
# Training epoch 8, loss 0.2609
# Validation epoch 8, loss 0.3122
# Training epoch 9, loss 0.2447
# Validation epoch 9, loss 0.3607
# Training epoch 10, loss 0.2336
# Validation epoch 10, loss 0.3369
# Training epoch 11, loss 0.2324
# Validation epoch 11, loss 0.2928
# Training epoch 12, loss 0.2259
# Validation epoch 12, loss 0.3328
# Training epoch 13, loss 0.2279
# Validation epoch 13, loss 0.2802
# Training epoch 14, loss 0.2238
# Validation epoch 14, loss 0.2956
# Training epoch 15, loss 0.2285
# Validation epoch 15, loss 0.3231
# Training epoch 16, loss 0.2134
# Validation epoch 16, loss 0.3125
# Training epoch 17, loss 0.1963
# Validation epoch 17, loss 0.2536
# Training epoch 18, loss 0.1898
# Validation epoch 18, loss 0.2339
# Training epoch 19, loss 0.1792
# Validation epoch 19, loss 0.2306
# Training epoch 20, loss 0.1620
# Validation epoch 20, loss 0.2284
# Training epoch 21, loss 0.1564
# Validation epoch 21, loss 0.2423
# Training epoch 22, loss 0.1540
# Validation epoch 22, loss 0.3119
# Training epoch 23, loss 0.1513
# Validation epoch 23, loss 0.3291
# Training epoch 24, loss 0.1482
# Validation epoch 24, loss 0.2938
# Training epoch 25, loss 0.1447
# Validation epoch 25, loss 0.2388
# Training epoch 26, loss 0.1506
# Validation epoch 26, loss 0.2275
# Training epoch 27, loss 0.1464
# Validation epoch 27, loss 0.2362
# Training epoch 28, loss 0.1417
# Validation epoch 28, loss 0.2727
# Training epoch 29, loss 0.1377
# Validation epoch 29, loss 0.2687
# Training epoch 30, loss 0.1415
# Validation epoch 30, loss 0.2083
# Training epoch 31, loss 0.1426
# Validation epoch 31, loss 0.2524
# Training epoch 32, loss 0.1366
# Validation epoch 32, loss 0.2254
# Training epoch 33, loss 0.1319
# Validation epoch 33, loss 0.2039
# Training epoch 34, loss 0.1286
# Validation epoch 34, loss 0.1974
# Training epoch 35, loss 0.1327
# Validation epoch 35, loss 0.2333
# Training epoch 36, loss 0.1284
# Validation epoch 36, loss 0.1986
# Training epoch 37, loss 0.1199
# Validation epoch 37, loss 0.2051
# Training epoch 38, loss 0.1175
# Validation epoch 38, loss 0.2151
# Training epoch 39, loss 0.1109
# Validation epoch 39, loss 0.2362
# Training epoch 40, loss 0.1032
# Validation epoch 40, loss 0.3057
# Training epoch 41, loss 0.1025
# Validation epoch 41, loss 0.2267
# Training epoch 42, loss 0.0969
# Validation epoch 42, loss 0.2915
# Training epoch 43, loss 0.0949
# Validation epoch 43, loss 0.4169
# Training epoch 44, loss 0.1015
# Validation epoch 44, loss 0.3868
# Training epoch 45, loss 0.1078
# Validation epoch 45, loss 0.3564
# Training epoch 46, loss 0.1030
# Validation epoch 46, loss 0.2181
# Training epoch 47, loss 0.1048
# Validation epoch 47, loss 0.2232
# Training epoch 48, loss 0.1128
# Validation epoch 48, loss 0.2365
# Training epoch 49, loss 0.1039
# Validation epoch 49, loss 0.1954
# Training epoch 50, loss 0.1057
# Validation epoch 50, loss 0.2041
# Training epoch 51, loss 0.1031
# Validation epoch 51, loss 0.2164
# Training epoch 52, loss 0.0978
# Validation epoch 52, loss 0.2138
# Training epoch 53, loss 0.0876
# Validation epoch 53, loss 0.2162
# Training epoch 54, loss 0.0940
# Validation epoch 54, loss 0.2036
# Training epoch 55, loss 0.0940
# Validation epoch 55, loss 0.2134
# Training epoch 56, loss 0.0936
# Validation epoch 56, loss 0.2207
# Training epoch 57, loss 0.0894
# Validation epoch 57, loss 0.2104
# Training epoch 58, loss 0.0842
# Validation epoch 58, loss 0.2542
# Training epoch 59, loss 0.0861
# Validation epoch 59, loss 0.2127
# Training epoch 60, loss 0.0867
# Validation epoch 60, loss 0.2542
# Training epoch 61, loss 0.0872
# Validation epoch 61, loss 0.1773
# Training epoch 62, loss 0.0972
# Validation epoch 62, loss 0.2117
# Training epoch 63, loss 0.0871
# Validation epoch 63, loss 0.2215
# Training epoch 64, loss 0.0896
# Validation epoch 64, loss 0.1816
# Training epoch 65, loss 0.0956
# Validation epoch 65, loss 0.2215
# Training epoch 66, loss 0.0899
# Validation epoch 66, loss 0.2017
# Training epoch 67, loss 0.0855
# Validation epoch 67, loss 0.2554
# Training epoch 68, loss 0.0732
# Validation epoch 68, loss 0.1990
# Training epoch 69, loss 0.0736
# Validation epoch 69, loss 0.1974
# Training epoch 70, loss 0.0788
# Validation epoch 70, loss 0.1956
# Training epoch 71, loss 0.0747
# Validation epoch 71, loss 0.1852
# Training epoch 72, loss 0.0757
# Validation epoch 72, loss 0.1915
# Training epoch 73, loss 0.0780
# Validation epoch 73, loss 0.2048
# Training epoch 74, loss 0.0810
# Validation epoch 74, loss 0.1965
# Training epoch 75, loss 0.0838
# Validation epoch 75, loss 0.1945
# Training epoch 76, loss 0.0805
# Validation epoch 76, loss 0.1870
# Training epoch 77, loss 0.0796
# Validation epoch 77, loss 0.2465
# Training epoch 78, loss 0.0772
# Validation epoch 78, loss 0.3555
# Training epoch 79, loss 0.0800
# Validation epoch 79, loss 0.2315
# Training epoch 80, loss 0.0709
# Validation epoch 80, loss 0.2273
# Training epoch 81, loss 0.0747
# Validation epoch 81, loss 0.2273
# Training epoch 82, loss 0.0737
# Validation epoch 82, loss 0.2456
# Training epoch 83, loss 0.0731
# Validation epoch 83, loss 0.1909
# Training epoch 84, loss 0.0689
# Validation epoch 84, loss 0.1917
# Training epoch 85, loss 0.0616
# Validation epoch 85, loss 0.1994
# Training epoch 86, loss 0.0621
# Validation epoch 86, loss 0.2076
# Training epoch 87, loss 0.0703
# Validation epoch 87, loss 0.2016
# Training epoch 88, loss 0.0717
# Validation epoch 88, loss 0.1835
# Training epoch 89, loss 0.0732
# Validation epoch 89, loss 0.1721
# Training epoch 90, loss 0.0767
# Validation epoch 90, loss 0.1855
# Training epoch 91, loss 0.0689
# Validation epoch 91, loss 0.1796
# Training epoch 92, loss 0.0611
# Validation epoch 92, loss 0.1739
# Training epoch 93, loss 0.0593
# Validation epoch 93, loss 0.1915
# Training epoch 94, loss 0.0549
# Validation epoch 94, loss 0.1817
# Training epoch 95, loss 0.0536
# Validation epoch 95, loss 0.1964
# Training epoch 96, loss 0.0579
# Validation epoch 96, loss 0.1841
# Training epoch 97, loss 0.0586
# Validation epoch 97, loss 0.1783
# Training epoch 98, loss 0.0569
# Validation epoch 98, loss 0.1849
# Training epoch 99, loss 0.0602
# Validation epoch 99, loss 0.1938
# 5-fold CVMSE: 0.1754716157913208
